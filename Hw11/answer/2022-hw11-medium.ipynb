# %% [markdown]
# # Homework 11 - Transfer Learning (Domain Adversarial Training)
#
# > Author: Arvin Liu (r09922071@ntu.edu.tw)
#
# If there are any questions, please contact mlta-2022-spring@googlegroups.com

# %% [markdown]
# # Readme
#
# In homework 11, you will need to implement Domain Adversarial Training in Transfer Learning. As shown in the bottom left part of the figure.
#
# <img src="https://i.imgur.com/iMVIxCH.png" width="500px">
#
# >
#
# ## Scenario and Why Domain Adversarial Training
# Now we have labeled source data and unlabeled target data, where source data might be relavent to the target data. We now want to train a model with source data only and test it on target data.
#
# What problem might occur if we do so? After we have learned Anomaly Detection, we now know that if we test the model with an abnormal data that have never appeared in source data, our trained model is likely to result in poor performance since it is not familiar with the abnormal data.
#
# For example, we have a model that contains Feature Extractor and Classifier:
# <img src="https://i.imgur.com/IL0PxCY.png" width="500px">
#
# When the model is trained with source data, the feature extractor
# will extract meaningful features since it is familiar with the distribution of it.It could be seen in the following figure that the blue dots, which is the distribution of source data, has already been clustered into different clusters. Therefore, the Classifier can predict the label based on these clusters.
#
# However, when test on the target data, the Feature Extractor will not be able to extract meaningful features that follow the distribution of the source feature distribution, which result in the classifier learned for the source domain will not be able to apply to the target domain.
#
#
# ## Domain Adversarial Training of Nerural Networks (DaNN)
#
# Based on the above problems, DaNN approaches build mappings between the source (training-time) and the target (test-time) domains, so that the classifier learned for the source domain can also be applied to the target domain, when composed with the learned mapping between domains.
#
# <img src="https://i.imgur.com/vrOE5a6.png" width="500px">
#
# In DaNN, the authors added a Domain Classifier, which is a deep discriminatively-trained classifeir in the training framework to distinguish the data from different domain by the features extracted by the feature extractor. As the training progresses, the approach promotes a domain classifier that discriminates between the source and the target domains and a feature extractor that can extractor features that are discriminative for the main learning task on the source domain and indiscriminate with respect to the shift between the domains.
#
#
# The feature extractor are likely to outperform the domain classifier as its input are generated by the feature extractor and that the task of domain classification and label classification are not conflict.
#
# This method leads to the emergence of features that are domain-invariant and on the same feature distribution.

# %% [markdown]
# # Data Introduce
#
# Our task contains source data: real photos, and target data: hand-drawn graffiti.
#
# We are going to train the model with the photos and the labels, and try to predict what the labels are for hand-drawn graffiti.
#
# The data could be downloaded [here](https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip). The code below is for data downloading and visualization.
#
# Note that: **The source and target data are all balanced data, you can make use of this information.**

# %%
# Download dataset
#!wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip" -O real_or_drawing.zip

# Download from mirrored dataset link
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.1/real_or_drawing.zip" -O real_or_drawing.zip
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.2/real_or_drawing.zip" -O real_or_drawing.zip

# Unzip the files
#!unzip real_or_drawing.zip

# %%
import matplotlib.pyplot as plt

def no_axis_show(img, title='', cmap=None):
  # imshow, and set the interpolation mode to be "nearest"。
  fig = plt.imshow(img, interpolation='nearest', cmap=cmap)
  # do not show the axes in the images.
  fig.axes.get_xaxis().set_visible(False)
  fig.axes.get_yaxis().set_visible(False)
  plt.title(title)

titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/train_data/{i}/{500*i}.bmp'), title=titles[i])

# %%
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/test_data/0/' + str(i).rjust(5, '0') + '.bmp'))

# %% [markdown]
# # Special Domain Knowledge
#
# When we graffiti, we usually draw the outline only, therefore we can perform edge detection processing on the source data to make it more similar to the target data.
#
#
# ## Canny Edge Detection
# The implementation of Canny Edge Detection is as follow.
# The algorithm will not be describe thoroughly here.  If you are interested, please refer to the wiki or [here](https://medium.com/@pomelyu5199/canny-edge-detector-%E5%AF%A6%E4%BD%9C-opencv-f7d1a0a57d19).
#
# We only need two parameters to implement Canny Edge Detection with CV2:  `low_threshold` and `high_threshold`.
#
# ```cv2.Canny(image, low_threshold, high_threshold)```
#
# Simply put, when the edge value exceeds the high_threshold, we determine it as an edge. If the edge value is only above low_threshold, we will then determine whether it is an edge or not.
#
# Let's implement it on the source data.

# %%
import cv2
import matplotlib.pyplot as plt
titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))

original_img = plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/train_data/0/0.bmp')
plt.subplot(1, 5, 1)
no_axis_show(original_img, title='original')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

canny_50100 = cv2.Canny(gray_img, 50, 100)
plt.subplot(1, 5, 3)
no_axis_show(canny_50100, title='Canny(50, 100)', cmap='gray')

canny_150200 = cv2.Canny(gray_img, 150, 200)
plt.subplot(1, 5, 4)
no_axis_show(canny_150200, title='Canny(150, 200)', cmap='gray')

canny_250300 = cv2.Canny(gray_img, 250, 300)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(250, 300)', cmap='gray')

# %% [markdown]
# # Data Process
#
#
# The data is suitible for `torchvision.ImageFolder`. You can create a dataset with `torchvision.ImageFolder`. Details for image augmentation please refer to the comments in the following codes.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Function
 
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
 
source_transform = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 170, 300)),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
target_transform = transforms.Compose([
    # Turn RGB to grayscale.
    transforms.Grayscale(),
    # Resize: size of source data is 32x32, thus we need to 
    #  enlarge the size of target data from 28x28 to 32x32。
    transforms.Resize((32, 32)),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
 
source_dataset = ImageFolder('../input/ml2022-spring-hw11/real_or_drawing/train_data', transform=source_transform)
target_dataset = ImageFolder('../input/ml2022-spring-hw11/real_or_drawing/test_data', transform=target_transform)
 
source_dataloader = DataLoader(source_dataset, batch_size=32, shuffle=True)
target_dataloader = DataLoader(target_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(target_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# # Model
#
# Feature Extractor: Classic VGG-like architecture
#
# Label Predictor / Domain Classifier: Linear models.

# %%
class FeatureExtractor(nn.Module):

    def __init__(self):
        super(FeatureExtractor, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
    def forward(self, x):
        x = self.conv(x).squeeze()
        return x

class LabelPredictor(nn.Module):

    def __init__(self):
        super(LabelPredictor, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 10),
        )

    def forward(self, h):
        c = self.layer(h)
        return c

class DomainClassifier(nn.Module):

    def __init__(self):
        super(DomainClassifier, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 1),
        )

    def forward(self, h):
        y = self.layer(h)
        return y

# %% [markdown]
# # Pre-processing
#
# Here we use Adam as our optimizor.

# %%
feature_extractor = FeatureExtractor().cuda()
label_predictor = LabelPredictor().cuda()
domain_classifier = DomainClassifier().cuda()

class_criterion = nn.CrossEntropyLoss()
domain_criterion = nn.BCEWithLogitsLoss()

optimizer_F = optim.Adam(feature_extractor.parameters())
optimizer_C = optim.Adam(label_predictor.parameters())
optimizer_D = optim.Adam(domain_classifier.parameters())

# %% [markdown]
# # Start Training
#
#
# ## DaNN Implementation
#
# In the original paper, Gradient Reversal Layer is used.
# Feature Extractor, Label Predictor, and Domain Classifier are all trained at the same time. In this code, we train Domain Classifier first, and then train our Feature Extractor (same concept as Generator and Discriminator training process in GAN).
#
# ## Reminder
# * Lambda, which controls the domain adversarial loss, is adaptive in the original paper. You can refer to [the original work](https://arxiv.org/pdf/1505.07818.pdf) . Here lambda is set to 0.1.
# * We do not have the label to target data, you can only evaluate your model by uploading your result to kaggle.:)

# %%
def train_epoch(source_dataloader, target_dataloader, lamb):
    '''
      Args:
        source_dataloader: source data的dataloader
        target_dataloader: target data的dataloader
        lamb: control the balance of domain adaptatoin and classification.
    '''

    # D loss: Domain Classifier的loss
    # F loss: Feature Extrator & Label Predictor的loss
    running_D_loss, running_F_loss = 0.0, 0.0
    total_hit, total_num = 0.0, 0.0

    for i, ((source_data, source_label), (target_data, _)) in enumerate(zip(source_dataloader, target_dataloader)):

        source_data = source_data.cuda()
        source_label = source_label.cuda()
        target_data = target_data.cuda()
        
        # Mixed the source data and target data, or it'll mislead the running params
        #   of batch_norm. (runnning mean/var of soucre and target data are different.)
        mixed_data = torch.cat([source_data, target_data], dim=0)
        domain_label = torch.zeros([source_data.shape[0] + target_data.shape[0], 1]).cuda()
        # set domain label of source data to be 1.
        domain_label[:source_data.shape[0]] = 1

        # Step 1 : train domain classifier
        feature = feature_extractor(mixed_data)
        # We don't need to train feature extractor in step 1.
        # Thus we detach the feature neuron to avoid backpropgation.
        domain_logits = domain_classifier(feature.detach())
        loss = domain_criterion(domain_logits, domain_label)
        running_D_loss+= loss.item()
        loss.backward()
        optimizer_D.step()

        # Step 2 : train feature extractor and label classifier
        class_logits = label_predictor(feature[:source_data.shape[0]])
        domain_logits = domain_classifier(feature)
        # loss = cross entropy of classification - lamb * domain binary cross entropy.
        #  The reason why using subtraction is similar to generator loss in disciminator of GAN
        loss = class_criterion(class_logits, source_label) - lamb * domain_criterion(domain_logits, domain_label)
        running_F_loss+= loss.item()
        loss.backward()
        optimizer_F.step()
        optimizer_C.step()

        optimizer_D.zero_grad()
        optimizer_F.zero_grad()
        optimizer_C.zero_grad()

        total_hit += torch.sum(torch.argmax(class_logits, dim=1) == source_label).item()
        total_num += source_data.shape[0]
        print(i, end='\r')

    return running_D_loss / (i+1), running_F_loss / (i+1), total_hit / total_num

# train 200 epochs
epochs = 800
marked_epoch = [1, epochs//3, epochs - 1]
for epoch in range(epochs):
    train_D_loss, train_F_loss, train_acc = train_epoch(source_dataloader, target_dataloader, lamb=0.7)
    
    if epoch in marked_epoch:
        torch.save(feature_extractor.state_dict(), f'extractor_model_{epoch}.bin')
        torch.save(label_predictor.state_dict(), f'predictor_model_{epoch}.bin')



    print('epoch {:>3d}: train D loss: {:6.4f}, train F loss: {:6.4f}, acc {:6.4f}'.format(epoch, train_D_loss, train_F_loss, train_acc))
torch.save(feature_extractor.state_dict(), f'extractor_model.bin')
torch.save(label_predictor.state_dict(), f'predictor_model.bin')
# Out:
# epoch   0: train D loss: 0.5986, train F loss: 1.9370, acc 0.1430
# epoch   1: train D loss: 0.6718, train F loss: 1.6451, acc 0.2154
# epoch   2: train D loss: 0.6761, train F loss: 1.5008, acc 0.2674
# epoch   3: train D loss: 0.6955, train F loss: 1.3657, acc 0.3158
# epoch   4: train D loss: 0.6773, train F loss: 1.2559, acc 0.3762
# epoch   5: train D loss: 0.6795, train F loss: 1.1339, acc 0.4172
# epoch   6: train D loss: 0.6608, train F loss: 1.0860, acc 0.4486
# epoch   7: train D loss: 0.6719, train F loss: 0.9979, acc 0.4864
# epoch   8: train D loss: 0.6711, train F loss: 0.9451, acc 0.4990
# epoch   9: train D loss: 0.6492, train F loss: 0.9419, acc 0.5160
# epoch  10: train D loss: 0.6614, train F loss: 0.8640, acc 0.5308
# epoch  11: train D loss: 0.6724, train F loss: 0.8214, acc 0.5478
# epoch  12: train D loss: 0.6578, train F loss: 0.8116, acc 0.5574
# epoch  13: train D loss: 0.6718, train F loss: 0.7652, acc 0.5652
# epoch  14: train D loss: 0.6626, train F loss: 0.7321, acc 0.5794
# epoch  15: train D loss: 0.6702, train F loss: 0.7088, acc 0.5962
# epoch  16: train D loss: 0.6718, train F loss: 0.6793, acc 0.6006
# epoch  17: train D loss: 0.6698, train F loss: 0.6536, acc 0.6158
# epoch  18: train D loss: 0.6683, train F loss: 0.6179, acc 0.6216
# epoch  19: train D loss: 0.6735, train F loss: 0.5909, acc 0.6296
# epoch  20: train D loss: 0.6685, train F loss: 0.5516, acc 0.6460
# epoch  21: train D loss: 0.6736, train F loss: 0.5336, acc 0.6466
# epoch  22: train D loss: 0.6682, train F loss: 0.4993, acc 0.6646
# epoch  23: train D loss: 0.6653, train F loss: 0.4972, acc 0.6636
# epoch  24: train D loss: 0.6635, train F loss: 0.4560, acc 0.6882
# epoch  25: train D loss: 0.6634, train F loss: 0.4188, acc 0.6942
# epoch  26: train D loss: 0.6674, train F loss: 0.3692, acc 0.6970
# epoch  27: train D loss: 0.6522, train F loss: 0.3708, acc 0.7236
# epoch  28: train D loss: 0.6646, train F loss: 0.3555, acc 0.7190
# epoch  29: train D loss: 0.6544, train F loss: 0.3085, acc 0.7356
# epoch  30: train D loss: 0.6710, train F loss: 0.2608, acc 0.7530
# epoch  31: train D loss: 0.6559, train F loss: 0.2597, acc 0.7506
# epoch  32: train D loss: 0.6617, train F loss: 0.2093, acc 0.7654
# epoch  33: train D loss: 0.6533, train F loss: 0.1937, acc 0.7742
# epoch  34: train D loss: 0.6726, train F loss: 0.1660, acc 0.7820
# epoch  35: train D loss: 0.6532, train F loss: 0.1537, acc 0.7894
# epoch  36: train D loss: 0.6640, train F loss: 0.1122, acc 0.7996
# epoch  37: train D loss: 0.6675, train F loss: 0.1146, acc 0.8004
# epoch  38: train D loss: 0.6471, train F loss: 0.0855, acc 0.8174
# epoch  39: train D loss: 0.6607, train F loss: 0.0438, acc 0.8260
# epoch  40: train D loss: 0.6454, train F loss: 0.0435, acc 0.8356
# epoch  41: train D loss: 0.6610, train F loss: 0.0110, acc 0.8428
# epoch  42: train D loss: 0.6570, train F loss: -0.0345, acc 0.8528
# epoch  43: train D loss: 0.6473, train F loss: -0.0215, acc 0.8566
# epoch  44: train D loss: 0.6422, train F loss: -0.0442, acc 0.8662
# epoch  45: train D loss: 0.6521, train F loss: -0.0458, acc 0.8630
# epoch  46: train D loss: 0.6403, train F loss: -0.0669, acc 0.8730
# epoch  47: train D loss: 0.6376, train F loss: -0.0810, acc 0.8842
# epoch  48: train D loss: 0.6384, train F loss: -0.0678, acc 0.8762
# epoch  49: train D loss: 0.6304, train F loss: -0.0840, acc 0.8806
# epoch  50: train D loss: 0.6401, train F loss: -0.1090, acc 0.8892
# epoch  51: train D loss: 0.6456, train F loss: -0.1256, acc 0.8852
# epoch  52: train D loss: 0.6533, train F loss: -0.1560, acc 0.8990
# epoch  53: train D loss: 0.6447, train F loss: -0.1331, acc 0.8968
# epoch  54: train D loss: 0.6331, train F loss: -0.1240, acc 0.8996
# epoch  55: train D loss: 0.6303, train F loss: -0.1493, acc 0.9042
# epoch  56: train D loss: 0.6368, train F loss: -0.1839, acc 0.9182
# epoch  57: train D loss: 0.6425, train F loss: -0.1780, acc 0.9100
# epoch  58: train D loss: 0.6471, train F loss: -0.1849, acc 0.9156
# epoch  59: train D loss: 0.6442, train F loss: -0.1986, acc 0.9160
# epoch  60: train D loss: 0.6337, train F loss: -0.2013, acc 0.9286
# epoch  61: train D loss: 0.6424, train F loss: -0.2042, acc 0.9184
# epoch  62: train D loss: 0.6339, train F loss: -0.1965, acc 0.9232
# epoch  63: train D loss: 0.6358, train F loss: -0.2020, acc 0.9236
# epoch  64: train D loss: 0.6461, train F loss: -0.1983, acc 0.9172
# epoch  65: train D loss: 0.6440, train F loss: -0.2365, acc 0.9320
# epoch  66: train D loss: 0.6347, train F loss: -0.2161, acc 0.9300
# epoch  67: train D loss: 0.6301, train F loss: -0.2100, acc 0.9284
# epoch  68: train D loss: 0.6412, train F loss: -0.2371, acc 0.9332
# epoch  69: train D loss: 0.6455, train F loss: -0.2293, acc 0.9288
# epoch  70: train D loss: 0.6296, train F loss: -0.2384, acc 0.9364
# epoch  71: train D loss: 0.6428, train F loss: -0.2592, acc 0.9386
# epoch  72: train D loss: 0.6323, train F loss: -0.2540, acc 0.9430
# epoch  73: train D loss: 0.6555, train F loss: -0.2638, acc 0.9366
# epoch  74: train D loss: 0.6377, train F loss: -0.2536, acc 0.9334
# epoch  75: train D loss: 0.6470, train F loss: -0.2628, acc 0.9400
# epoch  76: train D loss: 0.6406, train F loss: -0.2871, acc 0.9500
# epoch  77: train D loss: 0.6454, train F loss: -0.2861, acc 0.9488
# epoch  78: train D loss: 0.6278, train F loss: -0.2679, acc 0.9472
# epoch  79: train D loss: 0.6442, train F loss: -0.2581, acc 0.9372
# epoch  80: train D loss: 0.6425, train F loss: -0.2728, acc 0.9468
# epoch  81: train D loss: 0.6383, train F loss: -0.2797, acc 0.9486
# epoch  82: train D loss: 0.6372, train F loss: -0.2759, acc 0.9498
# epoch  83: train D loss: 0.6544, train F loss: -0.2765, acc 0.9418
# epoch  84: train D loss: 0.6303, train F loss: -0.2773, acc 0.9514
# epoch  85: train D loss: 0.6446, train F loss: -0.2820, acc 0.9482
# epoch  86: train D loss: 0.6450, train F loss: -0.2875, acc 0.9480
# epoch  87: train D loss: 0.6278, train F loss: -0.2885, acc 0.9570
# epoch  88: train D loss: 0.6401, train F loss: -0.2926, acc 0.9508
# epoch  89: train D loss: 0.6338, train F loss: -0.2584, acc 0.9436
# epoch  90: train D loss: 0.6482, train F loss: -0.3126, acc 0.9572
# epoch  91: train D loss: 0.6248, train F loss: -0.2789, acc 0.9492
# epoch  92: train D loss: 0.6378, train F loss: -0.2922, acc 0.9556
# epoch  93: train D loss: 0.6424, train F loss: -0.2932, acc 0.9534
# epoch  94: train D loss: 0.6423, train F loss: -0.2920, acc 0.9532
# epoch  95: train D loss: 0.6364, train F loss: -0.3127, acc 0.9598
# epoch  96: train D loss: 0.6338, train F loss: -0.2903, acc 0.9532
# epoch  97: train D loss: 0.6410, train F loss: -0.3048, acc 0.9540
# epoch  98: train D loss: 0.6309, train F loss: -0.3097, acc 0.9598
# epoch  99: train D loss: 0.6385, train F loss: -0.3159, acc 0.9612
# epoch 100: train D loss: 0.6318, train F loss: -0.3036, acc 0.9584
# epoch 101: train D loss: 0.6347, train F loss: -0.2950, acc 0.9534
# epoch 102: train D loss: 0.6332, train F loss: -0.2967, acc 0.9564
# epoch 103: train D loss: 0.6351, train F loss: -0.2958, acc 0.9528
# epoch 104: train D loss: 0.6362, train F loss: -0.3059, acc 0.9556
# epoch 105: train D loss: 0.6405, train F loss: -0.3058, acc 0.9558
# epoch 106: train D loss: 0.6369, train F loss: -0.3183, acc 0.9630
# epoch 107: train D loss: 0.6397, train F loss: -0.3192, acc 0.9584
# epoch 108: train D loss: 0.6394, train F loss: -0.3037, acc 0.9570
# epoch 109: train D loss: 0.6324, train F loss: -0.3057, acc 0.9562
# epoch 110: train D loss: 0.6458, train F loss: -0.3185, acc 0.9602
# epoch 111: train D loss: 0.6263, train F loss: -0.3156, acc 0.9654
# epoch 112: train D loss: 0.6331, train F loss: -0.3175, acc 0.9594
# epoch 113: train D loss: 0.6395, train F loss: -0.3072, acc 0.9604
# epoch 114: train D loss: 0.6396, train F loss: -0.3413, acc 0.9662
# epoch 115: train D loss: 0.6370, train F loss: -0.3083, acc 0.9612
# epoch 116: train D loss: 0.6437, train F loss: -0.3092, acc 0.9518
# epoch 117: train D loss: 0.6397, train F loss: -0.3296, acc 0.9630
# epoch 118: train D loss: 0.6323, train F loss: -0.3126, acc 0.9632
# epoch 119: train D loss: 0.6323, train F loss: -0.2997, acc 0.9554
# epoch 120: train D loss: 0.6343, train F loss: -0.3256, acc 0.9636
# epoch 121: train D loss: 0.6273, train F loss: -0.3017, acc 0.9618
# epoch 122: train D loss: 0.6409, train F loss: -0.3282, acc 0.9630
# epoch 123: train D loss: 0.6325, train F loss: -0.3286, acc 0.9664
# epoch 124: train D loss: 0.6363, train F loss: -0.3225, acc 0.9628
# epoch 125: train D loss: 0.6337, train F loss: -0.3096, acc 0.9586
# epoch 126: train D loss: 0.6407, train F loss: -0.3225, acc 0.9630
# epoch 127: train D loss: 0.6308, train F loss: -0.3157, acc 0.9630
# epoch 128: train D loss: 0.6283, train F loss: -0.3270, acc 0.9688
# epoch 129: train D loss: 0.6441, train F loss: -0.3455, acc 0.9678
# epoch 130: train D loss: 0.6352, train F loss: -0.3051, acc 0.9624
# epoch 131: train D loss: 0.6409, train F loss: -0.3291, acc 0.9660
# epoch 132: train D loss: 0.6277, train F loss: -0.3180, acc 0.9660
# epoch 133: train D loss: 0.6370, train F loss: -0.3254, acc 0.9640
# epoch 134: train D loss: 0.6401, train F loss: -0.3487, acc 0.9710
# epoch 135: train D loss: 0.6340, train F loss: -0.3257, acc 0.9632
# epoch 136: train D loss: 0.6349, train F loss: -0.3243, acc 0.9652
# epoch 137: train D loss: 0.6383, train F loss: -0.3313, acc 0.9682
# epoch 138: train D loss: 0.6283, train F loss: -0.3393, acc 0.9742
# epoch 139: train D loss: 0.6416, train F loss: -0.3255, acc 0.9604
# epoch 140: train D loss: 0.6385, train F loss: -0.3182, acc 0.9636
# epoch 141: train D loss: 0.6319, train F loss: -0.3234, acc 0.9644
# epoch 142: train D loss: 0.6353, train F loss: -0.3399, acc 0.9702
# epoch 143: train D loss: 0.6392, train F loss: -0.3445, acc 0.9688
# epoch 144: train D loss: 0.6448, train F loss: -0.3362, acc 0.9646
# epoch 145: train D loss: 0.6345, train F loss: -0.3382, acc 0.9680
# epoch 146: train D loss: 0.6351, train F loss: -0.3399, acc 0.9698
# epoch 147: train D loss: 0.6346, train F loss: -0.3362, acc 0.9684
# epoch 148: train D loss: 0.6385, train F loss: -0.3498, acc 0.9732
# epoch 149: train D loss: 0.6339, train F loss: -0.3331, acc 0.9690
# epoch 150: train D loss: 0.6383, train F loss: -0.3159, acc 0.9628
# epoch 151: train D loss: 0.6350, train F loss: -0.3174, acc 0.9602
# epoch 152: train D loss: 0.6372, train F loss: -0.3071, acc 0.9610
# epoch 153: train D loss: 0.6339, train F loss: -0.3496, acc 0.9720
# epoch 154: train D loss: 0.6306, train F loss: -0.3344, acc 0.9698
# epoch 155: train D loss: 0.6435, train F loss: -0.3489, acc 0.9688
# epoch 156: train D loss: 0.6389, train F loss: -0.3478, acc 0.9704
# epoch 157: train D loss: 0.6363, train F loss: -0.3400, acc 0.9692
# epoch 158: train D loss: 0.6437, train F loss: -0.3550, acc 0.9718
# epoch 159: train D loss: 0.6392, train F loss: -0.3372, acc 0.9704
# epoch 160: train D loss: 0.6387, train F loss: -0.3486, acc 0.9710
# epoch 161: train D loss: 0.6359, train F loss: -0.3616, acc 0.9766
# epoch 162: train D loss: 0.6352, train F loss: -0.3339, acc 0.9680
# epoch 163: train D loss: 0.6318, train F loss: -0.3568, acc 0.9756
# epoch 164: train D loss: 0.6434, train F loss: -0.3482, acc 0.9682
# epoch 165: train D loss: 0.6408, train F loss: -0.3402, acc 0.9670
# epoch 166: train D loss: 0.6439, train F loss: -0.3559, acc 0.9734
# epoch 167: train D loss: 0.6433, train F loss: -0.3387, acc 0.9660
# epoch 168: train D loss: 0.6333, train F loss: -0.3240, acc 0.9646
# epoch 169: train D loss: 0.6392, train F loss: -0.3451, acc 0.9718
# epoch 170: train D loss: 0.6401, train F loss: -0.3524, acc 0.9722
# epoch 171: train D loss: 0.6384, train F loss: -0.3544, acc 0.9746
# epoch 172: train D loss: 0.6311, train F loss: -0.3502, acc 0.9726
# epoch 173: train D loss: 0.6397, train F loss: -0.3493, acc 0.9712
# epoch 174: train D loss: 0.6368, train F loss: -0.3434, acc 0.9700
# epoch 175: train D loss: 0.6429, train F loss: -0.3433, acc 0.9714
# epoch 176: train D loss: 0.6432, train F loss: -0.3527, acc 0.9702
# epoch 177: train D loss: 0.6406, train F loss: -0.3588, acc 0.9730
# epoch 178: train D loss: 0.6285, train F loss: -0.3448, acc 0.9746
# epoch 179: train D loss: 0.6306, train F loss: -0.3394, acc 0.9704
# epoch 180: train D loss: 0.6323, train F loss: -0.3441, acc 0.9718
# epoch 181: train D loss: 0.6323, train F loss: -0.3455, acc 0.9722
# epoch 182: train D loss: 0.6440, train F loss: -0.3686, acc 0.9772
# epoch 183: train D loss: 0.6495, train F loss: -0.3524, acc 0.9708
# epoch 184: train D loss: 0.6418, train F loss: -0.3505, acc 0.9712
# epoch 185: train D loss: 0.6415, train F loss: -0.3610, acc 0.9736
# epoch 186: train D loss: 0.6422, train F loss: -0.3480, acc 0.9716
# epoch 187: train D loss: 0.6418, train F loss: -0.3622, acc 0.9734
# epoch 188: train D loss: 0.6447, train F loss: -0.3616, acc 0.9752
# epoch 189: train D loss: 0.6426, train F loss: -0.3591, acc 0.9720
# epoch 190: train D loss: 0.6501, train F loss: -0.3531, acc 0.9696
# epoch 191: train D loss: 0.6437, train F loss: -0.3621, acc 0.9738
# epoch 192: train D loss: 0.6355, train F loss: -0.3608, acc 0.9774
# epoch 193: train D loss: 0.6451, train F loss: -0.3721, acc 0.9796
# epoch 194: train D loss: 0.6358, train F loss: -0.3582, acc 0.9738
# epoch 195: train D loss: 0.6414, train F loss: -0.3650, acc 0.9780
# epoch 196: train D loss: 0.6374, train F loss: -0.3453, acc 0.9704
# epoch 197: train D loss: 0.6323, train F loss: -0.3510, acc 0.9736
# epoch 198: train D loss: 0.6386, train F loss: -0.3608, acc 0.9732
# epoch 199: train D loss: 0.6449, train F loss: -0.3656, acc 0.9756
# epoch 200: train D loss: 0.6476, train F loss: -0.3689, acc 0.9728
# epoch 201: train D loss: 0.6413, train F loss: -0.3654, acc 0.9750
# epoch 202: train D loss: 0.6428, train F loss: -0.3537, acc 0.9710
# epoch 203: train D loss: 0.6474, train F loss: -0.3769, acc 0.9762
# epoch 204: train D loss: 0.6471, train F loss: -0.3772, acc 0.9764
# epoch 205: train D loss: 0.6484, train F loss: -0.3625, acc 0.9734
# epoch 206: train D loss: 0.6414, train F loss: -0.3642, acc 0.9750
# epoch 207: train D loss: 0.6355, train F loss: -0.3519, acc 0.9726
# epoch 208: train D loss: 0.6500, train F loss: -0.3588, acc 0.9722
# epoch 209: train D loss: 0.6413, train F loss: -0.3670, acc 0.9778
# epoch 210: train D loss: 0.6364, train F loss: -0.3671, acc 0.9786
# epoch 211: train D loss: 0.6438, train F loss: -0.3663, acc 0.9766
# epoch 212: train D loss: 0.6384, train F loss: -0.3610, acc 0.9736
# epoch 213: train D loss: 0.6331, train F loss: -0.3581, acc 0.9806
# epoch 214: train D loss: 0.6521, train F loss: -0.3690, acc 0.9752
# epoch 215: train D loss: 0.6408, train F loss: -0.3769, acc 0.9796
# epoch 216: train D loss: 0.6384, train F loss: -0.3735, acc 0.9796
# epoch 217: train D loss: 0.6434, train F loss: -0.3785, acc 0.9798
# epoch 218: train D loss: 0.6487, train F loss: -0.3743, acc 0.9740
# epoch 219: train D loss: 0.6375, train F loss: -0.3519, acc 0.9734
# epoch 220: train D loss: 0.6501, train F loss: -0.3700, acc 0.9732
# epoch 221: train D loss: 0.6465, train F loss: -0.3787, acc 0.9790
# epoch 222: train D loss: 0.6490, train F loss: -0.3741, acc 0.9772
# epoch 223: train D loss: 0.6443, train F loss: -0.3686, acc 0.9760
# epoch 224: train D loss: 0.6457, train F loss: -0.3592, acc 0.9730
# epoch 225: train D loss: 0.6461, train F loss: -0.3766, acc 0.9788
# epoch 226: train D loss: 0.6434, train F loss: -0.3710, acc 0.9752
# epoch 227: train D loss: 0.6494, train F loss: -0.3755, acc 0.9762
# epoch 228: train D loss: 0.6426, train F loss: -0.3779, acc 0.9776
# epoch 229: train D loss: 0.6430, train F loss: -0.3578, acc 0.9762
# epoch 230: train D loss: 0.6440, train F loss: -0.3750, acc 0.9782
# epoch 231: train D loss: 0.6428, train F loss: -0.3598, acc 0.9754
# epoch 232: train D loss: 0.6455, train F loss: -0.3757, acc 0.9792
# epoch 233: train D loss: 0.6332, train F loss: -0.3693, acc 0.9784
# epoch 234: train D loss: 0.6429, train F loss: -0.3709, acc 0.9784
# epoch 235: train D loss: 0.6447, train F loss: -0.3678, acc 0.9752
# epoch 236: train D loss: 0.6501, train F loss: -0.3875, acc 0.9796
# epoch 237: train D loss: 0.6470, train F loss: -0.3675, acc 0.9750
# epoch 238: train D loss: 0.6407, train F loss: -0.3631, acc 0.9752
# epoch 239: train D loss: 0.6444, train F loss: -0.3668, acc 0.9770
# epoch 240: train D loss: 0.6484, train F loss: -0.3815, acc 0.9796
# epoch 241: train D loss: 0.6377, train F loss: -0.3678, acc 0.9794
# epoch 242: train D loss: 0.6379, train F loss: -0.3815, acc 0.9836
# epoch 243: train D loss: 0.6416, train F loss: -0.3550, acc 0.9724
# epoch 244: train D loss: 0.6490, train F loss: -0.3803, acc 0.9816
# epoch 245: train D loss: 0.6464, train F loss: -0.3793, acc 0.9814
# epoch 246: train D loss: 0.6474, train F loss: -0.3768, acc 0.9776
# epoch 247: train D loss: 0.6463, train F loss: -0.3786, acc 0.9776
# epoch 248: train D loss: 0.6491, train F loss: -0.3842, acc 0.9820
# epoch 249: train D loss: 0.6429, train F loss: -0.3794, acc 0.9810
# epoch 250: train D loss: 0.6437, train F loss: -0.3807, acc 0.9798
# epoch 251: train D loss: 0.6442, train F loss: -0.3761, acc 0.9796
# epoch 252: train D loss: 0.6506, train F loss: -0.3794, acc 0.9794
# epoch 253: train D loss: 0.6463, train F loss: -0.3804, acc 0.9778
# epoch 254: train D loss: 0.6491, train F loss: -0.3593, acc 0.9750
# epoch 255: train D loss: 0.6517, train F loss: -0.3819, acc 0.9802
# epoch 256: train D loss: 0.6480, train F loss: -0.3972, acc 0.9816
# epoch 257: train D loss: 0.6457, train F loss: -0.3660, acc 0.9758
# epoch 258: train D loss: 0.6499, train F loss: -0.3838, acc 0.9766
# epoch 259: train D loss: 0.6445, train F loss: -0.3738, acc 0.9794
# epoch 260: train D loss: 0.6430, train F loss: -0.3658, acc 0.9758
# epoch 261: train D loss: 0.6454, train F loss: -0.3718, acc 0.9760
# epoch 262: train D loss: 0.6418, train F loss: -0.3819, acc 0.9830
# epoch 263: train D loss: 0.6471, train F loss: -0.3730, acc 0.9774
# epoch 264: train D loss: 0.6513, train F loss: -0.3843, acc 0.9786
# epoch 265: train D loss: 0.6467, train F loss: -0.3806, acc 0.9792
# epoch 266: train D loss: 0.6437, train F loss: -0.3839, acc 0.9796
# epoch 267: train D loss: 0.6476, train F loss: -0.3687, acc 0.9774
# epoch 268: train D loss: 0.6525, train F loss: -0.3974, acc 0.9822
# epoch 269: train D loss: 0.6440, train F loss: -0.3768, acc 0.9800
# epoch 270: train D loss: 0.6470, train F loss: -0.3768, acc 0.9784
# epoch 271: train D loss: 0.6532, train F loss: -0.3858, acc 0.9772
# epoch 272: train D loss: 0.6469, train F loss: -0.3895, acc 0.9822
# epoch 273: train D loss: 0.6401, train F loss: -0.3775, acc 0.9808
# epoch 274: train D loss: 0.6434, train F loss: -0.3728, acc 0.9778
# epoch 275: train D loss: 0.6480, train F loss: -0.3805, acc 0.9804
# epoch 276: train D loss: 0.6495, train F loss: -0.3945, acc 0.9844
# epoch 277: train D loss: 0.6467, train F loss: -0.3647, acc 0.9728
# epoch 278: train D loss: 0.6511, train F loss: -0.3847, acc 0.9792
# epoch 279: train D loss: 0.6518, train F loss: -0.3906, acc 0.9816
# epoch 280: train D loss: 0.6500, train F loss: -0.3805, acc 0.9778
# epoch 281: train D loss: 0.6507, train F loss: -0.3826, acc 0.9840
# epoch 282: train D loss: 0.6500, train F loss: -0.3642, acc 0.9726
# epoch 283: train D loss: 0.6485, train F loss: -0.3845, acc 0.9788
# epoch 284: train D loss: 0.6457, train F loss: -0.3730, acc 0.9790
# epoch 285: train D loss: 0.6437, train F loss: -0.3783, acc 0.9810
# epoch 286: train D loss: 0.6504, train F loss: -0.3989, acc 0.9838
# epoch 287: train D loss: 0.6464, train F loss: -0.3814, acc 0.9790
# epoch 288: train D loss: 0.6503, train F loss: -0.3894, acc 0.9808
# epoch 289: train D loss: 0.6414, train F loss: -0.3777, acc 0.9808
# epoch 290: train D loss: 0.6491, train F loss: -0.3881, acc 0.9820
# epoch 291: train D loss: 0.6503, train F loss: -0.3863, acc 0.9816
# epoch 292: train D loss: 0.6547, train F loss: -0.3946, acc 0.9826
# epoch 293: train D loss: 0.6534, train F loss: -0.3909, acc 0.9794
# epoch 294: train D loss: 0.6497, train F loss: -0.3917, acc 0.9814
# epoch 295: train D loss: 0.6434, train F loss: -0.3867, acc 0.9830
# epoch 296: train D loss: 0.6464, train F loss: -0.3846, acc 0.9814
# epoch 297: train D loss: 0.6590, train F loss: -0.3965, acc 0.9816
# epoch 298: train D loss: 0.6533, train F loss: -0.3910, acc 0.9796
# epoch 299: train D loss: 0.6482, train F loss: -0.3749, acc 0.9790
# epoch 300: train D loss: 0.6540, train F loss: -0.3892, acc 0.9816
# epoch 301: train D loss: 0.6511, train F loss: -0.3933, acc 0.9818
# epoch 302: train D loss: 0.6405, train F loss: -0.3780, acc 0.9804
# epoch 303: train D loss: 0.6465, train F loss: -0.3808, acc 0.9814
# epoch 304: train D loss: 0.6454, train F loss: -0.3724, acc 0.9806
# epoch 305: train D loss: 0.6461, train F loss: -0.3752, acc 0.9798
# epoch 306: train D loss: 0.6453, train F loss: -0.3968, acc 0.9862
# epoch 307: train D loss: 0.6501, train F loss: -0.3813, acc 0.9812
# epoch 308: train D loss: 0.6489, train F loss: -0.3891, acc 0.9828
# epoch 309: train D loss: 0.6475, train F loss: -0.3850, acc 0.9790
# epoch 310: train D loss: 0.6513, train F loss: -0.3811, acc 0.9770
# epoch 311: train D loss: 0.6525, train F loss: -0.4040, acc 0.9868
# epoch 312: train D loss: 0.6457, train F loss: -0.3881, acc 0.9824
# epoch 313: train D loss: 0.6519, train F loss: -0.3932, acc 0.9836
# epoch 314: train D loss: 0.6474, train F loss: -0.3840, acc 0.9792
# epoch 315: train D loss: 0.6572, train F loss: -0.3835, acc 0.9770
# epoch 316: train D loss: 0.6454, train F loss: -0.3925, acc 0.9846
# epoch 317: train D loss: 0.6515, train F loss: -0.3892, acc 0.9826
# epoch 318: train D loss: 0.6479, train F loss: -0.3943, acc 0.9820
# epoch 319: train D loss: 0.6538, train F loss: -0.3919, acc 0.9816
# epoch 320: train D loss: 0.6509, train F loss: -0.3940, acc 0.9820
# epoch 321: train D loss: 0.6569, train F loss: -0.3925, acc 0.9800
# epoch 322: train D loss: 0.6548, train F loss: -0.3846, acc 0.9788
# epoch 323: train D loss: 0.6447, train F loss: -0.3910, acc 0.9832
# epoch 324: train D loss: 0.6447, train F loss: -0.3891, acc 0.9822
# epoch 325: train D loss: 0.6454, train F loss: -0.3906, acc 0.9802
# epoch 326: train D loss: 0.6411, train F loss: -0.3795, acc 0.9808
# epoch 327: train D loss: 0.6546, train F loss: -0.3882, acc 0.9818
# epoch 328: train D loss: 0.6503, train F loss: -0.3913, acc 0.9814
# epoch 329: train D loss: 0.6413, train F loss: -0.3920, acc 0.9836
# epoch 330: train D loss: 0.6474, train F loss: -0.4002, acc 0.9858
# epoch 331: train D loss: 0.6557, train F loss: -0.3950, acc 0.9808
# epoch 332: train D loss: 0.6502, train F loss: -0.3695, acc 0.9750
# epoch 333: train D loss: 0.6460, train F loss: -0.3917, acc 0.9844
# epoch 334: train D loss: 0.6505, train F loss: -0.3787, acc 0.9764
# epoch 335: train D loss: 0.6373, train F loss: -0.3785, acc 0.9808
# epoch 336: train D loss: 0.6496, train F loss: -0.3854, acc 0.9802
# epoch 337: train D loss: 0.6528, train F loss: -0.3908, acc 0.9814
# epoch 338: train D loss: 0.6430, train F loss: -0.3924, acc 0.9832
# epoch 339: train D loss: 0.6498, train F loss: -0.3922, acc 0.9822
# epoch 340: train D loss: 0.6451, train F loss: -0.3862, acc 0.9812
# epoch 341: train D loss: 0.6473, train F loss: -0.3949, acc 0.9850
# epoch 342: train D loss: 0.6534, train F loss: -0.3937, acc 0.9826
# epoch 343: train D loss: 0.6518, train F loss: -0.3940, acc 0.9808
# epoch 344: train D loss: 0.6513, train F loss: -0.3893, acc 0.9820
# epoch 345: train D loss: 0.6540, train F loss: -0.3996, acc 0.9842
# epoch 346: train D loss: 0.6379, train F loss: -0.3822, acc 0.9802
# epoch 347: train D loss: 0.6442, train F loss: -0.3806, acc 0.9804
# epoch 348: train D loss: 0.6531, train F loss: -0.3924, acc 0.9828
# epoch 349: train D loss: 0.6503, train F loss: -0.3943, acc 0.9828
# epoch 350: train D loss: 0.6600, train F loss: -0.3993, acc 0.9830
# epoch 351: train D loss: 0.6565, train F loss: -0.4007, acc 0.9842
# epoch 352: train D loss: 0.6519, train F loss: -0.3964, acc 0.9842
# epoch 353: train D loss: 0.6534, train F loss: -0.3860, acc 0.9784
# epoch 354: train D loss: 0.6533, train F loss: -0.3918, acc 0.9820
# epoch 355: train D loss: 0.6485, train F loss: -0.3891, acc 0.9822
# epoch 356: train D loss: 0.6495, train F loss: -0.3809, acc 0.9798
# epoch 357: train D loss: 0.6404, train F loss: -0.3758, acc 0.9812
# epoch 358: train D loss: 0.6490, train F loss: -0.3928, acc 0.9840
# epoch 359: train D loss: 0.6470, train F loss: -0.3969, acc 0.9850
# epoch 360: train D loss: 0.6502, train F loss: -0.3970, acc 0.9832
# epoch 361: train D loss: 0.6519, train F loss: -0.3966, acc 0.9832
# epoch 362: train D loss: 0.6477, train F loss: -0.4020, acc 0.9844
# epoch 363: train D loss: 0.6509, train F loss: -0.3976, acc 0.9840
# epoch 364: train D loss: 0.6495, train F loss: -0.3853, acc 0.9818
# epoch 365: train D loss: 0.6524, train F loss: -0.3973, acc 0.9830
# epoch 366: train D loss: 0.6478, train F loss: -0.3888, acc 0.9830
# epoch 367: train D loss: 0.6488, train F loss: -0.4034, acc 0.9860
# epoch 368: train D loss: 0.6431, train F loss: -0.3808, acc 0.9808
# epoch 369: train D loss: 0.6511, train F loss: -0.3882, acc 0.9830
# epoch 370: train D loss: 0.6493, train F loss: -0.4004, acc 0.9836
# epoch 371: train D loss: 0.6563, train F loss: -0.3931, acc 0.9804
# epoch 372: train D loss: 0.6517, train F loss: -0.3967, acc 0.9830
# epoch 373: train D loss: 0.6479, train F loss: -0.3856, acc 0.9838
# epoch 374: train D loss: 0.6480, train F loss: -0.3920, acc 0.9830
# epoch 375: train D loss: 0.6426, train F loss: -0.3988, acc 0.9866
# epoch 376: train D loss: 0.6616, train F loss: -0.4080, acc 0.9834
# epoch 377: train D loss: 0.6469, train F loss: -0.3941, acc 0.9836
# epoch 378: train D loss: 0.6551, train F loss: -0.3956, acc 0.9844
# epoch 379: train D loss: 0.6491, train F loss: -0.3955, acc 0.9814
# epoch 380: train D loss: 0.6447, train F loss: -0.3921, acc 0.9850
# epoch 381: train D loss: 0.6528, train F loss: -0.3860, acc 0.9834
# epoch 382: train D loss: 0.6476, train F loss: -0.3994, acc 0.9864
# epoch 383: train D loss: 0.6502, train F loss: -0.3958, acc 0.9824
# epoch 384: train D loss: 0.6435, train F loss: -0.3890, acc 0.9848
# epoch 385: train D loss: 0.6522, train F loss: -0.3892, acc 0.9822
# epoch 386: train D loss: 0.6548, train F loss: -0.3994, acc 0.9852
# epoch 387: train D loss: 0.6489, train F loss: -0.4022, acc 0.9842
# epoch 388: train D loss: 0.6546, train F loss: -0.3983, acc 0.9830
# epoch 389: train D loss: 0.6558, train F loss: -0.3843, acc 0.9798
# epoch 390: train D loss: 0.6471, train F loss: -0.3965, acc 0.9852
# epoch 391: train D loss: 0.6439, train F loss: -0.3898, acc 0.9820
# epoch 392: train D loss: 0.6462, train F loss: -0.3981, acc 0.9854
# epoch 393: train D loss: 0.6578, train F loss: -0.3970, acc 0.9854
# epoch 394: train D loss: 0.6561, train F loss: -0.3980, acc 0.9840
# epoch 395: train D loss: 0.6477, train F loss: -0.3957, acc 0.9850
# epoch 396: train D loss: 0.6474, train F loss: -0.3868, acc 0.9822
# epoch 397: train D loss: 0.6580, train F loss: -0.4002, acc 0.9838
# epoch 398: train D loss: 0.6486, train F loss: -0.3987, acc 0.9842
# epoch 399: train D loss: 0.6546, train F loss: -0.4077, acc 0.9872
# epoch 400: train D loss: 0.6581, train F loss: -0.3935, acc 0.9822
# epoch 401: train D loss: 0.6529, train F loss: -0.4073, acc 0.9874
# epoch 402: train D loss: 0.6473, train F loss: -0.4057, acc 0.9876
# epoch 403: train D loss: 0.6486, train F loss: -0.3982, acc 0.9838
# epoch 404: train D loss: 0.6497, train F loss: -0.3954, acc 0.9850
# epoch 405: train D loss: 0.6515, train F loss: -0.3895, acc 0.9856
# epoch 406: train D loss: 0.6501, train F loss: -0.3918, acc 0.9836
# epoch 407: train D loss: 0.6490, train F loss: -0.3899, acc 0.9830
# epoch 408: train D loss: 0.6474, train F loss: -0.4022, acc 0.9862
# epoch 409: train D loss: 0.6500, train F loss: -0.3951, acc 0.9838
# epoch 410: train D loss: 0.6482, train F loss: -0.3987, acc 0.9842
# epoch 411: train D loss: 0.6510, train F loss: -0.3904, acc 0.9842
# epoch 412: train D loss: 0.6454, train F loss: -0.3946, acc 0.9836
# epoch 413: train D loss: 0.6565, train F loss: -0.4047, acc 0.9866
# epoch 414: train D loss: 0.6527, train F loss: -0.4070, acc 0.9852
# epoch 415: train D loss: 0.6543, train F loss: -0.3986, acc 0.9842
# epoch 416: train D loss: 0.6552, train F loss: -0.4067, acc 0.9852
# epoch 417: train D loss: 0.6567, train F loss: -0.3959, acc 0.9818
# epoch 418: train D loss: 0.6477, train F loss: -0.4000, acc 0.9848
# epoch 419: train D loss: 0.6570, train F loss: -0.4054, acc 0.9854
# epoch 420: train D loss: 0.6484, train F loss: -0.4020, acc 0.9844
# epoch 421: train D loss: 0.6534, train F loss: -0.3984, acc 0.9846
# epoch 422: train D loss: 0.6534, train F loss: -0.4099, acc 0.9866
# epoch 423: train D loss: 0.6576, train F loss: -0.4054, acc 0.9846
# epoch 424: train D loss: 0.6508, train F loss: -0.3973, acc 0.9838
# epoch 425: train D loss: 0.6514, train F loss: -0.4043, acc 0.9872
# epoch 426: train D loss: 0.6537, train F loss: -0.3763, acc 0.9788
# epoch 427: train D loss: 0.6505, train F loss: -0.3880, acc 0.9814
# epoch 428: train D loss: 0.6499, train F loss: -0.4017, acc 0.9868
# epoch 429: train D loss: 0.6550, train F loss: -0.4075, acc 0.9860
# epoch 430: train D loss: 0.6517, train F loss: -0.4083, acc 0.9868
# epoch 431: train D loss: 0.6632, train F loss: -0.3921, acc 0.9810
# epoch 432: train D loss: 0.6548, train F loss: -0.4049, acc 0.9858
# epoch 433: train D loss: 0.6518, train F loss: -0.3998, acc 0.9840
# epoch 434: train D loss: 0.6557, train F loss: -0.4038, acc 0.9850
# epoch 435: train D loss: 0.6508, train F loss: -0.3956, acc 0.9830
# epoch 436: train D loss: 0.6477, train F loss: -0.3850, acc 0.9840
# epoch 437: train D loss: 0.6603, train F loss: -0.4081, acc 0.9856
# epoch 438: train D loss: 0.6591, train F loss: -0.4051, acc 0.9842
# epoch 439: train D loss: 0.6547, train F loss: -0.4057, acc 0.9854
# epoch 440: train D loss: 0.6527, train F loss: -0.4104, acc 0.9872
# epoch 441: train D loss: 0.6490, train F loss: -0.3949, acc 0.9852
# epoch 442: train D loss: 0.6433, train F loss: -0.3928, acc 0.9858
# epoch 443: train D loss: 0.6471, train F loss: -0.3980, acc 0.9848
# epoch 444: train D loss: 0.6459, train F loss: -0.4019, acc 0.9876
# epoch 445: train D loss: 0.6615, train F loss: -0.4139, acc 0.9882
# epoch 446: train D loss: 0.6520, train F loss: -0.4036, acc 0.9858
# epoch 447: train D loss: 0.6517, train F loss: -0.4067, acc 0.9872
# epoch 448: train D loss: 0.6520, train F loss: -0.4116, acc 0.9878
# epoch 449: train D loss: 0.6555, train F loss: -0.3973, acc 0.9824
# epoch 450: train D loss: 0.6525, train F loss: -0.4024, acc 0.9858
# epoch 451: train D loss: 0.6502, train F loss: -0.3909, acc 0.9826
# epoch 452: train D loss: 0.6531, train F loss: -0.3935, acc 0.9818
# epoch 453: train D loss: 0.6501, train F loss: -0.4048, acc 0.9870
# epoch 454: train D loss: 0.6514, train F loss: -0.4023, acc 0.9862
# epoch 455: train D loss: 0.6563, train F loss: -0.4024, acc 0.9860
# epoch 456: train D loss: 0.6534, train F loss: -0.3986, acc 0.9852
# epoch 457: train D loss: 0.6578, train F loss: -0.4058, acc 0.9850
# epoch 458: train D loss: 0.6475, train F loss: -0.4010, acc 0.9858
# epoch 459: train D loss: 0.6570, train F loss: -0.4167, acc 0.9870
# epoch 460: train D loss: 0.6556, train F loss: -0.4082, acc 0.9888
# epoch 461: train D loss: 0.6522, train F loss: -0.3958, acc 0.9866
# epoch 462: train D loss: 0.6497, train F loss: -0.4082, acc 0.9892
# epoch 463: train D loss: 0.6509, train F loss: -0.3883, acc 0.9802
# epoch 464: train D loss: 0.6511, train F loss: -0.4018, acc 0.9860
# epoch 465: train D loss: 0.6535, train F loss: -0.4084, acc 0.9862
# epoch 466: train D loss: 0.6458, train F loss: -0.3897, acc 0.9828
# epoch 467: train D loss: 0.6591, train F loss: -0.4098, acc 0.9854
# epoch 468: train D loss: 0.6568, train F loss: -0.4104, acc 0.9874
# epoch 469: train D loss: 0.6468, train F loss: -0.3856, acc 0.9824
# epoch 470: train D loss: 0.6514, train F loss: -0.3985, acc 0.9840
# epoch 471: train D loss: 0.6453, train F loss: -0.3955, acc 0.9854
# epoch 472: train D loss: 0.6481, train F loss: -0.4093, acc 0.9878
# epoch 473: train D loss: 0.6574, train F loss: -0.4045, acc 0.9850
# epoch 474: train D loss: 0.6512, train F loss: -0.3861, acc 0.9796
# epoch 475: train D loss: 0.6501, train F loss: -0.4024, acc 0.9862
# epoch 476: train D loss: 0.6526, train F loss: -0.4103, acc 0.9876
# epoch 477: train D loss: 0.6603, train F loss: -0.4096, acc 0.9860
# epoch 478: train D loss: 0.6517, train F loss: -0.4085, acc 0.9866
# epoch 479: train D loss: 0.6482, train F loss: -0.3963, acc 0.9854
# epoch 480: train D loss: 0.6536, train F loss: -0.3970, acc 0.9838
# epoch 481: train D loss: 0.6577, train F loss: -0.4080, acc 0.9864
# epoch 482: train D loss: 0.6493, train F loss: -0.3974, acc 0.9862
# epoch 483: train D loss: 0.6525, train F loss: -0.3978, acc 0.9854
# epoch 484: train D loss: 0.6553, train F loss: -0.3957, acc 0.9838
# epoch 485: train D loss: 0.6473, train F loss: -0.4016, acc 0.9878
# epoch 486: train D loss: 0.6508, train F loss: -0.4039, acc 0.9862
# epoch 487: train D loss: 0.6500, train F loss: -0.4082, acc 0.9880
# epoch 488: train D loss: 0.6522, train F loss: -0.4062, acc 0.9878
# epoch 489: train D loss: 0.6517, train F loss: -0.3991, acc 0.9848
# epoch 490: train D loss: 0.6510, train F loss: -0.4057, acc 0.9854
# epoch 491: train D loss: 0.6584, train F loss: -0.4103, acc 0.9858
# epoch 492: train D loss: 0.6584, train F loss: -0.3930, acc 0.9808
# epoch 493: train D loss: 0.6533, train F loss: -0.4103, acc 0.9868
# epoch 494: train D loss: 0.6484, train F loss: -0.4023, acc 0.9864
# epoch 495: train D loss: 0.6483, train F loss: -0.3946, acc 0.9836
# epoch 496: train D loss: 0.6509, train F loss: -0.4045, acc 0.9864
# epoch 497: train D loss: 0.6590, train F loss: -0.4041, acc 0.9854
# epoch 498: train D loss: 0.6573, train F loss: -0.4187, acc 0.9886
# epoch 499: train D loss: 0.6503, train F loss: -0.4041, acc 0.9872
# epoch 500: train D loss: 0.6581, train F loss: -0.4065, acc 0.9866
# epoch 501: train D loss: 0.6508, train F loss: -0.4068, acc 0.9866
# epoch 502: train D loss: 0.6512, train F loss: -0.4007, acc 0.9854
# epoch 503: train D loss: 0.6540, train F loss: -0.4015, acc 0.9838
# epoch 504: train D loss: 0.6600, train F loss: -0.4137, acc 0.9868
# epoch 505: train D loss: 0.6572, train F loss: -0.4128, acc 0.9862
# epoch 506: train D loss: 0.6534, train F loss: -0.4061, acc 0.9856
# epoch 507: train D loss: 0.6516, train F loss: -0.3985, acc 0.9848
# epoch 508: train D loss: 0.6550, train F loss: -0.4107, acc 0.9864
# epoch 509: train D loss: 0.6503, train F loss: -0.4035, acc 0.9862
# epoch 510: train D loss: 0.6571, train F loss: -0.4038, acc 0.9830
# epoch 511: train D loss: 0.6540, train F loss: -0.3966, acc 0.9828
# epoch 512: train D loss: 0.6576, train F loss: -0.3955, acc 0.9824
# epoch 513: train D loss: 0.6490, train F loss: -0.3978, acc 0.9840
# epoch 514: train D loss: 0.6515, train F loss: -0.4095, acc 0.9862
# epoch 515: train D loss: 0.6528, train F loss: -0.4045, acc 0.9858
# epoch 516: train D loss: 0.6514, train F loss: -0.4053, acc 0.9862
# epoch 517: train D loss: 0.6443, train F loss: -0.4055, acc 0.9882
# epoch 518: train D loss: 0.6592, train F loss: -0.4185, acc 0.9886
# epoch 519: train D loss: 0.6561, train F loss: -0.4152, acc 0.9868
# epoch 520: train D loss: 0.6585, train F loss: -0.4161, acc 0.9866
# epoch 521: train D loss: 0.6631, train F loss: -0.4122, acc 0.9846
# epoch 522: train D loss: 0.6563, train F loss: -0.4101, acc 0.9854
# epoch 523: train D loss: 0.6469, train F loss: -0.3949, acc 0.9854
# epoch 524: train D loss: 0.6555, train F loss: -0.4133, acc 0.9884
# epoch 525: train D loss: 0.6555, train F loss: -0.4064, acc 0.9850
# epoch 526: train D loss: 0.6555, train F loss: -0.4080, acc 0.9862
# epoch 527: train D loss: 0.6517, train F loss: -0.4018, acc 0.9862
# epoch 528: train D loss: 0.6493, train F loss: -0.4053, acc 0.9862
# epoch 529: train D loss: 0.6475, train F loss: -0.4047, acc 0.9880
# epoch 530: train D loss: 0.6546, train F loss: -0.4127, acc 0.9886
# epoch 531: train D loss: 0.6509, train F loss: -0.4034, acc 0.9878
# epoch 532: train D loss: 0.6549, train F loss: -0.4023, acc 0.9846
# epoch 533: train D loss: 0.6548, train F loss: -0.3907, acc 0.9834
# epoch 534: train D loss: 0.6483, train F loss: -0.4094, acc 0.9884
# epoch 535: train D loss: 0.6510, train F loss: -0.4047, acc 0.9864
# epoch 536: train D loss: 0.6528, train F loss: -0.4020, acc 0.9856
# epoch 537: train D loss: 0.6523, train F loss: -0.4126, acc 0.9898
# epoch 538: train D loss: 0.6494, train F loss: -0.4100, acc 0.9878
# epoch 539: train D loss: 0.6483, train F loss: -0.3998, acc 0.9866
# epoch 540: train D loss: 0.6539, train F loss: -0.4043, acc 0.9842
# epoch 541: train D loss: 0.6602, train F loss: -0.4108, acc 0.9868
# epoch 542: train D loss: 0.6568, train F loss: -0.3998, acc 0.9836
# epoch 543: train D loss: 0.6536, train F loss: -0.4122, acc 0.9874
# epoch 544: train D loss: 0.6545, train F loss: -0.4186, acc 0.9896
# epoch 545: train D loss: 0.6529, train F loss: -0.4097, acc 0.9868
# epoch 546: train D loss: 0.6508, train F loss: -0.3968, acc 0.9852
# epoch 547: train D loss: 0.6489, train F loss: -0.3992, acc 0.9854
# epoch 548: train D loss: 0.6551, train F loss: -0.4149, acc 0.9882
# epoch 549: train D loss: 0.6537, train F loss: -0.4085, acc 0.9868
# epoch 550: train D loss: 0.6546, train F loss: -0.4186, acc 0.9878
# epoch 551: train D loss: 0.6495, train F loss: -0.4077, acc 0.9880
# epoch 552: train D loss: 0.6539, train F loss: -0.4045, acc 0.9860
# epoch 553: train D loss: 0.6542, train F loss: -0.4131, acc 0.9878
# epoch 554: train D loss: 0.6603, train F loss: -0.4152, acc 0.9872
# epoch 555: train D loss: 0.6531, train F loss: -0.3933, acc 0.9854
# epoch 556: train D loss: 0.6469, train F loss: -0.3951, acc 0.9852
# epoch 557: train D loss: 0.6493, train F loss: -0.4137, acc 0.9890
# epoch 558: train D loss: 0.6537, train F loss: -0.3986, acc 0.9840
# epoch 559: train D loss: 0.6473, train F loss: -0.4022, acc 0.9858
# epoch 560: train D loss: 0.6506, train F loss: -0.4056, acc 0.9864
# epoch 561: train D loss: 0.6539, train F loss: -0.4142, acc 0.9886
# epoch 562: train D loss: 0.6500, train F loss: -0.4147, acc 0.9884
# epoch 563: train D loss: 0.6555, train F loss: -0.4159, acc 0.9870
# epoch 564: train D loss: 0.6537, train F loss: -0.4022, acc 0.9858
# epoch 565: train D loss: 0.6551, train F loss: -0.4187, acc 0.9880
# epoch 566: train D loss: 0.6525, train F loss: -0.3909, acc 0.9818
# epoch 567: train D loss: 0.6573, train F loss: -0.4067, acc 0.9868
# epoch 568: train D loss: 0.6516, train F loss: -0.4042, acc 0.9870
# epoch 569: train D loss: 0.6500, train F loss: -0.4109, acc 0.9882
# epoch 570: train D loss: 0.6522, train F loss: -0.3954, acc 0.9854
# epoch 571: train D loss: 0.6527, train F loss: -0.4044, acc 0.9856
# epoch 572: train D loss: 0.6542, train F loss: -0.4105, acc 0.9882
# epoch 573: train D loss: 0.6535, train F loss: -0.4090, acc 0.9874
# epoch 574: train D loss: 0.6517, train F loss: -0.4138, acc 0.9898
# epoch 575: train D loss: 0.6493, train F loss: -0.4157, acc 0.9898
# epoch 576: train D loss: 0.6555, train F loss: -0.4188, acc 0.9900
# epoch 577: train D loss: 0.6555, train F loss: -0.4134, acc 0.9882
# epoch 578: train D loss: 0.6622, train F loss: -0.4069, acc 0.9856
# epoch 579: train D loss: 0.6525, train F loss: -0.4012, acc 0.9866
# epoch 580: train D loss: 0.6524, train F loss: -0.4042, acc 0.9860
# epoch 581: train D loss: 0.6609, train F loss: -0.4162, acc 0.9858
# epoch 582: train D loss: 0.6555, train F loss: -0.4157, acc 0.9894
# epoch 583: train D loss: 0.6525, train F loss: -0.3959, acc 0.9854
# epoch 584: train D loss: 0.6605, train F loss: -0.4161, acc 0.9884
# epoch 585: train D loss: 0.6554, train F loss: -0.4130, acc 0.9856
# epoch 586: train D loss: 0.6538, train F loss: -0.4101, acc 0.9872
# epoch 587: train D loss: 0.6471, train F loss: -0.3991, acc 0.9870
# epoch 588: train D loss: 0.6545, train F loss: -0.4119, acc 0.9892
# epoch 589: train D loss: 0.6572, train F loss: -0.4140, acc 0.9876
# epoch 590: train D loss: 0.6580, train F loss: -0.4174, acc 0.9874
# epoch 591: train D loss: 0.6575, train F loss: -0.4209, acc 0.9890
# epoch 592: train D loss: 0.6553, train F loss: -0.4131, acc 0.9868
# epoch 593: train D loss: 0.6614, train F loss: -0.4125, acc 0.9852
# epoch 594: train D loss: 0.6566, train F loss: -0.4137, acc 0.9864
# epoch 595: train D loss: 0.6501, train F loss: -0.3999, acc 0.9866
# epoch 596: train D loss: 0.6590, train F loss: -0.4042, acc 0.9868
# epoch 597: train D loss: 0.6531, train F loss: -0.4078, acc 0.9878
# epoch 598: train D loss: 0.6556, train F loss: -0.4210, acc 0.9904
# epoch 599: train D loss: 0.6555, train F loss: -0.4047, acc 0.9860
# epoch 600: train D loss: 0.6532, train F loss: -0.4042, acc 0.9848
# epoch 601: train D loss: 0.6516, train F loss: -0.4093, acc 0.9872
# epoch 602: train D loss: 0.6521, train F loss: -0.4129, acc 0.9884
# epoch 603: train D loss: 0.6533, train F loss: -0.4076, acc 0.9856
# epoch 604: train D loss: 0.6516, train F loss: -0.3987, acc 0.9866
# epoch 605: train D loss: 0.6512, train F loss: -0.4148, acc 0.9890
# epoch 606: train D loss: 0.6551, train F loss: -0.4140, acc 0.9886
# epoch 607: train D loss: 0.6538, train F loss: -0.4110, acc 0.9872
# epoch 608: train D loss: 0.6537, train F loss: -0.4081, acc 0.9862
# epoch 609: train D loss: 0.6599, train F loss: -0.4099, acc 0.9870
# epoch 610: train D loss: 0.6548, train F loss: -0.4217, acc 0.9890
# epoch 611: train D loss: 0.6516, train F loss: -0.4199, acc 0.9904
# epoch 612: train D loss: 0.6494, train F loss: -0.4080, acc 0.9874
# epoch 613: train D loss: 0.6498, train F loss: -0.4029, acc 0.9876
# epoch 614: train D loss: 0.6481, train F loss: -0.4067, acc 0.9882
# epoch 615: train D loss: 0.6537, train F loss: -0.3958, acc 0.9816
# epoch 616: train D loss: 0.6577, train F loss: -0.4099, acc 0.9856
# epoch 617: train D loss: 0.6546, train F loss: -0.4018, acc 0.9858
# epoch 618: train D loss: 0.6581, train F loss: -0.4121, acc 0.9872
# epoch 619: train D loss: 0.6575, train F loss: -0.4264, acc 0.9910
# epoch 620: train D loss: 0.6557, train F loss: -0.4102, acc 0.9866
# epoch 621: train D loss: 0.6543, train F loss: -0.4112, acc 0.9866
# epoch 622: train D loss: 0.6523, train F loss: -0.4089, acc 0.9868
# epoch 623: train D loss: 0.6542, train F loss: -0.4089, acc 0.9870
# epoch 624: train D loss: 0.6553, train F loss: -0.4114, acc 0.9876
# epoch 625: train D loss: 0.6553, train F loss: -0.3983, acc 0.9844
# epoch 626: train D loss: 0.6582, train F loss: -0.4124, acc 0.9874
# epoch 627: train D loss: 0.6552, train F loss: -0.4157, acc 0.9872
# epoch 628: train D loss: 0.6434, train F loss: -0.4012, acc 0.9882
# epoch 629: train D loss: 0.6517, train F loss: -0.4073, acc 0.9882
# epoch 630: train D loss: 0.6466, train F loss: -0.4148, acc 0.9900
# epoch 631: train D loss: 0.6566, train F loss: -0.4135, acc 0.9866
# epoch 632: train D loss: 0.6561, train F loss: -0.4108, acc 0.9878
# epoch 633: train D loss: 0.6549, train F loss: -0.4071, acc 0.9866
# epoch 634: train D loss: 0.6561, train F loss: -0.4133, acc 0.9878
# epoch 635: train D loss: 0.6503, train F loss: -0.3953, acc 0.9856
# epoch 636: train D loss: 0.6537, train F loss: -0.4133, acc 0.9868
# epoch 637: train D loss: 0.6576, train F loss: -0.4046, acc 0.9848
# epoch 638: train D loss: 0.6559, train F loss: -0.4128, acc 0.9876
# epoch 639: train D loss: 0.6581, train F loss: -0.4195, acc 0.9890
# epoch 640: train D loss: 0.6578, train F loss: -0.4134, acc 0.9870
# epoch 641: train D loss: 0.6491, train F loss: -0.4118, acc 0.9884
# epoch 642: train D loss: 0.6572, train F loss: -0.4172, acc 0.9888
# epoch 643: train D loss: 0.6484, train F loss: -0.4052, acc 0.9868
# epoch 644: train D loss: 0.6530, train F loss: -0.4105, acc 0.9882
# epoch 645: train D loss: 0.6532, train F loss: -0.4143, acc 0.9888
# epoch 646: train D loss: 0.6500, train F loss: -0.4056, acc 0.9866
# epoch 647: train D loss: 0.6577, train F loss: -0.4128, acc 0.9880
# epoch 648: train D loss: 0.6547, train F loss: -0.4161, acc 0.9894
# epoch 649: train D loss: 0.6589, train F loss: -0.4143, acc 0.9864
# epoch 650: train D loss: 0.6535, train F loss: -0.4114, acc 0.9866
# epoch 651: train D loss: 0.6601, train F loss: -0.4140, acc 0.9886
# epoch 652: train D loss: 0.6580, train F loss: -0.4075, acc 0.9854
# epoch 653: train D loss: 0.6589, train F loss: -0.4110, acc 0.9872
# epoch 654: train D loss: 0.6516, train F loss: -0.4141, acc 0.9884
# epoch 655: train D loss: 0.6550, train F loss: -0.4162, acc 0.9888
# epoch 656: train D loss: 0.6570, train F loss: -0.4188, acc 0.9890
# epoch 657: train D loss: 0.6588, train F loss: -0.4066, acc 0.9852
# epoch 658: train D loss: 0.6597, train F loss: -0.4072, acc 0.9854
# epoch 659: train D loss: 0.6573, train F loss: -0.4071, acc 0.9850
# epoch 660: train D loss: 0.6519, train F loss: -0.4059, acc 0.9870
# epoch 661: train D loss: 0.6526, train F loss: -0.4167, acc 0.9890
# epoch 662: train D loss: 0.6541, train F loss: -0.4121, acc 0.9886
# epoch 663: train D loss: 0.6588, train F loss: -0.4075, acc 0.9894
# epoch 664: train D loss: 0.6592, train F loss: -0.4160, acc 0.9888
# epoch 665: train D loss: 0.6546, train F loss: -0.4159, acc 0.9882
# epoch 666: train D loss: 0.6556, train F loss: -0.4081, acc 0.9852
# epoch 667: train D loss: 0.6558, train F loss: -0.4129, acc 0.9886
# epoch 668: train D loss: 0.6605, train F loss: -0.4166, acc 0.9862
# epoch 669: train D loss: 0.6489, train F loss: -0.4091, acc 0.9890
# epoch 670: train D loss: 0.6506, train F loss: -0.4124, acc 0.9896
# epoch 671: train D loss: 0.6542, train F loss: -0.4104, acc 0.9876
# epoch 672: train D loss: 0.6505, train F loss: -0.4134, acc 0.9900
# epoch 673: train D loss: 0.6560, train F loss: -0.4193, acc 0.9894
# epoch 674: train D loss: 0.6563, train F loss: -0.4214, acc 0.9898
# epoch 675: train D loss: 0.6564, train F loss: -0.4161, acc 0.9878
# epoch 676: train D loss: 0.6536, train F loss: -0.4202, acc 0.9896
# epoch 677: train D loss: 0.6569, train F loss: -0.4206, acc 0.9900
# epoch 678: train D loss: 0.6567, train F loss: -0.4064, acc 0.9848
# epoch 679: train D loss: 0.6628, train F loss: -0.4160, acc 0.9860
# epoch 680: train D loss: 0.6520, train F loss: -0.4010, acc 0.9870
# epoch 681: train D loss: 0.6526, train F loss: -0.3958, acc 0.9844
# epoch 682: train D loss: 0.6545, train F loss: -0.4219, acc 0.9898
# epoch 683: train D loss: 0.6527, train F loss: -0.4182, acc 0.9906
# epoch 684: train D loss: 0.6523, train F loss: -0.4037, acc 0.9852
# epoch 685: train D loss: 0.6516, train F loss: -0.4136, acc 0.9876
# epoch 686: train D loss: 0.6502, train F loss: -0.4064, acc 0.9894
# epoch 687: train D loss: 0.6556, train F loss: -0.4183, acc 0.9890
# epoch 688: train D loss: 0.6571, train F loss: -0.4192, acc 0.9882
# epoch 689: train D loss: 0.6505, train F loss: -0.4110, acc 0.9866
# epoch 690: train D loss: 0.6548, train F loss: -0.4212, acc 0.9916
# epoch 691: train D loss: 0.6537, train F loss: -0.4093, acc 0.9880
# epoch 692: train D loss: 0.6512, train F loss: -0.4090, acc 0.9878
# epoch 693: train D loss: 0.6532, train F loss: -0.4076, acc 0.9856
# epoch 694: train D loss: 0.6568, train F loss: -0.4174, acc 0.9896
# epoch 695: train D loss: 0.6618, train F loss: -0.4219, acc 0.9886
# epoch 696: train D loss: 0.6595, train F loss: -0.4211, acc 0.9884
# epoch 697: train D loss: 0.6519, train F loss: -0.4176, acc 0.9900
# epoch 698: train D loss: 0.6598, train F loss: -0.4145, acc 0.9874
# epoch 699: train D loss: 0.6566, train F loss: -0.4017, acc 0.9856
# epoch 700: train D loss: 0.6499, train F loss: -0.4021, acc 0.9856
# epoch 701: train D loss: 0.6575, train F loss: -0.4140, acc 0.9872
# epoch 702: train D loss: 0.6511, train F loss: -0.4065, acc 0.9886
# epoch 703: train D loss: 0.6589, train F loss: -0.4213, acc 0.9904
# epoch 704: train D loss: 0.6533, train F loss: -0.4172, acc 0.9888
# epoch 705: train D loss: 0.6605, train F loss: -0.4333, acc 0.9932
# epoch 706: train D loss: 0.6552, train F loss: -0.4190, acc 0.9888
# epoch 707: train D loss: 0.6615, train F loss: -0.4127, acc 0.9856
# epoch 708: train D loss: 0.6569, train F loss: -0.4176, acc 0.9896
# epoch 709: train D loss: 0.6632, train F loss: -0.4255, acc 0.9890
# epoch 710: train D loss: 0.6568, train F loss: -0.4154, acc 0.9882
# epoch 711: train D loss: 0.6587, train F loss: -0.4211, acc 0.9882
# epoch 712: train D loss: 0.6630, train F loss: -0.4285, acc 0.9898
# epoch 713: train D loss: 0.6609, train F loss: -0.4223, acc 0.9902
# epoch 714: train D loss: 0.6623, train F loss: -0.4203, acc 0.9874
# epoch 715: train D loss: 0.6575, train F loss: -0.4007, acc 0.9842
# epoch 716: train D loss: 0.6587, train F loss: -0.4125, acc 0.9862
# epoch 717: train D loss: 0.6556, train F loss: -0.4122, acc 0.9878
# epoch 718: train D loss: 0.6524, train F loss: -0.4082, acc 0.9876
# epoch 719: train D loss: 0.6540, train F loss: -0.4193, acc 0.9898
# epoch 720: train D loss: 0.6498, train F loss: -0.4177, acc 0.9910
# epoch 721: train D loss: 0.6475, train F loss: -0.4037, acc 0.9884
# epoch 722: train D loss: 0.6631, train F loss: -0.4194, acc 0.9884
# epoch 723: train D loss: 0.6565, train F loss: -0.4233, acc 0.9894
# epoch 724: train D loss: 0.6579, train F loss: -0.4169, acc 0.9880
# epoch 725: train D loss: 0.6552, train F loss: -0.4195, acc 0.9872
# epoch 726: train D loss: 0.6551, train F loss: -0.4173, acc 0.9898
# epoch 727: train D loss: 0.6493, train F loss: -0.4060, acc 0.9884
# epoch 728: train D loss: 0.6524, train F loss: -0.4204, acc 0.9918
# epoch 729: train D loss: 0.6615, train F loss: -0.4182, acc 0.9878
# epoch 730: train D loss: 0.6604, train F loss: -0.4216, acc 0.9888
# epoch 731: train D loss: 0.6571, train F loss: -0.4093, acc 0.9864
# epoch 732: train D loss: 0.6561, train F loss: -0.4087, acc 0.9878
# epoch 733: train D loss: 0.6579, train F loss: -0.4186, acc 0.9886
# epoch 734: train D loss: 0.6499, train F loss: -0.4090, acc 0.9884
# epoch 735: train D loss: 0.6531, train F loss: -0.4096, acc 0.9876
# epoch 736: train D loss: 0.6454, train F loss: -0.4122, acc 0.9908
# epoch 737: train D loss: 0.6474, train F loss: -0.4176, acc 0.9920
# epoch 738: train D loss: 0.6572, train F loss: -0.4093, acc 0.9882
# epoch 739: train D loss: 0.6542, train F loss: -0.4111, acc 0.9860
# epoch 740: train D loss: 0.6519, train F loss: -0.4083, acc 0.9878
# epoch 741: train D loss: 0.6577, train F loss: -0.4180, acc 0.9880
# epoch 742: train D loss: 0.6594, train F loss: -0.4186, acc 0.9888
# epoch 743: train D loss: 0.6624, train F loss: -0.4237, acc 0.9904
# epoch 744: train D loss: 0.6620, train F loss: -0.4210, acc 0.9884
# epoch 745: train D loss: 0.6655, train F loss: -0.4245, acc 0.9890
# epoch 746: train D loss: 0.6562, train F loss: -0.4192, acc 0.9896
# epoch 747: train D loss: 0.6597, train F loss: -0.4210, acc 0.9894
# epoch 748: train D loss: 0.6603, train F loss: -0.4208, acc 0.9900
# epoch 749: train D loss: 0.6575, train F loss: -0.4186, acc 0.9902
# epoch 750: train D loss: 0.6529, train F loss: -0.4064, acc 0.9854
# epoch 751: train D loss: 0.6601, train F loss: -0.4156, acc 0.9874
# epoch 752: train D loss: 0.6573, train F loss: -0.4152, acc 0.9868
# epoch 753: train D loss: 0.6564, train F loss: -0.4220, acc 0.9896
# epoch 754: train D loss: 0.6573, train F loss: -0.4189, acc 0.9892
# epoch 755: train D loss: 0.6589, train F loss: -0.4223, acc 0.9896
# epoch 756: train D loss: 0.6597, train F loss: -0.4267, acc 0.9904
# epoch 757: train D loss: 0.6637, train F loss: -0.4295, acc 0.9914
# epoch 758: train D loss: 0.6612, train F loss: -0.4212, acc 0.9896
# epoch 759: train D loss: 0.6619, train F loss: -0.4156, acc 0.9878
# epoch 760: train D loss: 0.6561, train F loss: -0.4129, acc 0.9882
# epoch 761: train D loss: 0.6568, train F loss: -0.4101, acc 0.9856
# epoch 762: train D loss: 0.6523, train F loss: -0.4065, acc 0.9868
# epoch 763: train D loss: 0.6536, train F loss: -0.4132, acc 0.9896
# epoch 764: train D loss: 0.6602, train F loss: -0.4165, acc 0.9884
# epoch 765: train D loss: 0.6574, train F loss: -0.4129, acc 0.9888
# epoch 766: train D loss: 0.6532, train F loss: -0.4206, acc 0.9900
# epoch 767: train D loss: 0.6534, train F loss: -0.4174, acc 0.9896
# epoch 768: train D loss: 0.6563, train F loss: -0.4135, acc 0.9888
# epoch 769: train D loss: 0.6545, train F loss: -0.4168, acc 0.9890
# epoch 770: train D loss: 0.6635, train F loss: -0.4311, acc 0.9922
# epoch 771: train D loss: 0.6547, train F loss: -0.4099, acc 0.9850
# epoch 772: train D loss: 0.6502, train F loss: -0.4161, acc 0.9910
# epoch 773: train D loss: 0.6526, train F loss: -0.4205, acc 0.9902
# epoch 774: train D loss: 0.6615, train F loss: -0.4090, acc 0.9868
# epoch 775: train D loss: 0.6579, train F loss: -0.4235, acc 0.9910
# epoch 776: train D loss: 0.6581, train F loss: -0.4219, acc 0.9890
# epoch 777: train D loss: 0.6561, train F loss: -0.4246, acc 0.9912
# epoch 778: train D loss: 0.6571, train F loss: -0.4170, acc 0.9894
# epoch 779: train D loss: 0.6643, train F loss: -0.4256, acc 0.9900
# epoch 780: train D loss: 0.6638, train F loss: -0.4225, acc 0.9884
# epoch 781: train D loss: 0.6585, train F loss: -0.4182, acc 0.9898
# epoch 782: train D loss: 0.6569, train F loss: -0.4202, acc 0.9886
# epoch 783: train D loss: 0.6579, train F loss: -0.4159, acc 0.9878
# epoch 784: train D loss: 0.6580, train F loss: -0.4257, acc 0.9900
# epoch 785: train D loss: 0.6540, train F loss: -0.4243, acc 0.9914
# epoch 786: train D loss: 0.6598, train F loss: -0.4193, acc 0.9890
# epoch 787: train D loss: 0.6585, train F loss: -0.4132, acc 0.9868
# epoch 788: train D loss: 0.6649, train F loss: -0.4176, acc 0.9898
# epoch 789: train D loss: 0.6586, train F loss: -0.4287, acc 0.9916
# epoch 790: train D loss: 0.6618, train F loss: -0.4224, acc 0.9888
# epoch 791: train D loss: 0.6618, train F loss: -0.4208, acc 0.9880
# epoch 792: train D loss: 0.6519, train F loss: -0.4152, acc 0.9880
# epoch 793: train D loss: 0.6580, train F loss: -0.4207, acc 0.9880
# epoch 794: train D loss: 0.6590, train F loss: -0.4246, acc 0.9918
# epoch 795: train D loss: 0.6637, train F loss: -0.4228, acc 0.9902
# epoch 796: train D loss: 0.6576, train F loss: -0.4227, acc 0.9904
# epoch 797: train D loss: 0.6536, train F loss: -0.4264, acc 0.9930
# epoch 798: train D loss: 0.6585, train F loss: -0.4156, acc 0.9902
# epoch 799: train D loss: 0.6581, train F loss: -0.4224, acc 0.9898

# %% [markdown]
# # Inference
#
# We use pandas to generate our csv file.
#
# BTW, the performance of the model trained for 200 epoches might be unstable. You can train for more epoches for a more stable performance.

# %%
result = []
label_predictor.eval()
feature_extractor.eval()
for i, (test_data, _) in enumerate(test_dataloader):
    test_data = test_data.cuda()

    class_logits = label_predictor(feature_extractor(test_data))

    x = torch.argmax(class_logits, dim=1).cpu().detach().numpy()
    result.append(x)

import pandas as pd
result = np.concatenate(result)

# Generate your submission
df = pd.DataFrame({'id': np.arange(0,len(result)), 'label': result})
df.to_csv('DaNN_submission.csv',index=False)

# %% [markdown]
# # Visualization
# We use t-SNE plot to observe the distribution of extracted features.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold

# %%
class Feature():
    def __init__(self):
        self.X = []
        self.TX = []
        self.labels = []

def get_features(model_list):
    features = []
    for model in model_list:
        model.cuda()
        features.append(Feature())

    for (x, y), (tx, _) in zip(source_dataloader, target_dataloader):
        x , tx= x.cuda(), tx.cuda()
        for i, model in enumerate(model_list):
            features[i].X.append(model(x).detach().cpu())
            features[i].TX.append(model(tx).detach().cpu())
            features[i].labels.append(y)
    
    for feature in features:
        feature.X = torch.cat(feature.X).numpy()
        feature.TX = torch.cat(feature.TX).numpy()
        feature.labels = torch.cat(feature.labels).numpy()
        
    return features

def visualization(features):
    for i, feature in enumerate(features):
        X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(feature.X)
        TX_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(feature.TX)
        # Normalization the processed features 
        x_min, x_max = X_tsne.min(0), X_tsne.max(0)
        X_norm = (X_tsne - x_min) / (x_max - x_min)
        tx_min, tx_max = TX_tsne.min(0), TX_tsne.max(0)
        TX_norm = (TX_tsne - tx_min) / (tx_max - tx_min)
    
        plt.figure(figsize=(16, 8))
        plt.subplot(121)
        plt.title(f'stage {i}:distribution of features accross different class')
        plt.scatter(X_norm[:, 0], X_norm[:, 1], c=feature.labels)
        plt.subplot(122)
        plt.title(f'stage {i}:distribution of features accross different domain')
        plt.scatter(X_norm[:, 0], X_norm[:, 1], c='b', label='source domain')
        plt.scatter(TX_norm[:, 0], TX_norm[:, 1], c='r', label='target domain')
        plt.legend()
    plt.show()

# %%
model_list = []
for epoch in marked_epoch:
    model = FeatureExtractor()
    model.load_state_dict(torch.load(f'extractor_model_{epoch}.bin'))
    model_list.append(model)
    
visualization(get_features(model_list))
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 1.363s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.564359
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.699486
# [t-SNE] KL divergence after 1000 iterations: 1.235813
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5024 samples in 0.002s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 5024 samples in 1.721s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5024
# [t-SNE] Computed conditional probabilities for sample 2000 / 5024
# [t-SNE] Computed conditional probabilities for sample 3000 / 5024
# [t-SNE] Computed conditional probabilities for sample 4000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5024 / 5024
# [t-SNE] Mean sigma: 1.836298
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.578415
# [t-SNE] KL divergence after 1000 iterations: 1.280808
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 5000 samples in 1.034s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.833311
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.354263
# [t-SNE] KL divergence after 1000 iterations: 1.856820
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5024 samples in 0.002s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 5024 samples in 1.158s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5024
# [t-SNE] Computed conditional probabilities for sample 2000 / 5024
# [t-SNE] Computed conditional probabilities for sample 3000 / 5024
# [t-SNE] Computed conditional probabilities for sample 4000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5024 / 5024
# [t-SNE] Mean sigma: 1.739461
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.262718
# [t-SNE] KL divergence after 1000 iterations: 1.774101
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 5000 samples in 1.683s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.279481
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.987946
# [t-SNE] KL divergence after 1000 iterations: 1.738145
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5024 samples in 0.002s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 5024 samples in 1.051s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5024
# [t-SNE] Computed conditional probabilities for sample 2000 / 5024
# [t-SNE] Computed conditional probabilities for sample 3000 / 5024
# [t-SNE] Computed conditional probabilities for sample 4000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5024 / 5024
# [t-SNE] Mean sigma: 1.148076
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.426666
# [t-SNE] KL divergence after 1000 iterations: 1.656825

# %% [markdown]
# ## Step1: Load checkpoint and evaluate to get extracted features

# %%
# Hints:
# Set features_extractor to eval mode
# Start evaluation and collect features and labels

# %% [markdown]
# ## Step2: Apply t-SNE and normalize

# %%
# process extracted features with t-SNE
# X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(X)

# Normalization the processed features 
# x_min, x_max = X_tsne.min(0), X_tsne.max(0)
# X_norm = (X_tsne - x_min) / (x_max - x_min)

# %% [markdown]
# ## Step3: Visualization with matplotlib

# %%
# Data Visualization
# Use matplotlib to plot the distribution
# The shape of X_norm is (N,2)

# %% [markdown]
# # Training Statistics
#
# - Number of parameters:
#   - Feature Extractor: 2, 142, 336
#   - Label Predictor: 530, 442
#   - Domain Classifier: 1, 055, 233
#
# - Simple
#  - Training time on colab: ~ 1 hr
# - Medium
#  - Training time on colab: 2 ~ 4 hr
# - Strong
#  - Training time on colab: 5 ~ 6 hrs
# - Boss
#  - **Unmeasurable**

# %% [markdown]
# # Learning Curve (Strong Baseline)
# * This method is slightly different from colab.
#
# ![Loss Curve](https://i.imgur.com/vIujQyo.png)
#
# # Accuracy Curve (Strong Baseline)
# * Note that you cannot access testing accuracy. But this plot tells you that even though the model overfits the training data, the testing accuracy is still improving, and that's why you need to train more epochs.
#
# ![Acc Curve](https://i.imgur.com/4W1otXG.png)

# %% [markdown]
# # Q&A
#
# If there is any problem related to Domain Adaptation, please email to b08901058@ntu.edu.tw / mlta-2022-spring@googlegroups.com。
