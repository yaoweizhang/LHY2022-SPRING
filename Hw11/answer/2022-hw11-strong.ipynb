# %% [markdown]
# # Homework 11 - Transfer Learning (Domain Adversarial Training)
#
# > Author: Arvin Liu (r09922071@ntu.edu.tw)
#
# If there are any questions, please contact mlta-2022-spring@googlegroups.com

# %% [markdown]
# # Readme
#
# In homework 11, you will need to implement Domain Adversarial Training in Transfer Learning. As shown in the bottom left part of the figure.
#
# <img src="https://i.imgur.com/iMVIxCH.png" width="500px">
#
# >
#
# ## Scenario and Why Domain Adversarial Training
# Now we have labeled source data and unlabeled target data, where source data might be relavent to the target data. We now want to train a model with source data only and test it on target data.
#
# What problem might occur if we do so? After we have learned Anomaly Detection, we now know that if we test the model with an abnormal data that have never appeared in source data, our trained model is likely to result in poor performance since it is not familiar with the abnormal data.
#
# For example, we have a model that contains Feature Extractor and Classifier:
# <img src="https://i.imgur.com/IL0PxCY.png" width="500px">
#
# When the model is trained with source data, the feature extractor
# will extract meaningful features since it is familiar with the distribution of it.It could be seen in the following figure that the blue dots, which is the distribution of source data, has already been clustered into different clusters. Therefore, the Classifier can predict the label based on these clusters.
#
# However, when test on the target data, the Feature Extractor will not be able to extract meaningful features that follow the distribution of the source feature distribution, which result in the classifier learned for the source domain will not be able to apply to the target domain.
#
#
# ## Domain Adversarial Training of Nerural Networks (DaNN)
#
# Based on the above problems, DaNN approaches build mappings between the source (training-time) and the target (test-time) domains, so that the classifier learned for the source domain can also be applied to the target domain, when composed with the learned mapping between domains.
#
# <img src="https://i.imgur.com/vrOE5a6.png" width="500px">
#
# In DaNN, the authors added a Domain Classifier, which is a deep discriminatively-trained classifeir in the training framework to distinguish the data from different domain by the features extracted by the feature extractor. As the training progresses, the approach promotes a domain classifier that discriminates between the source and the target domains and a feature extractor that can extractor features that are discriminative for the main learning task on the source domain and indiscriminate with respect to the shift between the domains.
#
#
# The feature extractor are likely to outperform the domain classifier as its input are generated by the feature extractor and that the task of domain classification and label classification are not conflict.
#
# This method leads to the emergence of features that are domain-invariant and on the same feature distribution.

# %% [markdown]
# # Data Introduce
#
# Our task contains source data: real photos, and target data: hand-drawn graffiti.
#
# We are going to train the model with the photos and the labels, and try to predict what the labels are for hand-drawn graffiti.
#
# The data could be downloaded [here](https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip). The code below is for data downloading and visualization.
#
# Note that: **The source and target data are all balanced data, you can make use of this information.**

# %%
# Download dataset
#!wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip" -O real_or_drawing.zip

# Download from mirrored dataset link
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.1/real_or_drawing.zip" -O real_or_drawing.zip
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.2/real_or_drawing.zip" -O real_or_drawing.zip

# Unzip the files
#!unzip real_or_drawing.zip

# %%
# !nvidia-smi
# Out:
# Tue Jul  5 08:44:32 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.82.01    Driver Version: 470.82.01    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import matplotlib.pyplot as plt

def no_axis_show(img, title='', cmap=None):
  # imshow, and set the interpolation mode to be "nearest"。
  fig = plt.imshow(img, interpolation='nearest', cmap=cmap)
  # do not show the axes in the images.
  fig.axes.get_xaxis().set_visible(False)
  fig.axes.get_yaxis().set_visible(False)
  plt.title(title)

titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/train_data/{i}/{500*i}.bmp'), title=titles[i])

# %%
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/test_data/0/' + str(i).rjust(5, '0') + '.bmp'))

# %% [markdown]
# # Special Domain Knowledge
#
# When we graffiti, we usually draw the outline only, therefore we can perform edge detection processing on the source data to make it more similar to the target data.
#
#
# ## Canny Edge Detection
# The implementation of Canny Edge Detection is as follow.
# The algorithm will not be describe thoroughly here.  If you are interested, please refer to the wiki or [here](https://medium.com/@pomelyu5199/canny-edge-detector-%E5%AF%A6%E4%BD%9C-opencv-f7d1a0a57d19).
#
# We only need two parameters to implement Canny Edge Detection with CV2:  `low_threshold` and `high_threshold`.
#
# ```cv2.Canny(image, low_threshold, high_threshold)```
#
# Simply put, when the edge value exceeds the high_threshold, we determine it as an edge. If the edge value is only above low_threshold, we will then determine whether it is an edge or not.
#
# Let's implement it on the source data.

# %%
import cv2
import matplotlib.pyplot as plt
titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))

original_img = plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/train_data/0/0.bmp')
plt.subplot(1, 5, 1)
no_axis_show(original_img, title='original')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

canny_50100 = cv2.Canny(gray_img, 50, 100)
plt.subplot(1, 5, 3)
no_axis_show(canny_50100, title='Canny(50, 100)', cmap='gray')

canny_150200 = cv2.Canny(gray_img, 150, 200)
plt.subplot(1, 5, 4)
no_axis_show(canny_150200, title='Canny(150, 200)', cmap='gray')

canny_250300 = cv2.Canny(gray_img, 250, 300)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(250, 300)', cmap='gray')

# %% [markdown]
# # Data Process
#
#
# The data is suitible for `torchvision.ImageFolder`. You can create a dataset with `torchvision.ImageFolder`. Details for image augmentation please refer to the comments in the following codes.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Function
 
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
 
source_transform = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 170, 300)),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
target_transform = transforms.Compose([
    # Turn RGB to grayscale.
    transforms.Grayscale(),
    # Resize: size of source data is 32x32, thus we need to 
    #  enlarge the size of target data from 28x28 to 32x32。
    transforms.Resize((32, 32)),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
 
source_dataset = ImageFolder('../input/ml2022-spring-hw11/real_or_drawing/train_data', transform=source_transform)
target_dataset = ImageFolder('../input/ml2022-spring-hw11/real_or_drawing/test_data', transform=target_transform)
 
source_dataloader = DataLoader(source_dataset, batch_size=32, shuffle=True)
target_dataloader = DataLoader(target_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(target_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# # Model
#
# Feature Extractor: Classic VGG-like architecture
#
# Label Predictor / Domain Classifier: Linear models.

# %%
class FeatureExtractor(nn.Module):

    def __init__(self):
        super(FeatureExtractor, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
    def forward(self, x):
        x = self.conv(x).squeeze()
        return x

class LabelPredictor(nn.Module):

    def __init__(self):
        super(LabelPredictor, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 10),
        )

    def forward(self, h):
        c = self.layer(h)
        return c

class DomainClassifier(nn.Module):

    def __init__(self):
        super(DomainClassifier, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 1),
        )

    def forward(self, h):
        y = self.layer(h)
        return y

# %% [markdown]
# # Pre-processing
#
# Here we use Adam as our optimizor.

# %%
feature_extractor = FeatureExtractor().cuda()
label_predictor = LabelPredictor().cuda()
domain_classifier = DomainClassifier().cuda()

class_criterion = nn.CrossEntropyLoss()
domain_criterion = nn.BCEWithLogitsLoss()

optimizer_F = optim.Adam(feature_extractor.parameters())
optimizer_C = optim.Adam(label_predictor.parameters())
optimizer_D = optim.Adam(domain_classifier.parameters())

# %% [markdown]
# # Start Training
#
#
# ## DaNN Implementation
#
# In the original paper, Gradient Reversal Layer is used.
# Feature Extractor, Label Predictor, and Domain Classifier are all trained at the same time. In this code, we train Domain Classifier first, and then train our Feature Extractor (same concept as Generator and Discriminator training process in GAN).
#
# ## Reminder
# * Lambda, which controls the domain adversarial loss, is adaptive in the original paper. You can refer to [the original work](https://arxiv.org/pdf/1505.07818.pdf) . Here lambda is set to 0.1.
# * We do not have the label to target data, you can only evaluate your model by uploading your result to kaggle.:)

# %%
def train_epoch(source_dataloader, target_dataloader, lamb):
    '''
      Args:
        source_dataloader: source data的dataloader
        target_dataloader: target data的dataloader
        lamb: control the balance of domain adaptatoin and classification.
    '''

    # D loss: Domain Classifier的loss
    # F loss: Feature Extrator & Label Predictor的loss
    running_D_loss, running_F_loss = 0.0, 0.0
    total_hit, total_num = 0.0, 0.0

    for i, ((source_data, source_label), (target_data, _)) in enumerate(zip(source_dataloader, target_dataloader)):

        source_data = source_data.cuda()
        source_label = source_label.cuda()
        target_data = target_data.cuda()
        
        #Mixed the source data and target data, or it'll mislead the running params
        #   of batch_norm. (runnning mean/var of soucre and target data are different.)
        mixed_data = torch.cat([source_data, target_data], dim=0)
        domain_label = torch.zeros([source_data.shape[0] + target_data.shape[0], 1]).cuda()
        # set domain label of source data to be 1.
        domain_label[:source_data.shape[0]] = 1
        # Step 1 : train domain classifier
        feature = feature_extractor(mixed_data)
        # We don't need to train feature extractor in step 1.
        # Thus we detach the feature neuron to avoid backpropgation.
        domain_logits = domain_classifier(feature.detach())
        loss = domain_criterion(domain_logits, domain_label)
        running_D_loss += loss.item()
        loss.backward()
        optimizer_D.step()
    
        # Step 2 : train feature extractor and label classifier
        class_logits = label_predictor(feature[:source_data.shape[0]])
        domain_logits = domain_classifier(feature)
        # loss = cross entropy of classification - lamb * domain binary cross entropy.
        #  The reason why using subtraction is similar to generator loss in disciminator of GAN
        loss = class_criterion(class_logits, source_label) - lamb * domain_criterion(domain_logits, domain_label)
        running_F_loss += loss.item()
        loss.backward()
        optimizer_F.step()
        optimizer_C.step()

        optimizer_D.zero_grad()
        optimizer_F.zero_grad()
        optimizer_C.zero_grad()
        total_hit += torch.sum(torch.argmax(class_logits, dim=1) == source_label).item()
        total_num += source_data.shape[0]
        print(i, end='\r') 
        
    return running_D_loss / (i+1), running_F_loss / (i+1), total_hit / total_num

# train 200 epochs
print('start training')
epochs = 1000
gap = 200
marked_epoch = [0] + [gap*i - 1 for i in range(1, epochs//gap + 1)]
for epoch in range(epochs):
    lamb = np.log(1.02 + 1.7*epoch/epochs)
    train_D_loss, train_F_loss, train_acc = train_epoch(source_dataloader, target_dataloader, lamb=lamb)
    
    if epoch in marked_epoch:
        torch.save(feature_extractor.state_dict(), f'extractor_model_{epoch}.bin')
        torch.save(label_predictor.state_dict(), f'predictor_model_{epoch}.bin')

    print('epoch {:>3d}: train D loss: {:6.4f}, train F loss: {:6.4f}, acc {:6.4f}'.format(epoch, train_D_loss, train_F_loss, train_acc))

torch.save(feature_extractor.state_dict(), f'extractor_model.bin')
torch.save(label_predictor.state_dict(), f'predictor_model.bin')
# Out:
# start training
# epoch   0: train D loss: 0.4009, train F loss: 1.9055, acc 0.2902
# epoch   1: train D loss: 0.4621, train F loss: 1.6256, acc 0.4156
# epoch   2: train D loss: 0.4472, train F loss: 1.4959, acc 0.4684
# epoch   3: train D loss: 0.4166, train F loss: 1.3964, acc 0.5080
# epoch   4: train D loss: 0.4029, train F loss: 1.3360, acc 0.5348
# epoch   5: train D loss: 0.3783, train F loss: 1.2978, acc 0.5378
# epoch   6: train D loss: 0.3922, train F loss: 1.2605, acc 0.5578
# epoch   7: train D loss: 0.3838, train F loss: 1.2100, acc 0.5734
# epoch   8: train D loss: 0.3621, train F loss: 1.1650, acc 0.5930
# epoch   9: train D loss: 0.3908, train F loss: 1.1490, acc 0.5938
# epoch  10: train D loss: 0.3849, train F loss: 1.1003, acc 0.6090
# epoch  11: train D loss: 0.3787, train F loss: 1.0769, acc 0.6228
# epoch  12: train D loss: 0.3740, train F loss: 1.0341, acc 0.6410
# epoch  13: train D loss: 0.3556, train F loss: 0.9915, acc 0.6464
# epoch  14: train D loss: 0.3708, train F loss: 0.9645, acc 0.6608
# epoch  15: train D loss: 0.3657, train F loss: 0.9290, acc 0.6750
# epoch  16: train D loss: 0.3660, train F loss: 0.8953, acc 0.6746
# epoch  17: train D loss: 0.3662, train F loss: 0.8687, acc 0.6916
# epoch  18: train D loss: 0.3635, train F loss: 0.8171, acc 0.7154
# epoch  19: train D loss: 0.3480, train F loss: 0.7888, acc 0.7232
# epoch  20: train D loss: 0.3683, train F loss: 0.7490, acc 0.7374
# epoch  21: train D loss: 0.3563, train F loss: 0.7192, acc 0.7454
# epoch  22: train D loss: 0.3758, train F loss: 0.7067, acc 0.7474
# epoch  23: train D loss: 0.3523, train F loss: 0.6502, acc 0.7650
# epoch  24: train D loss: 0.3502, train F loss: 0.6183, acc 0.7774
# epoch  25: train D loss: 0.3273, train F loss: 0.5930, acc 0.7872
# epoch  26: train D loss: 0.3328, train F loss: 0.5645, acc 0.7954
# epoch  27: train D loss: 0.3321, train F loss: 0.5243, acc 0.8098
# epoch  28: train D loss: 0.3477, train F loss: 0.5288, acc 0.8158
# epoch  29: train D loss: 0.3069, train F loss: 0.4817, acc 0.8204
# epoch  30: train D loss: 0.3254, train F loss: 0.4592, acc 0.8364
# epoch  31: train D loss: 0.3267, train F loss: 0.4537, acc 0.8328
# epoch  32: train D loss: 0.3261, train F loss: 0.3927, acc 0.8598
# epoch  33: train D loss: 0.3119, train F loss: 0.3868, acc 0.8584
# epoch  34: train D loss: 0.3143, train F loss: 0.3594, acc 0.8678
# epoch  35: train D loss: 0.3216, train F loss: 0.3665, acc 0.8686
# epoch  36: train D loss: 0.3124, train F loss: 0.3125, acc 0.8830
# epoch  37: train D loss: 0.3057, train F loss: 0.3230, acc 0.8890
# epoch  38: train D loss: 0.3153, train F loss: 0.3067, acc 0.8878
# epoch  39: train D loss: 0.3086, train F loss: 0.3086, acc 0.8848
# epoch  40: train D loss: 0.3329, train F loss: 0.2730, acc 0.9038
# epoch  41: train D loss: 0.3219, train F loss: 0.2699, acc 0.8998
# epoch  42: train D loss: 0.3201, train F loss: 0.2480, acc 0.9106
# epoch  43: train D loss: 0.3139, train F loss: 0.2398, acc 0.9070
# epoch  44: train D loss: 0.3117, train F loss: 0.2457, acc 0.9088
# epoch  45: train D loss: 0.3091, train F loss: 0.2399, acc 0.9084
# epoch  46: train D loss: 0.3137, train F loss: 0.2007, acc 0.9222
# epoch  47: train D loss: 0.3113, train F loss: 0.2134, acc 0.9166
# epoch  48: train D loss: 0.2990, train F loss: 0.2120, acc 0.9190
# epoch  49: train D loss: 0.3109, train F loss: 0.1803, acc 0.9312
# epoch  50: train D loss: 0.3173, train F loss: 0.1800, acc 0.9314
# epoch  51: train D loss: 0.3285, train F loss: 0.1816, acc 0.9274
# epoch  52: train D loss: 0.3322, train F loss: 0.1709, acc 0.9298
# epoch  53: train D loss: 0.3285, train F loss: 0.1609, acc 0.9356
# epoch  54: train D loss: 0.3322, train F loss: 0.1605, acc 0.9358
# epoch  55: train D loss: 0.3490, train F loss: 0.1372, acc 0.9442
# epoch  56: train D loss: 0.3410, train F loss: 0.1667, acc 0.9352
# epoch  57: train D loss: 0.3404, train F loss: 0.1460, acc 0.9438
# epoch  58: train D loss: 0.3309, train F loss: 0.1383, acc 0.9412
# epoch  59: train D loss: 0.3444, train F loss: 0.1268, acc 0.9470
# epoch  60: train D loss: 0.3374, train F loss: 0.1294, acc 0.9448
# epoch  61: train D loss: 0.3459, train F loss: 0.1392, acc 0.9416
# epoch  62: train D loss: 0.3609, train F loss: 0.1183, acc 0.9468
# epoch  63: train D loss: 0.3601, train F loss: 0.1140, acc 0.9512
# epoch  64: train D loss: 0.3602, train F loss: 0.1289, acc 0.9426
# epoch  65: train D loss: 0.3594, train F loss: 0.1240, acc 0.9494
# epoch  66: train D loss: 0.3689, train F loss: 0.0951, acc 0.9546
# epoch  67: train D loss: 0.3726, train F loss: 0.1211, acc 0.9472
# epoch  68: train D loss: 0.3790, train F loss: 0.0961, acc 0.9544
# epoch  69: train D loss: 0.3672, train F loss: 0.1174, acc 0.9480
# epoch  70: train D loss: 0.3778, train F loss: 0.1022, acc 0.9526
# epoch  71: train D loss: 0.3732, train F loss: 0.1008, acc 0.9502
# epoch  72: train D loss: 0.3772, train F loss: 0.1034, acc 0.9504
# epoch  73: train D loss: 0.3819, train F loss: 0.0666, acc 0.9638
# epoch  74: train D loss: 0.3771, train F loss: 0.0907, acc 0.9536
# epoch  75: train D loss: 0.3858, train F loss: 0.0816, acc 0.9546
# epoch  76: train D loss: 0.4025, train F loss: 0.0613, acc 0.9620
# epoch  77: train D loss: 0.4006, train F loss: 0.0855, acc 0.9532
# epoch  78: train D loss: 0.3940, train F loss: 0.0599, acc 0.9624
# epoch  79: train D loss: 0.3910, train F loss: 0.0822, acc 0.9570
# epoch  80: train D loss: 0.4078, train F loss: 0.0426, acc 0.9660
# epoch  81: train D loss: 0.4097, train F loss: 0.0506, acc 0.9630
# epoch  82: train D loss: 0.4181, train F loss: 0.0548, acc 0.9640
# epoch  83: train D loss: 0.4051, train F loss: 0.0722, acc 0.9570
# epoch  84: train D loss: 0.3966, train F loss: 0.0799, acc 0.9550
# epoch  85: train D loss: 0.4074, train F loss: 0.0509, acc 0.9648
# epoch  86: train D loss: 0.4164, train F loss: 0.0532, acc 0.9628
# epoch  87: train D loss: 0.4113, train F loss: 0.0687, acc 0.9568
# epoch  88: train D loss: 0.4351, train F loss: 0.0522, acc 0.9638
# epoch  89: train D loss: 0.4305, train F loss: 0.0373, acc 0.9684
# epoch  90: train D loss: 0.4245, train F loss: 0.0416, acc 0.9648
# epoch  91: train D loss: 0.4481, train F loss: 0.0356, acc 0.9646
# epoch  92: train D loss: 0.4332, train F loss: 0.0368, acc 0.9676
# epoch  93: train D loss: 0.4301, train F loss: 0.0293, acc 0.9686
# epoch  94: train D loss: 0.4217, train F loss: 0.0388, acc 0.9648
# epoch  95: train D loss: 0.4381, train F loss: 0.0489, acc 0.9632
# epoch  96: train D loss: 0.4289, train F loss: 0.0473, acc 0.9608
# epoch  97: train D loss: 0.4315, train F loss: 0.0185, acc 0.9708
# epoch  98: train D loss: 0.4459, train F loss: 0.0327, acc 0.9664
# epoch  99: train D loss: 0.4451, train F loss: 0.0294, acc 0.9642
# epoch 100: train D loss: 0.4304, train F loss: 0.0664, acc 0.9582
# epoch 101: train D loss: 0.4478, train F loss: 0.0248, acc 0.9682
# epoch 102: train D loss: 0.4403, train F loss: 0.0114, acc 0.9726
# epoch 103: train D loss: 0.4550, train F loss: 0.0056, acc 0.9718
# epoch 104: train D loss: 0.4578, train F loss: 0.0159, acc 0.9702
# epoch 105: train D loss: 0.4704, train F loss: 0.0260, acc 0.9652
# epoch 106: train D loss: 0.4504, train F loss: -0.0004, acc 0.9752
# epoch 107: train D loss: 0.4699, train F loss: 0.0241, acc 0.9678
# epoch 108: train D loss: 0.4548, train F loss: 0.0288, acc 0.9660
# epoch 109: train D loss: 0.4545, train F loss: -0.0100, acc 0.9778
# epoch 110: train D loss: 0.4753, train F loss: 0.0115, acc 0.9672
# epoch 111: train D loss: 0.4665, train F loss: 0.0139, acc 0.9684
# epoch 112: train D loss: 0.4764, train F loss: 0.0040, acc 0.9704
# epoch 113: train D loss: 0.4760, train F loss: 0.0008, acc 0.9734
# epoch 114: train D loss: 0.4741, train F loss: 0.0148, acc 0.9664
# epoch 115: train D loss: 0.4741, train F loss: 0.0031, acc 0.9692
# epoch 116: train D loss: 0.4593, train F loss: 0.0048, acc 0.9706
# epoch 117: train D loss: 0.4691, train F loss: -0.0028, acc 0.9750
# epoch 118: train D loss: 0.4875, train F loss: -0.0003, acc 0.9700
# epoch 119: train D loss: 0.4762, train F loss: -0.0003, acc 0.9700
# epoch 120: train D loss: 0.4872, train F loss: -0.0133, acc 0.9724
# epoch 121: train D loss: 0.4904, train F loss: -0.0175, acc 0.9710
# epoch 122: train D loss: 0.4897, train F loss: -0.0040, acc 0.9742
# epoch 123: train D loss: 0.4794, train F loss: -0.0028, acc 0.9720
# epoch 124: train D loss: 0.4765, train F loss: 0.0012, acc 0.9684
# epoch 125: train D loss: 0.4807, train F loss: -0.0249, acc 0.9776
# epoch 126: train D loss: 0.5005, train F loss: -0.0072, acc 0.9692
# epoch 127: train D loss: 0.4865, train F loss: -0.0181, acc 0.9734
# epoch 128: train D loss: 0.4891, train F loss: -0.0142, acc 0.9742
# epoch 129: train D loss: 0.4813, train F loss: -0.0184, acc 0.9770
# epoch 130: train D loss: 0.4842, train F loss: -0.0152, acc 0.9716
# epoch 131: train D loss: 0.4916, train F loss: -0.0208, acc 0.9730
# epoch 132: train D loss: 0.4783, train F loss: -0.0149, acc 0.9742
# epoch 133: train D loss: 0.4753, train F loss: -0.0255, acc 0.9762
# epoch 134: train D loss: 0.4915, train F loss: -0.0279, acc 0.9762
# epoch 135: train D loss: 0.4966, train F loss: -0.0249, acc 0.9742
# epoch 136: train D loss: 0.5058, train F loss: -0.0334, acc 0.9762
# epoch 137: train D loss: 0.4882, train F loss: -0.0321, acc 0.9752
# epoch 138: train D loss: 0.5055, train F loss: -0.0367, acc 0.9726
# epoch 139: train D loss: 0.5072, train F loss: -0.0246, acc 0.9712
# epoch 140: train D loss: 0.5007, train F loss: -0.0235, acc 0.9726
# epoch 141: train D loss: 0.4911, train F loss: -0.0334, acc 0.9760
# epoch 142: train D loss: 0.4990, train F loss: -0.0427, acc 0.9782
# epoch 143: train D loss: 0.5272, train F loss: -0.0381, acc 0.9742
# epoch 144: train D loss: 0.5178, train F loss: -0.0395, acc 0.9736
# epoch 145: train D loss: 0.5224, train F loss: -0.0389, acc 0.9726
# epoch 146: train D loss: 0.5208, train F loss: -0.0347, acc 0.9750
# epoch 147: train D loss: 0.5081, train F loss: -0.0426, acc 0.9764
# epoch 148: train D loss: 0.5137, train F loss: -0.0463, acc 0.9774
# epoch 149: train D loss: 0.5134, train F loss: -0.0484, acc 0.9778
# epoch 150: train D loss: 0.5051, train F loss: -0.0350, acc 0.9736
# epoch 151: train D loss: 0.5122, train F loss: -0.0349, acc 0.9724
# epoch 152: train D loss: 0.5128, train F loss: -0.0429, acc 0.9730
# epoch 153: train D loss: 0.4933, train F loss: -0.0394, acc 0.9768
# epoch 154: train D loss: 0.5118, train F loss: -0.0505, acc 0.9762
# epoch 155: train D loss: 0.5199, train F loss: -0.0520, acc 0.9770
# epoch 156: train D loss: 0.5163, train F loss: -0.0457, acc 0.9742
# epoch 157: train D loss: 0.5110, train F loss: -0.0452, acc 0.9728
# epoch 158: train D loss: 0.5166, train F loss: -0.0522, acc 0.9776
# epoch 159: train D loss: 0.5227, train F loss: -0.0479, acc 0.9766
# epoch 160: train D loss: 0.5252, train F loss: -0.0546, acc 0.9768
# epoch 161: train D loss: 0.5155, train F loss: -0.0633, acc 0.9790
# epoch 162: train D loss: 0.5186, train F loss: -0.0607, acc 0.9788
# epoch 163: train D loss: 0.5228, train F loss: -0.0685, acc 0.9786
# epoch 164: train D loss: 0.5242, train F loss: -0.0543, acc 0.9762
# epoch 165: train D loss: 0.5328, train F loss: -0.0522, acc 0.9730
# epoch 166: train D loss: 0.5246, train F loss: -0.0583, acc 0.9728
# epoch 167: train D loss: 0.5224, train F loss: -0.0685, acc 0.9766
# epoch 168: train D loss: 0.5273, train F loss: -0.0582, acc 0.9792
# epoch 169: train D loss: 0.5387, train F loss: -0.0717, acc 0.9774
# epoch 170: train D loss: 0.5270, train F loss: -0.0704, acc 0.9790
# epoch 171: train D loss: 0.5269, train F loss: -0.0728, acc 0.9802
# epoch 172: train D loss: 0.5316, train F loss: -0.0544, acc 0.9744
# epoch 173: train D loss: 0.5304, train F loss: -0.0648, acc 0.9738
# epoch 174: train D loss: 0.5332, train F loss: -0.0801, acc 0.9802
# epoch 175: train D loss: 0.5383, train F loss: -0.0755, acc 0.9770
# epoch 176: train D loss: 0.5312, train F loss: -0.0780, acc 0.9794
# epoch 177: train D loss: 0.5422, train F loss: -0.0861, acc 0.9792
# epoch 178: train D loss: 0.5360, train F loss: -0.0698, acc 0.9772
# epoch 179: train D loss: 0.5528, train F loss: -0.0820, acc 0.9782
# epoch 180: train D loss: 0.5480, train F loss: -0.0797, acc 0.9758
# epoch 181: train D loss: 0.5450, train F loss: -0.0768, acc 0.9760
# epoch 182: train D loss: 0.5380, train F loss: -0.0582, acc 0.9704
# epoch 183: train D loss: 0.5357, train F loss: -0.0779, acc 0.9772
# epoch 184: train D loss: 0.5406, train F loss: -0.0919, acc 0.9800
# epoch 185: train D loss: 0.5403, train F loss: -0.0743, acc 0.9776
# epoch 186: train D loss: 0.5432, train F loss: -0.0832, acc 0.9766
# epoch 187: train D loss: 0.5231, train F loss: -0.0832, acc 0.9796
# epoch 188: train D loss: 0.5460, train F loss: -0.0877, acc 0.9796
# epoch 189: train D loss: 0.5366, train F loss: -0.0790, acc 0.9794
# epoch 190: train D loss: 0.5397, train F loss: -0.0964, acc 0.9820
# epoch 191: train D loss: 0.5551, train F loss: -0.0923, acc 0.9818
# epoch 192: train D loss: 0.5463, train F loss: -0.0885, acc 0.9792
# epoch 193: train D loss: 0.5487, train F loss: -0.0894, acc 0.9796
# epoch 194: train D loss: 0.5472, train F loss: -0.0760, acc 0.9738
# epoch 195: train D loss: 0.5341, train F loss: -0.0860, acc 0.9780
# epoch 196: train D loss: 0.5482, train F loss: -0.0981, acc 0.9810
# epoch 197: train D loss: 0.5568, train F loss: -0.0943, acc 0.9792
# epoch 198: train D loss: 0.5494, train F loss: -0.1097, acc 0.9836
# epoch 199: train D loss: 0.5593, train F loss: -0.1058, acc 0.9806
# epoch 200: train D loss: 0.5598, train F loss: -0.0822, acc 0.9768
# epoch 201: train D loss: 0.5442, train F loss: -0.1089, acc 0.9814
# epoch 202: train D loss: 0.5525, train F loss: -0.1081, acc 0.9812
# epoch 203: train D loss: 0.5570, train F loss: -0.1021, acc 0.9778
# epoch 204: train D loss: 0.5597, train F loss: -0.1105, acc 0.9804
# epoch 205: train D loss: 0.5558, train F loss: -0.0952, acc 0.9772
# epoch 206: train D loss: 0.5549, train F loss: -0.0799, acc 0.9734
# epoch 207: train D loss: 0.5562, train F loss: -0.0974, acc 0.9768
# epoch 208: train D loss: 0.5413, train F loss: -0.0785, acc 0.9748
# epoch 209: train D loss: 0.5578, train F loss: -0.1001, acc 0.9794
# epoch 210: train D loss: 0.5584, train F loss: -0.1031, acc 0.9772
# epoch 211: train D loss: 0.5590, train F loss: -0.1066, acc 0.9790
# epoch 212: train D loss: 0.5647, train F loss: -0.1087, acc 0.9764
# epoch 213: train D loss: 0.5536, train F loss: -0.1136, acc 0.9814
# epoch 214: train D loss: 0.5552, train F loss: -0.1127, acc 0.9814
# epoch 215: train D loss: 0.5560, train F loss: -0.1065, acc 0.9756
# epoch 216: train D loss: 0.5630, train F loss: -0.1128, acc 0.9794
# epoch 217: train D loss: 0.5647, train F loss: -0.1239, acc 0.9830
# epoch 218: train D loss: 0.5727, train F loss: -0.1245, acc 0.9794
# epoch 219: train D loss: 0.5740, train F loss: -0.1280, acc 0.9808
# epoch 220: train D loss: 0.5719, train F loss: -0.1154, acc 0.9804
# epoch 221: train D loss: 0.5623, train F loss: -0.1088, acc 0.9778
# epoch 222: train D loss: 0.5621, train F loss: -0.1205, acc 0.9806
# epoch 223: train D loss: 0.5591, train F loss: -0.1123, acc 0.9790
# epoch 224: train D loss: 0.5549, train F loss: -0.1284, acc 0.9850
# epoch 225: train D loss: 0.5638, train F loss: -0.1133, acc 0.9796
# epoch 226: train D loss: 0.5671, train F loss: -0.1351, acc 0.9826
# epoch 227: train D loss: 0.5684, train F loss: -0.1252, acc 0.9786
# epoch 228: train D loss: 0.5774, train F loss: -0.1269, acc 0.9818
# epoch 229: train D loss: 0.5745, train F loss: -0.1292, acc 0.9794
# epoch 230: train D loss: 0.5791, train F loss: -0.1357, acc 0.9820
# epoch 231: train D loss: 0.5791, train F loss: -0.1277, acc 0.9782
# epoch 232: train D loss: 0.5693, train F loss: -0.1292, acc 0.9826
# epoch 233: train D loss: 0.5734, train F loss: -0.1325, acc 0.9810
# epoch 234: train D loss: 0.5749, train F loss: -0.1404, acc 0.9816
# epoch 235: train D loss: 0.5835, train F loss: -0.1430, acc 0.9814
# epoch 236: train D loss: 0.5690, train F loss: -0.1427, acc 0.9848
# epoch 237: train D loss: 0.5830, train F loss: -0.1458, acc 0.9830
# epoch 238: train D loss: 0.5835, train F loss: -0.1177, acc 0.9752
# epoch 239: train D loss: 0.5748, train F loss: -0.1290, acc 0.9768
# epoch 240: train D loss: 0.5643, train F loss: -0.1376, acc 0.9824
# epoch 241: train D loss: 0.5823, train F loss: -0.1483, acc 0.9818
# epoch 242: train D loss: 0.5771, train F loss: -0.1336, acc 0.9784
# epoch 243: train D loss: 0.5745, train F loss: -0.1493, acc 0.9836
# epoch 244: train D loss: 0.5775, train F loss: -0.1337, acc 0.9792
# epoch 245: train D loss: 0.5769, train F loss: -0.1466, acc 0.9820
# epoch 246: train D loss: 0.5838, train F loss: -0.1532, acc 0.9820
# epoch 247: train D loss: 0.5759, train F loss: -0.1432, acc 0.9796
# epoch 248: train D loss: 0.5725, train F loss: -0.1431, acc 0.9826
# epoch 249: train D loss: 0.5750, train F loss: -0.1485, acc 0.9808
# epoch 250: train D loss: 0.5684, train F loss: -0.1433, acc 0.9808
# epoch 251: train D loss: 0.5788, train F loss: -0.1401, acc 0.9772
# epoch 252: train D loss: 0.5837, train F loss: -0.1522, acc 0.9814
# epoch 253: train D loss: 0.5906, train F loss: -0.1591, acc 0.9842
# epoch 254: train D loss: 0.5767, train F loss: -0.1625, acc 0.9838
# epoch 255: train D loss: 0.5853, train F loss: -0.1521, acc 0.9786
# epoch 256: train D loss: 0.5905, train F loss: -0.1600, acc 0.9814
# epoch 257: train D loss: 0.5847, train F loss: -0.1366, acc 0.9804
# epoch 258: train D loss: 0.5801, train F loss: -0.1497, acc 0.9796
# epoch 259: train D loss: 0.5792, train F loss: -0.1645, acc 0.9836
# epoch 260: train D loss: 0.5824, train F loss: -0.1523, acc 0.9796
# epoch 261: train D loss: 0.5832, train F loss: -0.1658, acc 0.9842
# epoch 262: train D loss: 0.5858, train F loss: -0.1474, acc 0.9800
# epoch 263: train D loss: 0.5942, train F loss: -0.1405, acc 0.9798
# epoch 264: train D loss: 0.5843, train F loss: -0.1666, acc 0.9830
# epoch 265: train D loss: 0.5848, train F loss: -0.1553, acc 0.9808
# epoch 266: train D loss: 0.5963, train F loss: -0.1681, acc 0.9816
# epoch 267: train D loss: 0.5822, train F loss: -0.1609, acc 0.9822
# epoch 268: train D loss: 0.5879, train F loss: -0.1650, acc 0.9828
# epoch 269: train D loss: 0.5921, train F loss: -0.1766, acc 0.9848
# epoch 270: train D loss: 0.5853, train F loss: -0.1624, acc 0.9822
# epoch 271: train D loss: 0.5793, train F loss: -0.1612, acc 0.9814
# epoch 272: train D loss: 0.5916, train F loss: -0.1770, acc 0.9852
# epoch 273: train D loss: 0.6000, train F loss: -0.1824, acc 0.9818
# epoch 274: train D loss: 0.5929, train F loss: -0.1720, acc 0.9810
# epoch 275: train D loss: 0.5931, train F loss: -0.1663, acc 0.9820
# epoch 276: train D loss: 0.6011, train F loss: -0.1717, acc 0.9804
# epoch 277: train D loss: 0.5973, train F loss: -0.1832, acc 0.9836
# epoch 278: train D loss: 0.5917, train F loss: -0.1682, acc 0.9814
# epoch 279: train D loss: 0.6081, train F loss: -0.1662, acc 0.9778
# epoch 280: train D loss: 0.6040, train F loss: -0.1841, acc 0.9812
# epoch 281: train D loss: 0.6041, train F loss: -0.1835, acc 0.9832
# epoch 282: train D loss: 0.5967, train F loss: -0.1802, acc 0.9824
# epoch 283: train D loss: 0.5984, train F loss: -0.1946, acc 0.9858
# epoch 284: train D loss: 0.5976, train F loss: -0.1732, acc 0.9798
# epoch 285: train D loss: 0.6076, train F loss: -0.1856, acc 0.9830
# epoch 286: train D loss: 0.5999, train F loss: -0.1603, acc 0.9794
# epoch 287: train D loss: 0.6011, train F loss: -0.1832, acc 0.9800
# epoch 288: train D loss: 0.5938, train F loss: -0.1693, acc 0.9802
# epoch 289: train D loss: 0.5944, train F loss: -0.1976, acc 0.9868
# epoch 290: train D loss: 0.5953, train F loss: -0.1877, acc 0.9838
# epoch 291: train D loss: 0.6035, train F loss: -0.1899, acc 0.9838
# epoch 292: train D loss: 0.6074, train F loss: -0.1909, acc 0.9816
# epoch 293: train D loss: 0.6074, train F loss: -0.1854, acc 0.9802
# epoch 294: train D loss: 0.6056, train F loss: -0.1917, acc 0.9818
# epoch 295: train D loss: 0.6039, train F loss: -0.1856, acc 0.9824
# epoch 296: train D loss: 0.6045, train F loss: -0.1853, acc 0.9806
# epoch 297: train D loss: 0.6000, train F loss: -0.1973, acc 0.9848
# epoch 298: train D loss: 0.6044, train F loss: -0.2016, acc 0.9864
# epoch 299: train D loss: 0.6044, train F loss: -0.2016, acc 0.9838
# epoch 300: train D loss: 0.6010, train F loss: -0.1970, acc 0.9850
# epoch 301: train D loss: 0.5979, train F loss: -0.1897, acc 0.9828
# epoch 302: train D loss: 0.6013, train F loss: -0.1956, acc 0.9846
# epoch 303: train D loss: 0.6060, train F loss: -0.2003, acc 0.9834
# epoch 304: train D loss: 0.5976, train F loss: -0.1799, acc 0.9782
# epoch 305: train D loss: 0.6056, train F loss: -0.2053, acc 0.9840
# epoch 306: train D loss: 0.6144, train F loss: -0.1967, acc 0.9820
# epoch 307: train D loss: 0.6096, train F loss: -0.2000, acc 0.9816
# epoch 308: train D loss: 0.6012, train F loss: -0.2109, acc 0.9866
# epoch 309: train D loss: 0.6030, train F loss: -0.1962, acc 0.9810
# epoch 310: train D loss: 0.6050, train F loss: -0.2090, acc 0.9844
# epoch 311: train D loss: 0.6021, train F loss: -0.2054, acc 0.9832
# epoch 312: train D loss: 0.6037, train F loss: -0.1971, acc 0.9806
# epoch 313: train D loss: 0.6071, train F loss: -0.1976, acc 0.9804
# epoch 314: train D loss: 0.6088, train F loss: -0.2052, acc 0.9824
# epoch 315: train D loss: 0.6136, train F loss: -0.2142, acc 0.9826
# epoch 316: train D loss: 0.5970, train F loss: -0.2022, acc 0.9830
# epoch 317: train D loss: 0.6130, train F loss: -0.2087, acc 0.9832
# epoch 318: train D loss: 0.6105, train F loss: -0.2159, acc 0.9848
# epoch 319: train D loss: 0.6179, train F loss: -0.2056, acc 0.9824
# epoch 320: train D loss: 0.6122, train F loss: -0.2121, acc 0.9822
# epoch 321: train D loss: 0.6032, train F loss: -0.2087, acc 0.9838
# epoch 322: train D loss: 0.6043, train F loss: -0.2047, acc 0.9822
# epoch 323: train D loss: 0.6023, train F loss: -0.2048, acc 0.9814
# epoch 324: train D loss: 0.6041, train F loss: -0.2099, acc 0.9824
# epoch 325: train D loss: 0.6097, train F loss: -0.2078, acc 0.9794
# epoch 326: train D loss: 0.6157, train F loss: -0.2215, acc 0.9840
# epoch 327: train D loss: 0.6057, train F loss: -0.2295, acc 0.9876
# epoch 328: train D loss: 0.6117, train F loss: -0.2165, acc 0.9836
# epoch 329: train D loss: 0.6068, train F loss: -0.2170, acc 0.9844
# epoch 330: train D loss: 0.6198, train F loss: -0.2257, acc 0.9838
# epoch 331: train D loss: 0.6116, train F loss: -0.2355, acc 0.9872
# epoch 332: train D loss: 0.6178, train F loss: -0.2221, acc 0.9806
# epoch 333: train D loss: 0.6105, train F loss: -0.2212, acc 0.9826
# epoch 334: train D loss: 0.6129, train F loss: -0.2155, acc 0.9784
# epoch 335: train D loss: 0.6162, train F loss: -0.2202, acc 0.9818
# epoch 336: train D loss: 0.6193, train F loss: -0.2337, acc 0.9882
# epoch 337: train D loss: 0.6178, train F loss: -0.2200, acc 0.9808
# epoch 338: train D loss: 0.6133, train F loss: -0.2270, acc 0.9830
# epoch 339: train D loss: 0.6070, train F loss: -0.2254, acc 0.9854
# epoch 340: train D loss: 0.6097, train F loss: -0.2314, acc 0.9854
# epoch 341: train D loss: 0.6181, train F loss: -0.2343, acc 0.9840
# epoch 342: train D loss: 0.6172, train F loss: -0.2359, acc 0.9856
# epoch 343: train D loss: 0.6189, train F loss: -0.2219, acc 0.9822
# epoch 344: train D loss: 0.6248, train F loss: -0.2393, acc 0.9840
# epoch 345: train D loss: 0.6097, train F loss: -0.2337, acc 0.9838
# epoch 346: train D loss: 0.6220, train F loss: -0.2409, acc 0.9836
# epoch 347: train D loss: 0.6119, train F loss: -0.2269, acc 0.9824
# epoch 348: train D loss: 0.6210, train F loss: -0.2371, acc 0.9838
# epoch 349: train D loss: 0.6148, train F loss: -0.2443, acc 0.9872
# epoch 350: train D loss: 0.6237, train F loss: -0.2319, acc 0.9792
# epoch 351: train D loss: 0.6230, train F loss: -0.2391, acc 0.9846
# epoch 352: train D loss: 0.6136, train F loss: -0.2481, acc 0.9860
# epoch 353: train D loss: 0.6220, train F loss: -0.2317, acc 0.9842
# epoch 354: train D loss: 0.6196, train F loss: -0.2362, acc 0.9810
# epoch 355: train D loss: 0.6122, train F loss: -0.2422, acc 0.9860
# epoch 356: train D loss: 0.6208, train F loss: -0.2500, acc 0.9832
# epoch 357: train D loss: 0.6205, train F loss: -0.2459, acc 0.9832
# epoch 358: train D loss: 0.6163, train F loss: -0.2414, acc 0.9848
# epoch 359: train D loss: 0.6146, train F loss: -0.2417, acc 0.9830
# epoch 360: train D loss: 0.6117, train F loss: -0.2451, acc 0.9846
# epoch 361: train D loss: 0.6224, train F loss: -0.2516, acc 0.9852
# epoch 362: train D loss: 0.6227, train F loss: -0.2491, acc 0.9840
# epoch 363: train D loss: 0.6215, train F loss: -0.2502, acc 0.9840
# epoch 364: train D loss: 0.6218, train F loss: -0.2449, acc 0.9838
# epoch 365: train D loss: 0.6121, train F loss: -0.2475, acc 0.9848
# epoch 366: train D loss: 0.6205, train F loss: -0.2501, acc 0.9848
# epoch 367: train D loss: 0.6284, train F loss: -0.2519, acc 0.9834
# epoch 368: train D loss: 0.6245, train F loss: -0.2616, acc 0.9878
# epoch 369: train D loss: 0.6130, train F loss: -0.2480, acc 0.9858
# epoch 370: train D loss: 0.6261, train F loss: -0.2501, acc 0.9848
# epoch 371: train D loss: 0.6199, train F loss: -0.2648, acc 0.9874
# epoch 372: train D loss: 0.6199, train F loss: -0.2629, acc 0.9870
# epoch 373: train D loss: 0.6318, train F loss: -0.2625, acc 0.9846
# epoch 374: train D loss: 0.6346, train F loss: -0.2618, acc 0.9834
# epoch 375: train D loss: 0.6262, train F loss: -0.2589, acc 0.9834
# epoch 376: train D loss: 0.6305, train F loss: -0.2686, acc 0.9866
# epoch 377: train D loss: 0.6206, train F loss: -0.2563, acc 0.9856
# epoch 378: train D loss: 0.6260, train F loss: -0.2664, acc 0.9860
# epoch 379: train D loss: 0.6281, train F loss: -0.2684, acc 0.9862
# epoch 380: train D loss: 0.6326, train F loss: -0.2679, acc 0.9836
# epoch 381: train D loss: 0.6239, train F loss: -0.2594, acc 0.9842
# epoch 382: train D loss: 0.6241, train F loss: -0.2609, acc 0.9842
# epoch 383: train D loss: 0.6255, train F loss: -0.2671, acc 0.9848
# epoch 384: train D loss: 0.6199, train F loss: -0.2622, acc 0.9852
# epoch 385: train D loss: 0.6213, train F loss: -0.2639, acc 0.9828
# epoch 386: train D loss: 0.6321, train F loss: -0.2703, acc 0.9852
# epoch 387: train D loss: 0.6284, train F loss: -0.2763, acc 0.9856
# epoch 388: train D loss: 0.6310, train F loss: -0.2724, acc 0.9848
# epoch 389: train D loss: 0.6311, train F loss: -0.2690, acc 0.9842
# epoch 390: train D loss: 0.6309, train F loss: -0.2729, acc 0.9852
# epoch 391: train D loss: 0.6249, train F loss: -0.2510, acc 0.9820
# epoch 392: train D loss: 0.6299, train F loss: -0.2759, acc 0.9862
# epoch 393: train D loss: 0.6211, train F loss: -0.2681, acc 0.9832
# epoch 394: train D loss: 0.6227, train F loss: -0.2757, acc 0.9864
# epoch 395: train D loss: 0.6175, train F loss: -0.2652, acc 0.9874
# epoch 396: train D loss: 0.6248, train F loss: -0.2588, acc 0.9816
# epoch 397: train D loss: 0.6366, train F loss: -0.2858, acc 0.9868
# epoch 398: train D loss: 0.6291, train F loss: -0.2675, acc 0.9816
# epoch 399: train D loss: 0.6262, train F loss: -0.2800, acc 0.9850
# epoch 400: train D loss: 0.6315, train F loss: -0.2790, acc 0.9836
# epoch 401: train D loss: 0.6261, train F loss: -0.2622, acc 0.9794
# epoch 402: train D loss: 0.6183, train F loss: -0.2780, acc 0.9866
# epoch 403: train D loss: 0.6280, train F loss: -0.2819, acc 0.9880
# epoch 404: train D loss: 0.6280, train F loss: -0.2913, acc 0.9900
# epoch 405: train D loss: 0.6309, train F loss: -0.2775, acc 0.9810
# epoch 406: train D loss: 0.6245, train F loss: -0.2856, acc 0.9856
# epoch 407: train D loss: 0.6258, train F loss: -0.2925, acc 0.9888
# epoch 408: train D loss: 0.6203, train F loss: -0.2711, acc 0.9842
# epoch 409: train D loss: 0.6276, train F loss: -0.2860, acc 0.9856
# epoch 410: train D loss: 0.6280, train F loss: -0.2852, acc 0.9868
# epoch 411: train D loss: 0.6313, train F loss: -0.2730, acc 0.9838
# epoch 412: train D loss: 0.6289, train F loss: -0.2847, acc 0.9838
# epoch 413: train D loss: 0.6277, train F loss: -0.2916, acc 0.9854
# epoch 414: train D loss: 0.6288, train F loss: -0.2838, acc 0.9840
# epoch 415: train D loss: 0.6249, train F loss: -0.2808, acc 0.9848
# epoch 416: train D loss: 0.6324, train F loss: -0.2936, acc 0.9856
# epoch 417: train D loss: 0.6360, train F loss: -0.2973, acc 0.9852
# epoch 418: train D loss: 0.6293, train F loss: -0.2957, acc 0.9856
# epoch 419: train D loss: 0.6330, train F loss: -0.2965, acc 0.9864
# epoch 420: train D loss: 0.6325, train F loss: -0.2978, acc 0.9868
# epoch 421: train D loss: 0.6335, train F loss: -0.2983, acc 0.9862
# epoch 422: train D loss: 0.6336, train F loss: -0.2943, acc 0.9840
# epoch 423: train D loss: 0.6408, train F loss: -0.3086, acc 0.9870
# epoch 424: train D loss: 0.6315, train F loss: -0.3001, acc 0.9864
# epoch 425: train D loss: 0.6359, train F loss: -0.2940, acc 0.9840
# epoch 426: train D loss: 0.6302, train F loss: -0.3059, acc 0.9882
# epoch 427: train D loss: 0.6415, train F loss: -0.2956, acc 0.9838
# epoch 428: train D loss: 0.6290, train F loss: -0.2900, acc 0.9830
# epoch 429: train D loss: 0.6363, train F loss: -0.2919, acc 0.9850
# epoch 430: train D loss: 0.6383, train F loss: -0.3071, acc 0.9856
# epoch 431: train D loss: 0.6323, train F loss: -0.2961, acc 0.9822
# epoch 432: train D loss: 0.6290, train F loss: -0.2919, acc 0.9832
# epoch 433: train D loss: 0.6364, train F loss: -0.3094, acc 0.9864
# epoch 434: train D loss: 0.6274, train F loss: -0.2974, acc 0.9844
# epoch 435: train D loss: 0.6328, train F loss: -0.3026, acc 0.9852
# epoch 436: train D loss: 0.6274, train F loss: -0.3004, acc 0.9870
# epoch 437: train D loss: 0.6333, train F loss: -0.3153, acc 0.9888
# epoch 438: train D loss: 0.6364, train F loss: -0.3043, acc 0.9824
# epoch 439: train D loss: 0.6308, train F loss: -0.2968, acc 0.9848
# epoch 440: train D loss: 0.6345, train F loss: -0.3048, acc 0.9852
# epoch 441: train D loss: 0.6294, train F loss: -0.3005, acc 0.9832
# epoch 442: train D loss: 0.6353, train F loss: -0.3099, acc 0.9860
# epoch 443: train D loss: 0.6308, train F loss: -0.3121, acc 0.9878
# epoch 444: train D loss: 0.6413, train F loss: -0.3139, acc 0.9856
# epoch 445: train D loss: 0.6332, train F loss: -0.3051, acc 0.9836
# epoch 446: train D loss: 0.6332, train F loss: -0.3121, acc 0.9866
# epoch 447: train D loss: 0.6286, train F loss: -0.3007, acc 0.9832
# epoch 448: train D loss: 0.6335, train F loss: -0.3028, acc 0.9826
# epoch 449: train D loss: 0.6295, train F loss: -0.3097, acc 0.9852
# epoch 450: train D loss: 0.6342, train F loss: -0.3209, acc 0.9872
# epoch 451: train D loss: 0.6381, train F loss: -0.3229, acc 0.9876
# epoch 452: train D loss: 0.6340, train F loss: -0.3120, acc 0.9836
# epoch 453: train D loss: 0.6334, train F loss: -0.3131, acc 0.9868
# epoch 454: train D loss: 0.6315, train F loss: -0.3122, acc 0.9854
# epoch 455: train D loss: 0.6397, train F loss: -0.3254, acc 0.9856
# epoch 456: train D loss: 0.6275, train F loss: -0.3126, acc 0.9842
# epoch 457: train D loss: 0.6348, train F loss: -0.3176, acc 0.9866
# epoch 458: train D loss: 0.6346, train F loss: -0.3099, acc 0.9848
# epoch 459: train D loss: 0.6292, train F loss: -0.3192, acc 0.9868
# epoch 460: train D loss: 0.6364, train F loss: -0.3251, acc 0.9864
# epoch 461: train D loss: 0.6310, train F loss: -0.3203, acc 0.9870
# epoch 462: train D loss: 0.6309, train F loss: -0.3149, acc 0.9840
# epoch 463: train D loss: 0.6361, train F loss: -0.3330, acc 0.9888
# epoch 464: train D loss: 0.6416, train F loss: -0.3378, acc 0.9890
# epoch 465: train D loss: 0.6384, train F loss: -0.3212, acc 0.9850
# epoch 466: train D loss: 0.6377, train F loss: -0.3314, acc 0.9878
# epoch 467: train D loss: 0.6386, train F loss: -0.3268, acc 0.9862
# epoch 468: train D loss: 0.6399, train F loss: -0.3224, acc 0.9836
# epoch 469: train D loss: 0.6328, train F loss: -0.3107, acc 0.9840
# epoch 470: train D loss: 0.6414, train F loss: -0.3307, acc 0.9854
# epoch 471: train D loss: 0.6385, train F loss: -0.3283, acc 0.9858
# epoch 472: train D loss: 0.6391, train F loss: -0.3313, acc 0.9852
# epoch 473: train D loss: 0.6388, train F loss: -0.3323, acc 0.9872
# epoch 474: train D loss: 0.6451, train F loss: -0.3341, acc 0.9848
# epoch 475: train D loss: 0.6399, train F loss: -0.3460, acc 0.9890
# epoch 476: train D loss: 0.6438, train F loss: -0.3362, acc 0.9862
# epoch 477: train D loss: 0.6341, train F loss: -0.3318, acc 0.9850
# epoch 478: train D loss: 0.6353, train F loss: -0.3351, acc 0.9888
# epoch 479: train D loss: 0.6397, train F loss: -0.3358, acc 0.9866
# epoch 480: train D loss: 0.6426, train F loss: -0.3435, acc 0.9868
# epoch 481: train D loss: 0.6406, train F loss: -0.3405, acc 0.9878
# epoch 482: train D loss: 0.6462, train F loss: -0.3392, acc 0.9850
# epoch 483: train D loss: 0.6380, train F loss: -0.3398, acc 0.9868
# epoch 484: train D loss: 0.6347, train F loss: -0.3426, acc 0.9880
# epoch 485: train D loss: 0.6443, train F loss: -0.3457, acc 0.9862
# epoch 486: train D loss: 0.6420, train F loss: -0.3433, acc 0.9872
# epoch 487: train D loss: 0.6407, train F loss: -0.3413, acc 0.9866
# epoch 488: train D loss: 0.6378, train F loss: -0.3339, acc 0.9850
# epoch 489: train D loss: 0.6359, train F loss: -0.3409, acc 0.9860
# epoch 490: train D loss: 0.6431, train F loss: -0.3469, acc 0.9864
# epoch 491: train D loss: 0.6399, train F loss: -0.3340, acc 0.9830
# epoch 492: train D loss: 0.6407, train F loss: -0.3513, acc 0.9870
# epoch 493: train D loss: 0.6417, train F loss: -0.3425, acc 0.9850
# epoch 494: train D loss: 0.6445, train F loss: -0.3422, acc 0.9844
# epoch 495: train D loss: 0.6372, train F loss: -0.3523, acc 0.9884
# epoch 496: train D loss: 0.6386, train F loss: -0.3400, acc 0.9854
# epoch 497: train D loss: 0.6457, train F loss: -0.3360, acc 0.9820
# epoch 498: train D loss: 0.6418, train F loss: -0.3440, acc 0.9860
# epoch 499: train D loss: 0.6399, train F loss: -0.3439, acc 0.9858
# epoch 500: train D loss: 0.6367, train F loss: -0.3535, acc 0.9880
# epoch 501: train D loss: 0.6384, train F loss: -0.3429, acc 0.9844
# epoch 502: train D loss: 0.6422, train F loss: -0.3457, acc 0.9872
# epoch 503: train D loss: 0.6426, train F loss: -0.3546, acc 0.9868
# epoch 504: train D loss: 0.6444, train F loss: -0.3667, acc 0.9894
# epoch 505: train D loss: 0.6448, train F loss: -0.3486, acc 0.9846
# epoch 506: train D loss: 0.6465, train F loss: -0.3561, acc 0.9852
# epoch 507: train D loss: 0.6403, train F loss: -0.3568, acc 0.9866
# epoch 508: train D loss: 0.6448, train F loss: -0.3598, acc 0.9874
# epoch 509: train D loss: 0.6452, train F loss: -0.3673, acc 0.9880
# epoch 510: train D loss: 0.6396, train F loss: -0.3538, acc 0.9852
# epoch 511: train D loss: 0.6468, train F loss: -0.3603, acc 0.9884
# epoch 512: train D loss: 0.6418, train F loss: -0.3499, acc 0.9844
# epoch 513: train D loss: 0.6416, train F loss: -0.3633, acc 0.9882
# epoch 514: train D loss: 0.6427, train F loss: -0.3577, acc 0.9872
# epoch 515: train D loss: 0.6457, train F loss: -0.3563, acc 0.9848
# epoch 516: train D loss: 0.6472, train F loss: -0.3588, acc 0.9856
# epoch 517: train D loss: 0.6415, train F loss: -0.3651, acc 0.9872
# epoch 518: train D loss: 0.6458, train F loss: -0.3653, acc 0.9866
# epoch 519: train D loss: 0.6471, train F loss: -0.3630, acc 0.9844
# epoch 520: train D loss: 0.6467, train F loss: -0.3721, acc 0.9868
# epoch 521: train D loss: 0.6474, train F loss: -0.3684, acc 0.9880
# epoch 522: train D loss: 0.6525, train F loss: -0.3715, acc 0.9864
# epoch 523: train D loss: 0.6475, train F loss: -0.3753, acc 0.9886
# epoch 524: train D loss: 0.6498, train F loss: -0.3679, acc 0.9860
# epoch 525: train D loss: 0.6473, train F loss: -0.3698, acc 0.9878
# epoch 526: train D loss: 0.6438, train F loss: -0.3640, acc 0.9846
# epoch 527: train D loss: 0.6465, train F loss: -0.3693, acc 0.9860
# epoch 528: train D loss: 0.6449, train F loss: -0.3720, acc 0.9876
# epoch 529: train D loss: 0.6373, train F loss: -0.3674, acc 0.9878
# epoch 530: train D loss: 0.6470, train F loss: -0.3728, acc 0.9880
# epoch 531: train D loss: 0.6527, train F loss: -0.3826, acc 0.9880
# epoch 532: train D loss: 0.6472, train F loss: -0.3773, acc 0.9876
# epoch 533: train D loss: 0.6423, train F loss: -0.3746, acc 0.9878
# epoch 534: train D loss: 0.6417, train F loss: -0.3722, acc 0.9880
# epoch 535: train D loss: 0.6413, train F loss: -0.3710, acc 0.9880
# epoch 536: train D loss: 0.6495, train F loss: -0.3736, acc 0.9852
# epoch 537: train D loss: 0.6490, train F loss: -0.3737, acc 0.9850
# epoch 538: train D loss: 0.6469, train F loss: -0.3864, acc 0.9888
# epoch 539: train D loss: 0.6445, train F loss: -0.3775, acc 0.9864
# epoch 540: train D loss: 0.6466, train F loss: -0.3890, acc 0.9916
# epoch 541: train D loss: 0.6506, train F loss: -0.3687, acc 0.9858
# epoch 542: train D loss: 0.6384, train F loss: -0.3635, acc 0.9844
# epoch 543: train D loss: 0.6382, train F loss: -0.3704, acc 0.9878
# epoch 544: train D loss: 0.6520, train F loss: -0.3901, acc 0.9886
# epoch 545: train D loss: 0.6456, train F loss: -0.3858, acc 0.9872
# epoch 546: train D loss: 0.6454, train F loss: -0.3642, acc 0.9802
# epoch 547: train D loss: 0.6372, train F loss: -0.3813, acc 0.9890
# epoch 548: train D loss: 0.6467, train F loss: -0.3828, acc 0.9874
# epoch 549: train D loss: 0.6414, train F loss: -0.3864, acc 0.9884
# epoch 550: train D loss: 0.6443, train F loss: -0.3725, acc 0.9860
# epoch 551: train D loss: 0.6496, train F loss: -0.3872, acc 0.9880
# epoch 552: train D loss: 0.6504, train F loss: -0.3861, acc 0.9846
# epoch 553: train D loss: 0.6534, train F loss: -0.3764, acc 0.9834
# epoch 554: train D loss: 0.6409, train F loss: -0.3800, acc 0.9860
# epoch 555: train D loss: 0.6493, train F loss: -0.3816, acc 0.9854
# epoch 556: train D loss: 0.6490, train F loss: -0.3963, acc 0.9886
# epoch 557: train D loss: 0.6449, train F loss: -0.3958, acc 0.9910
# epoch 558: train D loss: 0.6413, train F loss: -0.3851, acc 0.9878
# epoch 559: train D loss: 0.6526, train F loss: -0.3900, acc 0.9868
# epoch 560: train D loss: 0.6502, train F loss: -0.3829, acc 0.9832
# epoch 561: train D loss: 0.6483, train F loss: -0.3882, acc 0.9856
# epoch 562: train D loss: 0.6443, train F loss: -0.3904, acc 0.9870
# epoch 563: train D loss: 0.6481, train F loss: -0.3862, acc 0.9858
# epoch 564: train D loss: 0.6437, train F loss: -0.3860, acc 0.9890
# epoch 565: train D loss: 0.6494, train F loss: -0.3883, acc 0.9850
# epoch 566: train D loss: 0.6447, train F loss: -0.3915, acc 0.9862
# epoch 567: train D loss: 0.6478, train F loss: -0.3999, acc 0.9876
# epoch 568: train D loss: 0.6478, train F loss: -0.3983, acc 0.9874
# epoch 569: train D loss: 0.6455, train F loss: -0.3908, acc 0.9858
# epoch 570: train D loss: 0.6547, train F loss: -0.4026, acc 0.9868
# epoch 571: train D loss: 0.6483, train F loss: -0.4016, acc 0.9874
# epoch 572: train D loss: 0.6521, train F loss: -0.3978, acc 0.9884
# epoch 573: train D loss: 0.6508, train F loss: -0.4076, acc 0.9878
# epoch 574: train D loss: 0.6547, train F loss: -0.3900, acc 0.9840
# epoch 575: train D loss: 0.6455, train F loss: -0.3965, acc 0.9872
# epoch 576: train D loss: 0.6515, train F loss: -0.4034, acc 0.9878
# epoch 577: train D loss: 0.6462, train F loss: -0.4013, acc 0.9880
# epoch 578: train D loss: 0.6469, train F loss: -0.4080, acc 0.9902
# epoch 579: train D loss: 0.6510, train F loss: -0.3959, acc 0.9860
# epoch 580: train D loss: 0.6464, train F loss: -0.3948, acc 0.9852
# epoch 581: train D loss: 0.6465, train F loss: -0.4044, acc 0.9894
# epoch 582: train D loss: 0.6553, train F loss: -0.4017, acc 0.9862
# epoch 583: train D loss: 0.6395, train F loss: -0.4004, acc 0.9866
# epoch 584: train D loss: 0.6477, train F loss: -0.4009, acc 0.9870
# epoch 585: train D loss: 0.6536, train F loss: -0.4060, acc 0.9864
# epoch 586: train D loss: 0.6476, train F loss: -0.4105, acc 0.9902
# epoch 587: train D loss: 0.6565, train F loss: -0.4122, acc 0.9874
# epoch 588: train D loss: 0.6488, train F loss: -0.4084, acc 0.9880
# epoch 589: train D loss: 0.6533, train F loss: -0.4099, acc 0.9874
# epoch 590: train D loss: 0.6532, train F loss: -0.4165, acc 0.9874
# epoch 591: train D loss: 0.6569, train F loss: -0.4037, acc 0.9854
# epoch 592: train D loss: 0.6442, train F loss: -0.4097, acc 0.9900
# epoch 593: train D loss: 0.6500, train F loss: -0.4091, acc 0.9858
# epoch 594: train D loss: 0.6492, train F loss: -0.4095, acc 0.9862
# epoch 595: train D loss: 0.6503, train F loss: -0.4166, acc 0.9888
# epoch 596: train D loss: 0.6468, train F loss: -0.4211, acc 0.9900
# epoch 597: train D loss: 0.6516, train F loss: -0.4117, acc 0.9866
# epoch 598: train D loss: 0.6518, train F loss: -0.4148, acc 0.9886
# epoch 599: train D loss: 0.6484, train F loss: -0.4181, acc 0.9892
# epoch 600: train D loss: 0.6559, train F loss: -0.4204, acc 0.9892
# epoch 601: train D loss: 0.6574, train F loss: -0.4163, acc 0.9870
# epoch 602: train D loss: 0.6488, train F loss: -0.4185, acc 0.9888
# epoch 603: train D loss: 0.6529, train F loss: -0.4173, acc 0.9862
# epoch 604: train D loss: 0.6529, train F loss: -0.4161, acc 0.9888
# epoch 605: train D loss: 0.6489, train F loss: -0.4210, acc 0.9866
# epoch 606: train D loss: 0.6557, train F loss: -0.4099, acc 0.9858
# epoch 607: train D loss: 0.6573, train F loss: -0.4323, acc 0.9888
# epoch 608: train D loss: 0.6455, train F loss: -0.4132, acc 0.9858
# epoch 609: train D loss: 0.6476, train F loss: -0.4206, acc 0.9894
# epoch 610: train D loss: 0.6471, train F loss: -0.4200, acc 0.9878
# epoch 611: train D loss: 0.6553, train F loss: -0.4283, acc 0.9894
# epoch 612: train D loss: 0.6571, train F loss: -0.4326, acc 0.9874
# epoch 613: train D loss: 0.6563, train F loss: -0.4253, acc 0.9862
# epoch 614: train D loss: 0.6562, train F loss: -0.4276, acc 0.9884
# epoch 615: train D loss: 0.6466, train F loss: -0.4118, acc 0.9852
# epoch 616: train D loss: 0.6495, train F loss: -0.4295, acc 0.9888
# epoch 617: train D loss: 0.6550, train F loss: -0.4251, acc 0.9862
# epoch 618: train D loss: 0.6499, train F loss: -0.4185, acc 0.9870
# epoch 619: train D loss: 0.6574, train F loss: -0.4323, acc 0.9898
# epoch 620: train D loss: 0.6501, train F loss: -0.4260, acc 0.9876
# epoch 621: train D loss: 0.6542, train F loss: -0.4257, acc 0.9846
# epoch 622: train D loss: 0.6445, train F loss: -0.3848, acc 0.9812
# epoch 623: train D loss: 0.6548, train F loss: -0.4278, acc 0.9876
# epoch 624: train D loss: 0.6518, train F loss: -0.4366, acc 0.9894
# epoch 625: train D loss: 0.6542, train F loss: -0.4336, acc 0.9872
# epoch 626: train D loss: 0.6490, train F loss: -0.4325, acc 0.9874
# epoch 627: train D loss: 0.6516, train F loss: -0.4363, acc 0.9886
# epoch 628: train D loss: 0.6497, train F loss: -0.4257, acc 0.9862
# epoch 629: train D loss: 0.6498, train F loss: -0.4216, acc 0.9828
# epoch 630: train D loss: 0.6553, train F loss: -0.4369, acc 0.9858
# epoch 631: train D loss: 0.6572, train F loss: -0.4368, acc 0.9896
# epoch 632: train D loss: 0.6561, train F loss: -0.4325, acc 0.9856
# epoch 633: train D loss: 0.6458, train F loss: -0.4356, acc 0.9894
# epoch 634: train D loss: 0.6493, train F loss: -0.4363, acc 0.9878
# epoch 635: train D loss: 0.6564, train F loss: -0.4343, acc 0.9858
# epoch 636: train D loss: 0.6549, train F loss: -0.4376, acc 0.9890
# epoch 637: train D loss: 0.6543, train F loss: -0.4438, acc 0.9900
# epoch 638: train D loss: 0.6605, train F loss: -0.4432, acc 0.9886
# epoch 639: train D loss: 0.6548, train F loss: -0.4510, acc 0.9904
# epoch 640: train D loss: 0.6506, train F loss: -0.4406, acc 0.9888
# epoch 641: train D loss: 0.6567, train F loss: -0.4423, acc 0.9876
# epoch 642: train D loss: 0.6562, train F loss: -0.4368, acc 0.9850
# epoch 643: train D loss: 0.6524, train F loss: -0.4389, acc 0.9904
# epoch 644: train D loss: 0.6588, train F loss: -0.4456, acc 0.9860
# epoch 645: train D loss: 0.6517, train F loss: -0.4541, acc 0.9914
# epoch 646: train D loss: 0.6551, train F loss: -0.4436, acc 0.9878
# epoch 647: train D loss: 0.6593, train F loss: -0.4495, acc 0.9886
# epoch 648: train D loss: 0.6505, train F loss: -0.4388, acc 0.9858
# epoch 649: train D loss: 0.6563, train F loss: -0.4477, acc 0.9882
# epoch 650: train D loss: 0.6553, train F loss: -0.4477, acc 0.9866
# epoch 651: train D loss: 0.6634, train F loss: -0.4529, acc 0.9866
# epoch 652: train D loss: 0.6523, train F loss: -0.4413, acc 0.9890
# epoch 653: train D loss: 0.6536, train F loss: -0.4381, acc 0.9878
# epoch 654: train D loss: 0.6496, train F loss: -0.4489, acc 0.9896
# epoch 655: train D loss: 0.6531, train F loss: -0.4431, acc 0.9854
# epoch 656: train D loss: 0.6520, train F loss: -0.4485, acc 0.9888
# epoch 657: train D loss: 0.6539, train F loss: -0.4226, acc 0.9828
# epoch 658: train D loss: 0.6568, train F loss: -0.4496, acc 0.9874
# epoch 659: train D loss: 0.6543, train F loss: -0.4556, acc 0.9874
# epoch 660: train D loss: 0.6474, train F loss: -0.4439, acc 0.9892
# epoch 661: train D loss: 0.6483, train F loss: -0.4435, acc 0.9866
# epoch 662: train D loss: 0.6560, train F loss: -0.4594, acc 0.9902
# epoch 663: train D loss: 0.6547, train F loss: -0.4599, acc 0.9894
# epoch 664: train D loss: 0.6520, train F loss: -0.4598, acc 0.9904
# epoch 665: train D loss: 0.6536, train F loss: -0.4467, acc 0.9868
# epoch 666: train D loss: 0.6522, train F loss: -0.4487, acc 0.9870
# epoch 667: train D loss: 0.6572, train F loss: -0.4548, acc 0.9856
# epoch 668: train D loss: 0.6606, train F loss: -0.4678, acc 0.9900
# epoch 669: train D loss: 0.6590, train F loss: -0.4546, acc 0.9854
# epoch 670: train D loss: 0.6615, train F loss: -0.4672, acc 0.9880
# epoch 671: train D loss: 0.6572, train F loss: -0.4547, acc 0.9856
# epoch 672: train D loss: 0.6558, train F loss: -0.4617, acc 0.9890
# epoch 673: train D loss: 0.6586, train F loss: -0.4578, acc 0.9852
# epoch 674: train D loss: 0.6572, train F loss: -0.4670, acc 0.9890
# epoch 675: train D loss: 0.6557, train F loss: -0.4586, acc 0.9866
# epoch 676: train D loss: 0.6506, train F loss: -0.4514, acc 0.9878
# epoch 677: train D loss: 0.6537, train F loss: -0.4707, acc 0.9918
# epoch 678: train D loss: 0.6585, train F loss: -0.4674, acc 0.9876
# epoch 679: train D loss: 0.6530, train F loss: -0.4609, acc 0.9864
# epoch 680: train D loss: 0.6544, train F loss: -0.4615, acc 0.9886
# epoch 681: train D loss: 0.6531, train F loss: -0.4572, acc 0.9874
# epoch 682: train D loss: 0.6485, train F loss: -0.4669, acc 0.9908
# epoch 683: train D loss: 0.6564, train F loss: -0.4705, acc 0.9894
# epoch 684: train D loss: 0.6510, train F loss: -0.4577, acc 0.9878
# epoch 685: train D loss: 0.6606, train F loss: -0.4669, acc 0.9868
# epoch 686: train D loss: 0.6559, train F loss: -0.4708, acc 0.9884
# epoch 687: train D loss: 0.6597, train F loss: -0.4648, acc 0.9868
# epoch 688: train D loss: 0.6525, train F loss: -0.4719, acc 0.9890
# epoch 689: train D loss: 0.6603, train F loss: -0.4736, acc 0.9876
# epoch 690: train D loss: 0.6599, train F loss: -0.4716, acc 0.9874
# epoch 691: train D loss: 0.6551, train F loss: -0.4738, acc 0.9884
# epoch 692: train D loss: 0.6622, train F loss: -0.4670, acc 0.9840
# epoch 693: train D loss: 0.6485, train F loss: -0.4632, acc 0.9882
# epoch 694: train D loss: 0.6576, train F loss: -0.4643, acc 0.9880
# epoch 695: train D loss: 0.6605, train F loss: -0.4862, acc 0.9924
# epoch 696: train D loss: 0.6582, train F loss: -0.4590, acc 0.9836
# epoch 697: train D loss: 0.6590, train F loss: -0.4811, acc 0.9898
# epoch 698: train D loss: 0.6659, train F loss: -0.4809, acc 0.9886
# epoch 699: train D loss: 0.6558, train F loss: -0.4762, acc 0.9862
# epoch 700: train D loss: 0.6590, train F loss: -0.4741, acc 0.9876
# epoch 701: train D loss: 0.6603, train F loss: -0.4914, acc 0.9916
# epoch 702: train D loss: 0.6627, train F loss: -0.4832, acc 0.9876
# epoch 703: train D loss: 0.6518, train F loss: -0.4690, acc 0.9888
# epoch 704: train D loss: 0.6542, train F loss: -0.4702, acc 0.9852
# epoch 705: train D loss: 0.6535, train F loss: -0.4794, acc 0.9890
# epoch 706: train D loss: 0.6685, train F loss: -0.4806, acc 0.9860
# epoch 707: train D loss: 0.6587, train F loss: -0.4844, acc 0.9894
# epoch 708: train D loss: 0.6549, train F loss: -0.4678, acc 0.9870
# epoch 709: train D loss: 0.6632, train F loss: -0.4893, acc 0.9884
# epoch 710: train D loss: 0.6612, train F loss: -0.4879, acc 0.9896
# epoch 711: train D loss: 0.6589, train F loss: -0.4891, acc 0.9900
# epoch 712: train D loss: 0.6605, train F loss: -0.4838, acc 0.9876
# epoch 713: train D loss: 0.6618, train F loss: -0.4882, acc 0.9896
# epoch 714: train D loss: 0.6540, train F loss: -0.4928, acc 0.9914
# epoch 715: train D loss: 0.6594, train F loss: -0.4911, acc 0.9906
# epoch 716: train D loss: 0.6567, train F loss: -0.4568, acc 0.9848
# ...
# epoch 762: train D loss: 0.6652, train F loss: -0.5186, acc 0.9896
# epoch 763: train D loss: 0.6619, train F loss: -0.5189, acc 0.9910
# epoch 764: train D loss: 0.6575, train F loss: -0.5158, acc 0.9888
# epoch 765: train D loss: 0.6559, train F loss: -0.4966, acc 0.9870
# epoch 766: train D loss: 0.6696, train F loss: -0.5095, acc 0.9876
# epoch 767: train D loss: 0.6627, train F loss: -0.5212, acc 0.9888
# epoch 768: train D loss: 0.6662, train F loss: -0.5224, acc 0.9882
# epoch 769: train D loss: 0.6628, train F loss: -0.5193, acc 0.9886
# epoch 770: train D loss: 0.6607, train F loss: -0.5138, acc 0.9888
# epoch 771: train D loss: 0.6607, train F loss: -0.5093, acc 0.9886
# epoch 772: train D loss: 0.6675, train F loss: -0.5129, acc 0.9844
# epoch 773: train D loss: 0.6582, train F loss: -0.5078, acc 0.9896
# epoch 774: train D loss: 0.6695, train F loss: -0.5334, acc 0.9918
# epoch 775: train D loss: 0.6641, train F loss: -0.5244, acc 0.9894
# epoch 776: train D loss: 0.6641, train F loss: -0.5250, acc 0.9904
# epoch 777: train D loss: 0.6654, train F loss: -0.5242, acc 0.9892
# epoch 778: train D loss: 0.6637, train F loss: -0.5224, acc 0.9896
# epoch 779: train D loss: 0.6610, train F loss: -0.5097, acc 0.9874
# epoch 780: train D loss: 0.6603, train F loss: -0.5251, acc 0.9902
# epoch 781: train D loss: 0.6662, train F loss: -0.5143, acc 0.9866
# epoch 782: train D loss: 0.6577, train F loss: -0.5244, acc 0.9904
# epoch 783: train D loss: 0.6625, train F loss: -0.5097, acc 0.9856
# epoch 784: train D loss: 0.6561, train F loss: -0.5110, acc 0.9858
# epoch 785: train D loss: 0.6594, train F loss: -0.5222, acc 0.9898
# epoch 786: train D loss: 0.6647, train F loss: -0.5289, acc 0.9906
# epoch 787: train D loss: 0.6630, train F loss: -0.5316, acc 0.9912
# epoch 788: train D loss: 0.6693, train F loss: -0.5341, acc 0.9902
# epoch 789: train D loss: 0.6616, train F loss: -0.5130, acc 0.9836
# epoch 790: train D loss: 0.6645, train F loss: -0.5255, acc 0.9880
# epoch 791: train D loss: 0.6574, train F loss: -0.5207, acc 0.9884
# epoch 792: train D loss: 0.6575, train F loss: -0.5260, acc 0.9910
# epoch 793: train D loss: 0.6650, train F loss: -0.5272, acc 0.9900
# epoch 794: train D loss: 0.6608, train F loss: -0.5212, acc 0.9884
# epoch 795: train D loss: 0.6633, train F loss: -0.5242, acc 0.9896
# epoch 796: train D loss: 0.6647, train F loss: -0.5326, acc 0.9896
# epoch 797: train D loss: 0.6628, train F loss: -0.5313, acc 0.9886
# epoch 798: train D loss: 0.6599, train F loss: -0.5235, acc 0.9868
# epoch 799: train D loss: 0.6628, train F loss: -0.5296, acc 0.9884
# epoch 800: train D loss: 0.6669, train F loss: -0.5410, acc 0.9902
# epoch 801: train D loss: 0.6603, train F loss: -0.5265, acc 0.9892
# epoch 802: train D loss: 0.6593, train F loss: -0.5264, acc 0.9882
# epoch 803: train D loss: 0.6610, train F loss: -0.5267, acc 0.9874
# epoch 804: train D loss: 0.6611, train F loss: -0.5328, acc 0.9888
# epoch 805: train D loss: 0.6662, train F loss: -0.5255, acc 0.9874
# epoch 806: train D loss: 0.6660, train F loss: -0.5453, acc 0.9902
# epoch 807: train D loss: 0.6655, train F loss: -0.5456, acc 0.9892
# epoch 808: train D loss: 0.6650, train F loss: -0.5438, acc 0.9900
# epoch 809: train D loss: 0.6674, train F loss: -0.5414, acc 0.9884
# epoch 810: train D loss: 0.6635, train F loss: -0.5335, acc 0.9882
# epoch 811: train D loss: 0.6653, train F loss: -0.5395, acc 0.9896
# epoch 812: train D loss: 0.6611, train F loss: -0.5328, acc 0.9878
# epoch 813: train D loss: 0.6665, train F loss: -0.5384, acc 0.9880
# epoch 814: train D loss: 0.6629, train F loss: -0.5335, acc 0.9884
# epoch 815: train D loss: 0.6610, train F loss: -0.5400, acc 0.9898
# epoch 816: train D loss: 0.6624, train F loss: -0.5340, acc 0.9882
# epoch 817: train D loss: 0.6631, train F loss: -0.5438, acc 0.9916
# epoch 818: train D loss: 0.6642, train F loss: -0.5319, acc 0.9856
# epoch 819: train D loss: 0.6670, train F loss: -0.5400, acc 0.9884
# epoch 820: train D loss: 0.6634, train F loss: -0.5314, acc 0.9876
# epoch 821: train D loss: 0.6599, train F loss: -0.5428, acc 0.9896
# epoch 822: train D loss: 0.6611, train F loss: -0.5432, acc 0.9912
# epoch 823: train D loss: 0.6599, train F loss: -0.5450, acc 0.9908
# epoch 824: train D loss: 0.6610, train F loss: -0.5404, acc 0.9890
# epoch 825: train D loss: 0.6659, train F loss: -0.5473, acc 0.9886
# epoch 826: train D loss: 0.6672, train F loss: -0.5561, acc 0.9918
# epoch 827: train D loss: 0.6658, train F loss: -0.5424, acc 0.9894
# epoch 828: train D loss: 0.6648, train F loss: -0.5435, acc 0.9872
# epoch 829: train D loss: 0.6645, train F loss: -0.5423, acc 0.9874
# epoch 830: train D loss: 0.6635, train F loss: -0.5512, acc 0.9896
# epoch 831: train D loss: 0.6651, train F loss: -0.5474, acc 0.9888
# epoch 832: train D loss: 0.6572, train F loss: -0.5484, acc 0.9906
# epoch 833: train D loss: 0.6601, train F loss: -0.5321, acc 0.9878
# epoch 834: train D loss: 0.6648, train F loss: -0.5444, acc 0.9878
# epoch 835: train D loss: 0.6632, train F loss: -0.5413, acc 0.9886
# epoch 836: train D loss: 0.6642, train F loss: -0.5479, acc 0.9872
# epoch 837: train D loss: 0.6647, train F loss: -0.5444, acc 0.9878
# epoch 838: train D loss: 0.6626, train F loss: -0.5522, acc 0.9908
# epoch 839: train D loss: 0.6649, train F loss: -0.5528, acc 0.9884
# epoch 840: train D loss: 0.6637, train F loss: -0.5518, acc 0.9884
# epoch 841: train D loss: 0.6647, train F loss: -0.5575, acc 0.9900
# epoch 842: train D loss: 0.6638, train F loss: -0.5451, acc 0.9874
# epoch 843: train D loss: 0.6634, train F loss: -0.5514, acc 0.9888
# epoch 844: train D loss: 0.6599, train F loss: -0.5497, acc 0.9894
# epoch 845: train D loss: 0.6653, train F loss: -0.5582, acc 0.9916
# epoch 846: train D loss: 0.6688, train F loss: -0.5599, acc 0.9884
# epoch 847: train D loss: 0.6654, train F loss: -0.5565, acc 0.9874
# epoch 848: train D loss: 0.6655, train F loss: -0.5620, acc 0.9908
# epoch 849: train D loss: 0.6693, train F loss: -0.5601, acc 0.9878
# epoch 850: train D loss: 0.6648, train F loss: -0.5555, acc 0.9884
# epoch 851: train D loss: 0.6630, train F loss: -0.5533, acc 0.9894
# epoch 852: train D loss: 0.6628, train F loss: -0.5595, acc 0.9902
# epoch 853: train D loss: 0.6687, train F loss: -0.5714, acc 0.9904
# epoch 854: train D loss: 0.6626, train F loss: -0.5578, acc 0.9892
# epoch 855: train D loss: 0.6602, train F loss: -0.5569, acc 0.9912
# epoch 856: train D loss: 0.6729, train F loss: -0.5525, acc 0.9830
# epoch 857: train D loss: 0.6690, train F loss: -0.5760, acc 0.9920
# epoch 858: train D loss: 0.6608, train F loss: -0.5569, acc 0.9892
# epoch 859: train D loss: 0.6633, train F loss: -0.5527, acc 0.9890
# epoch 860: train D loss: 0.6667, train F loss: -0.5641, acc 0.9898
# epoch 861: train D loss: 0.6629, train F loss: -0.5599, acc 0.9892
# epoch 862: train D loss: 0.6656, train F loss: -0.5656, acc 0.9906
# epoch 863: train D loss: 0.6611, train F loss: -0.5276, acc 0.9852
# epoch 864: train D loss: 0.6548, train F loss: -0.5462, acc 0.9888
# epoch 865: train D loss: 0.6606, train F loss: -0.5545, acc 0.9896
# epoch 866: train D loss: 0.6587, train F loss: -0.5612, acc 0.9906
# epoch 867: train D loss: 0.6627, train F loss: -0.5576, acc 0.9886
# epoch 868: train D loss: 0.6653, train F loss: -0.5733, acc 0.9908
# epoch 869: train D loss: 0.6616, train F loss: -0.5507, acc 0.9858
# epoch 870: train D loss: 0.6651, train F loss: -0.5607, acc 0.9898
# epoch 871: train D loss: 0.6635, train F loss: -0.5733, acc 0.9926
# epoch 872: train D loss: 0.6644, train F loss: -0.5712, acc 0.9912
# epoch 873: train D loss: 0.6596, train F loss: -0.5676, acc 0.9906
# epoch 874: train D loss: 0.6596, train F loss: -0.5218, acc 0.9816
# epoch 875: train D loss: 0.6613, train F loss: -0.5658, acc 0.9872
# epoch 876: train D loss: 0.6612, train F loss: -0.5610, acc 0.9898
# epoch 877: train D loss: 0.6603, train F loss: -0.5643, acc 0.9890
# epoch 878: train D loss: 0.6582, train F loss: -0.5479, acc 0.9858
# epoch 879: train D loss: 0.6615, train F loss: -0.5518, acc 0.9870
# epoch 880: train D loss: 0.6625, train F loss: -0.5634, acc 0.9882
# epoch 881: train D loss: 0.6613, train F loss: -0.5551, acc 0.9882
# epoch 882: train D loss: 0.6605, train F loss: -0.5448, acc 0.9880
# epoch 883: train D loss: 0.6640, train F loss: -0.5619, acc 0.9866
# epoch 884: train D loss: 0.6575, train F loss: -0.5560, acc 0.9874
# epoch 885: train D loss: 0.6592, train F loss: -0.5628, acc 0.9888
# epoch 886: train D loss: 0.6605, train F loss: -0.5749, acc 0.9920
# epoch 887: train D loss: 0.6641, train F loss: -0.5707, acc 0.9894
# epoch 888: train D loss: 0.6650, train F loss: -0.5680, acc 0.9886
# epoch 889: train D loss: 0.6645, train F loss: -0.5758, acc 0.9890
# epoch 890: train D loss: 0.6655, train F loss: -0.5781, acc 0.9892
# epoch 891: train D loss: 0.6622, train F loss: -0.5749, acc 0.9880
# epoch 892: train D loss: 0.6629, train F loss: -0.5756, acc 0.9902
# epoch 893: train D loss: 0.6634, train F loss: -0.5691, acc 0.9882
# epoch 894: train D loss: 0.6647, train F loss: -0.5608, acc 0.9862
# epoch 895: train D loss: 0.6615, train F loss: -0.5722, acc 0.9880
# epoch 896: train D loss: 0.6627, train F loss: -0.5828, acc 0.9888
# epoch 897: train D loss: 0.6713, train F loss: -0.5926, acc 0.9910
# epoch 898: train D loss: 0.6630, train F loss: -0.5829, acc 0.9914
# epoch 899: train D loss: 0.6674, train F loss: -0.5857, acc 0.9904
# epoch 900: train D loss: 0.6639, train F loss: -0.5805, acc 0.9888
# epoch 901: train D loss: 0.6673, train F loss: -0.5907, acc 0.9914
# epoch 902: train D loss: 0.6679, train F loss: -0.5880, acc 0.9904
# epoch 903: train D loss: 0.6668, train F loss: -0.5919, acc 0.9916
# epoch 904: train D loss: 0.6650, train F loss: -0.5901, acc 0.9914
# epoch 905: train D loss: 0.6753, train F loss: -0.5853, acc 0.9870
# epoch 906: train D loss: 0.6684, train F loss: -0.5746, acc 0.9878
# epoch 907: train D loss: 0.6665, train F loss: -0.5801, acc 0.9884
# epoch 908: train D loss: 0.6677, train F loss: -0.5907, acc 0.9912
# epoch 909: train D loss: 0.6651, train F loss: -0.5823, acc 0.9878
# epoch 910: train D loss: 0.6597, train F loss: -0.5743, acc 0.9898
# epoch 911: train D loss: 0.6670, train F loss: -0.5852, acc 0.9892
# epoch 912: train D loss: 0.6642, train F loss: -0.5912, acc 0.9910
# epoch 913: train D loss: 0.6653, train F loss: -0.5786, acc 0.9884
# epoch 914: train D loss: 0.6694, train F loss: -0.5777, acc 0.9854
# epoch 915: train D loss: 0.6656, train F loss: -0.5948, acc 0.9914
# epoch 916: train D loss: 0.6716, train F loss: -0.5906, acc 0.9890
# epoch 917: train D loss: 0.6681, train F loss: -0.5873, acc 0.9902
# epoch 918: train D loss: 0.6673, train F loss: -0.5939, acc 0.9896
# epoch 919: train D loss: 0.6675, train F loss: -0.5958, acc 0.9904
# epoch 920: train D loss: 0.6708, train F loss: -0.5885, acc 0.9880
# epoch 921: train D loss: 0.6666, train F loss: -0.5974, acc 0.9896
# epoch 922: train D loss: 0.6692, train F loss: -0.5902, acc 0.9878
# epoch 923: train D loss: 0.6661, train F loss: -0.5926, acc 0.9884
# epoch 924: train D loss: 0.6671, train F loss: -0.5951, acc 0.9904
# epoch 925: train D loss: 0.6723, train F loss: -0.6007, acc 0.9894
# epoch 926: train D loss: 0.6653, train F loss: -0.5942, acc 0.9888
# epoch 927: train D loss: 0.6713, train F loss: -0.5981, acc 0.9890
# epoch 928: train D loss: 0.6669, train F loss: -0.5939, acc 0.9888
# epoch 929: train D loss: 0.6659, train F loss: -0.5903, acc 0.9892
# epoch 930: train D loss: 0.6645, train F loss: -0.5905, acc 0.9880
# epoch 931: train D loss: 0.6698, train F loss: -0.6032, acc 0.9902
# epoch 932: train D loss: 0.6708, train F loss: -0.6072, acc 0.9904
# epoch 933: train D loss: 0.6646, train F loss: -0.5977, acc 0.9898
# epoch 934: train D loss: 0.6692, train F loss: -0.5994, acc 0.9886
# epoch 935: train D loss: 0.6643, train F loss: -0.5885, acc 0.9890
# epoch 936: train D loss: 0.6667, train F loss: -0.5956, acc 0.9902
# epoch 937: train D loss: 0.6671, train F loss: -0.5883, acc 0.9868
# epoch 938: train D loss: 0.6711, train F loss: -0.6046, acc 0.9890
# epoch 939: train D loss: 0.6666, train F loss: -0.5970, acc 0.9886
# epoch 940: train D loss: 0.6662, train F loss: -0.5934, acc 0.9882
# epoch 941: train D loss: 0.6666, train F loss: -0.5967, acc 0.9886
# epoch 942: train D loss: 0.6752, train F loss: -0.6076, acc 0.9882
# epoch 943: train D loss: 0.6728, train F loss: -0.6182, acc 0.9914
# epoch 944: train D loss: 0.6595, train F loss: -0.5952, acc 0.9892
# epoch 945: train D loss: 0.6669, train F loss: -0.5998, acc 0.9904
# epoch 946: train D loss: 0.6671, train F loss: -0.5979, acc 0.9882
# epoch 947: train D loss: 0.6704, train F loss: -0.6071, acc 0.9900
# epoch 948: train D loss: 0.6681, train F loss: -0.6095, acc 0.9898
# epoch 949: train D loss: 0.6659, train F loss: -0.6023, acc 0.9890
# epoch 950: train D loss: 0.6733, train F loss: -0.6127, acc 0.9910
# epoch 951: train D loss: 0.6682, train F loss: -0.6078, acc 0.9908
# epoch 952: train D loss: 0.6650, train F loss: -0.6001, acc 0.9890
# epoch 953: train D loss: 0.6622, train F loss: -0.5937, acc 0.9888
# epoch 954: train D loss: 0.6635, train F loss: -0.5970, acc 0.9882
# epoch 955: train D loss: 0.6737, train F loss: -0.6151, acc 0.9890
# epoch 956: train D loss: 0.6671, train F loss: -0.6083, acc 0.9884
# epoch 957: train D loss: 0.6660, train F loss: -0.5924, acc 0.9870
# epoch 958: train D loss: 0.6767, train F loss: -0.6168, acc 0.9888
# epoch 959: train D loss: 0.6666, train F loss: -0.5961, acc 0.9872
# epoch 960: train D loss: 0.6698, train F loss: -0.6151, acc 0.9898
# epoch 961: train D loss: 0.6706, train F loss: -0.6065, acc 0.9888
# epoch 962: train D loss: 0.6682, train F loss: -0.6156, acc 0.9908
# epoch 963: train D loss: 0.6677, train F loss: -0.5892, acc 0.9860
# epoch 964: train D loss: 0.6646, train F loss: -0.6105, acc 0.9898
# epoch 965: train D loss: 0.6662, train F loss: -0.6133, acc 0.9890
# epoch 966: train D loss: 0.6678, train F loss: -0.6246, acc 0.9934
# epoch 967: train D loss: 0.6677, train F loss: -0.6163, acc 0.9888
# epoch 968: train D loss: 0.6632, train F loss: -0.6191, acc 0.9924
# epoch 969: train D loss: 0.6694, train F loss: -0.6192, acc 0.9904
# epoch 970: train D loss: 0.6698, train F loss: -0.6173, acc 0.9896
# epoch 971: train D loss: 0.6694, train F loss: -0.6193, acc 0.9886
# epoch 972: train D loss: 0.6685, train F loss: -0.6183, acc 0.9894
# epoch 973: train D loss: 0.6718, train F loss: -0.6206, acc 0.9906
# epoch 974: train D loss: 0.6686, train F loss: -0.6032, acc 0.9884
# epoch 975: train D loss: 0.6693, train F loss: -0.6105, acc 0.9884
# epoch 976: train D loss: 0.6704, train F loss: -0.6217, acc 0.9906
# epoch 977: train D loss: 0.6695, train F loss: -0.6253, acc 0.9918
# epoch 978: train D loss: 0.6699, train F loss: -0.6204, acc 0.9886
# epoch 979: train D loss: 0.6701, train F loss: -0.6242, acc 0.9904
# epoch 980: train D loss: 0.6742, train F loss: -0.6263, acc 0.9896
# epoch 981: train D loss: 0.6758, train F loss: -0.6349, acc 0.9920
# epoch 982: train D loss: 0.6682, train F loss: -0.6221, acc 0.9896
# epoch 983: train D loss: 0.6742, train F loss: -0.6307, acc 0.9914
# epoch 984: train D loss: 0.6749, train F loss: -0.6310, acc 0.9888
# epoch 985: train D loss: 0.6689, train F loss: -0.6112, acc 0.9874
# epoch 986: train D loss: 0.6724, train F loss: -0.6245, acc 0.9898
# epoch 987: train D loss: 0.6655, train F loss: -0.6280, acc 0.9918
# epoch 988: train D loss: 0.6678, train F loss: -0.6252, acc 0.9910
# epoch 989: train D loss: 0.6653, train F loss: -0.6198, acc 0.9916
# epoch 990: train D loss: 0.6723, train F loss: -0.6254, acc 0.9892
# epoch 991: train D loss: 0.6702, train F loss: -0.6195, acc 0.9894
# epoch 992: train D loss: 0.6721, train F loss: -0.6335, acc 0.9906
# epoch 993: train D loss: 0.6704, train F loss: -0.6326, acc 0.9912
# epoch 994: train D loss: 0.6697, train F loss: -0.6279, acc 0.9882
# epoch 995: train D loss: 0.6706, train F loss: -0.6315, acc 0.9918
# epoch 996: train D loss: 0.6747, train F loss: -0.6157, acc 0.9858
# epoch 997: train D loss: 0.6697, train F loss: -0.6316, acc 0.9904
# epoch 998: train D loss: 0.6749, train F loss: -0.6380, acc 0.9912
# epoch 999: train D loss: 0.6681, train F loss: -0.6372, acc 0.9906

# %% [markdown]
# # Inference
#
# We use pandas to generate our csv file.
#
# BTW, the performance of the model trained for 200 epoches might be unstable. You can train for more epoches for a more stable performance.

# %%
result = []
label_predictor.eval()
feature_extractor.eval()
for i, (test_data, _) in enumerate(test_dataloader):
    test_data = test_data.cuda()

    class_logits = label_predictor(feature_extractor(test_data))

    x = torch.argmax(class_logits, dim=1).cpu().detach().numpy()
    result.append(x)

import pandas as pd
result = np.concatenate(result)

# Generate your submission
df = pd.DataFrame({'id': np.arange(0,len(result)), 'label': result})
df.to_csv('DaNN_submission.csv',index=False)

# %% [markdown]
# # Visualization
# We use t-SNE plot to observe the distribution of extracted features.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold

# %%
class Feature():
    def __init__(self):
        self.X = []
        self.TX = []
        self.labels = []

def get_features(model_list):
    features = []
    for model in model_list:
        model.cuda()
        model.eval()
        features.append(Feature())

    for (x, y), (tx, _) in zip(source_dataloader, target_dataloader):
        x , tx= x.cuda(), tx.cuda()
        for i, model in enumerate(model_list):
            features[i].X.append(model(x).detach().cpu())
            features[i].TX.append(model(tx).detach().cpu())
            features[i].labels.append(y)
    
    for feature in features:
        feature.X = torch.cat(feature.X).numpy()
        feature.TX = torch.cat(feature.TX).numpy()
        feature.labels = torch.cat(feature.labels).numpy()
        
    return features

def visualization(features):
    for i, feature in enumerate(features):
        data = np.concatenate([feature.X, feature.TX])
        num_source = len(feature.labels)
        X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(data)
        # Normalization the processed features 
        x_min, x_max = X_tsne.min(0), X_tsne.max(0)
        X_norm = (X_tsne - x_min) / (x_max - x_min)
    
        plt.figure(figsize=(16, 8))
        plt.subplot(121)
        plt.title(f'epoch {marked_epoch[i]}:distribution of features accross different class')
        plt.scatter(X_norm[:num_source, 0], X_norm[:num_source, 1], c=feature.labels, label='source domain')
        plt.subplot(122)
        plt.title(f'epoch {marked_epoch[i]}:distribution of features accross different domain')
        plt.scatter(X_norm[:num_source, 0], X_norm[:num_source, 1], c='b', label='source domain')
        plt.scatter(X_norm[num_source:, 0], X_norm[num_source:, 1], c='r', label='target domain', alpha=0.5)
        plt.legend()
    plt.show()

# %%
model_list = []
for epoch in marked_epoch:
    model = FeatureExtractor()
    model.load_state_dict(torch.load(f'extractor_model_{epoch}.bin'))
    model_list.append(model)
    
visualization(get_features(model_list))
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10024 samples in 0.004s...
# [t-SNE] Computed neighbors for 10024 samples in 2.955s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10024
# [t-SNE] Computed conditional probabilities for sample 2000 / 10024
# [t-SNE] Computed conditional probabilities for sample 3000 / 10024
# [t-SNE] Computed conditional probabilities for sample 4000 / 10024
# [t-SNE] Computed conditional probabilities for sample 5000 / 10024
# [t-SNE] Computed conditional probabilities for sample 6000 / 10024
# [t-SNE] Computed conditional probabilities for sample 7000 / 10024
# [t-SNE] Computed conditional probabilities for sample 8000 / 10024
# [t-SNE] Computed conditional probabilities for sample 9000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10024 / 10024
# [t-SNE] Mean sigma: 2.309409
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.120590
# [t-SNE] KL divergence after 1000 iterations: 1.741842
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10024 samples in 0.003s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 10024 samples in 4.690s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10024
# [t-SNE] Computed conditional probabilities for sample 2000 / 10024
# [t-SNE] Computed conditional probabilities for sample 3000 / 10024
# [t-SNE] Computed conditional probabilities for sample 4000 / 10024
# [t-SNE] Computed conditional probabilities for sample 5000 / 10024
# [t-SNE] Computed conditional probabilities for sample 6000 / 10024
# [t-SNE] Computed conditional probabilities for sample 7000 / 10024
# [t-SNE] Computed conditional probabilities for sample 8000 / 10024
# [t-SNE] Computed conditional probabilities for sample 9000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10024 / 10024
# [t-SNE] Mean sigma: 1.548632
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.107399
# [t-SNE] KL divergence after 1000 iterations: 2.152545
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10024 samples in 0.004s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 10024 samples in 4.285s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10024
# [t-SNE] Computed conditional probabilities for sample 2000 / 10024
# [t-SNE] Computed conditional probabilities for sample 3000 / 10024
# [t-SNE] Computed conditional probabilities for sample 4000 / 10024
# [t-SNE] Computed conditional probabilities for sample 5000 / 10024
# [t-SNE] Computed conditional probabilities for sample 6000 / 10024
# [t-SNE] Computed conditional probabilities for sample 7000 / 10024
# [t-SNE] Computed conditional probabilities for sample 8000 / 10024
# [t-SNE] Computed conditional probabilities for sample 9000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10024 / 10024
# [t-SNE] Mean sigma: 1.212794
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.891525
# [t-SNE] KL divergence after 1000 iterations: 2.104269
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10024 samples in 0.004s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 10024 samples in 4.669s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10024
# [t-SNE] Computed conditional probabilities for sample 2000 / 10024
# [t-SNE] Computed conditional probabilities for sample 3000 / 10024
# [t-SNE] Computed conditional probabilities for sample 4000 / 10024
# [t-SNE] Computed conditional probabilities for sample 5000 / 10024
# [t-SNE] Computed conditional probabilities for sample 6000 / 10024
# [t-SNE] Computed conditional probabilities for sample 7000 / 10024
# [t-SNE] Computed conditional probabilities for sample 8000 / 10024
# [t-SNE] Computed conditional probabilities for sample 9000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10024 / 10024
# [t-SNE] Mean sigma: 1.120194
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.040833
# [t-SNE] KL divergence after 1000 iterations: 2.030047
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10024 samples in 0.004s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 10024 samples in 4.062s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10024
# [t-SNE] Computed conditional probabilities for sample 2000 / 10024
# [t-SNE] Computed conditional probabilities for sample 3000 / 10024
# [t-SNE] Computed conditional probabilities for sample 4000 / 10024
# [t-SNE] Computed conditional probabilities for sample 5000 / 10024
# [t-SNE] Computed conditional probabilities for sample 6000 / 10024
# [t-SNE] Computed conditional probabilities for sample 7000 / 10024
# [t-SNE] Computed conditional probabilities for sample 8000 / 10024
# [t-SNE] Computed conditional probabilities for sample 9000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10024 / 10024
# [t-SNE] Mean sigma: 1.040552
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.457634
# [t-SNE] KL divergence after 1000 iterations: 2.024426
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10024 samples in 0.006s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 10024 samples in 4.580s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10024
# [t-SNE] Computed conditional probabilities for sample 2000 / 10024
# [t-SNE] Computed conditional probabilities for sample 3000 / 10024
# [t-SNE] Computed conditional probabilities for sample 4000 / 10024
# [t-SNE] Computed conditional probabilities for sample 5000 / 10024
# [t-SNE] Computed conditional probabilities for sample 6000 / 10024
# [t-SNE] Computed conditional probabilities for sample 7000 / 10024
# [t-SNE] Computed conditional probabilities for sample 8000 / 10024
# [t-SNE] Computed conditional probabilities for sample 9000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10024 / 10024
# [t-SNE] Mean sigma: 1.088886
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.606857
# [t-SNE] KL divergence after 1000 iterations: 1.971465

# %% [markdown]
# ## Step1: Load checkpoint and evaluate to get extracted features

# %%
# Hints:
# Set features_extractor to eval mode
# Start evaluation and collect features and labels

# %% [markdown]
# ## Step2: Apply t-SNE and normalize

# %%
# process extracted features with t-SNE
# X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(X)

# Normalization the processed features 
# x_min, x_max = X_tsne.min(0), X_tsne.max(0)
# X_norm = (X_tsne - x_min) / (x_max - x_min)

# %% [markdown]
# ## Step3: Visualization with matplotlib

# %%
# Data Visualization
# Use matplotlib to plot the distribution
# The shape of X_norm is (N,2)

# %% [markdown]
# # Training Statistics
#
# - Number of parameters:
#   - Feature Extractor: 2, 142, 336
#   - Label Predictor: 530, 442
#   - Domain Classifier: 1, 055, 233
#
# - Simple
#  - Training time on colab: ~ 1 hr
# - Medium
#  - Training time on colab: 2 ~ 4 hr
# - Strong
#  - Training time on colab: 5 ~ 6 hrs
# - Boss
#  - **Unmeasurable**

# %% [markdown]
# # Learning Curve (Strong Baseline)
# * This method is slightly different from colab.
#
# ![Loss Curve](https://i.imgur.com/vIujQyo.png)
#
# # Accuracy Curve (Strong Baseline)
# * Note that you cannot access testing accuracy. But this plot tells you that even though the model overfits the training data, the testing accuracy is still improving, and that's why you need to train more epochs.
#
# ![Acc Curve](https://i.imgur.com/4W1otXG.png)

# %% [markdown]
# # Q&A
#
# If there is any problem related to Domain Adaptation, please email to b08901058@ntu.edu.tw / mlta-2022-spring@googlegroups.com。
