# %% [markdown]
# # Homework 11 - Transfer Learning (Domain Adversarial Training)
#
# > Author: Arvin Liu (r09922071@ntu.edu.tw)
#
# If there are any questions, please contact mlta-2022-spring@googlegroups.com

# %% [markdown]
# # Readme
#
# In homework 11, you will need to implement Domain Adversarial Training in Transfer Learning. As shown in the bottom left part of the figure.
#
# <img src="https://i.imgur.com/iMVIxCH.png" width="500px">
#
# >
#
# ## Scenario and Why Domain Adversarial Training
# Now we have labeled source data and unlabeled target data, where source data might be relavent to the target data. We now want to train a model with source data only and test it on target data.
#
# What problem might occur if we do so? After we have learned Anomaly Detection, we now know that if we test the model with an abnormal data that have never appeared in source data, our trained model is likely to result in poor performance since it is not familiar with the abnormal data.
#
# For example, we have a model that contains Feature Extractor and Classifier:
# <img src="https://i.imgur.com/IL0PxCY.png" width="500px">
#
# When the model is trained with source data, the feature extractor
# will extract meaningful features since it is familiar with the distribution of it.It could be seen in the following figure that the blue dots, which is the distribution of source data, has already been clustered into different clusters. Therefore, the Classifier can predict the label based on these clusters.
#
# However, when test on the target data, the Feature Extractor will not be able to extract meaningful features that follow the distribution of the source feature distribution, which result in the classifier learned for the source domain will not be able to apply to the target domain.
#
#
# ## Domain Adversarial Training of Nerural Networks (DaNN)
#
# Based on the above problems, DaNN approaches build mappings between the source (training-time) and the target (test-time) domains, so that the classifier learned for the source domain can also be applied to the target domain, when composed with the learned mapping between domains.
#
# <img src="https://i.imgur.com/vrOE5a6.png" width="500px">
#
# In DaNN, the authors added a Domain Classifier, which is a deep discriminatively-trained classifeir in the training framework to distinguish the data from different domain by the features extracted by the feature extractor. As the training progresses, the approach promotes a domain classifier that discriminates between the source and the target domains and a feature extractor that can extractor features that are discriminative for the main learning task on the source domain and indiscriminate with respect to the shift between the domains.
#
#
# The feature extractor are likely to outperform the domain classifier as its input are generated by the feature extractor and that the task of domain classification and label classification are not conflict.
#
# This method leads to the emergence of features that are domain-invariant and on the same feature distribution.

# %% [markdown]
# # Data Introduce
#
# Our task contains source data: real photos, and target data: hand-drawn graffiti.
#
# We are going to train the model with the photos and the labels, and try to predict what the labels are for hand-drawn graffiti.
#
# The data could be downloaded [here](https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip). The code below is for data downloading and visualization.
#
# Note that: **The source and target data are all balanced data, you can make use of this information.**

# %%
# Download dataset
#!wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip" -O real_or_drawing.zip

# Download from mirrored dataset link
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.1/real_or_drawing.zip" -O real_or_drawing.zip
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.2/real_or_drawing.zip" -O real_or_drawing.zip

# Unzip the files
#!unzip real_or_drawing.zip

# %%
import matplotlib.pyplot as plt

def no_axis_show(img, title='', cmap=None):
  # imshow, and set the interpolation mode to be "nearest"。
  fig = plt.imshow(img, interpolation='nearest', cmap=cmap)
  # do not show the axes in the images.
  fig.axes.get_xaxis().set_visible(False)
  fig.axes.get_yaxis().set_visible(False)
  plt.title(title)

titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/train_data/{i}/{500*i}.bmp'), title=titles[i])

# %%
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/test_data/0/' + str(i).rjust(5, '0') + '.bmp'))

# %% [markdown]
# # Special Domain Knowledge
#
# When we graffiti, we usually draw the outline only, therefore we can perform edge detection processing on the source data to make it more similar to the target data.
#
#
# ## Canny Edge Detection
# The implementation of Canny Edge Detection is as follow.
# The algorithm will not be describe thoroughly here.  If you are interested, please refer to the wiki or [here](https://medium.com/@pomelyu5199/canny-edge-detector-%E5%AF%A6%E4%BD%9C-opencv-f7d1a0a57d19).
#
# We only need two parameters to implement Canny Edge Detection with CV2:  `low_threshold` and `high_threshold`.
#
# ```cv2.Canny(image, low_threshold, high_threshold)```
#
# Simply put, when the edge value exceeds the high_threshold, we determine it as an edge. If the edge value is only above low_threshold, we will then determine whether it is an edge or not.
#
# Let's implement it on the source data.

# %%
import cv2
import matplotlib.pyplot as plt
titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))

original_img = plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/train_data/0/0.bmp')
plt.subplot(1, 5, 1)
no_axis_show(original_img, title='original')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

canny_50100 = cv2.Canny(gray_img, 50, 100)
plt.subplot(1, 5, 3)
no_axis_show(canny_50100, title='Canny(50, 100)', cmap='gray')

canny_150200 = cv2.Canny(gray_img, 150, 200)
plt.subplot(1, 5, 4)
no_axis_show(canny_150200, title='Canny(150, 200)', cmap='gray')

canny_250300 = cv2.Canny(gray_img, 250, 300)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(250, 300)', cmap='gray')

# %% [markdown]
# # Data Process
#
#
# The data is suitible for `torchvision.ImageFolder`. You can create a dataset with `torchvision.ImageFolder`. Details for image augmentation please refer to the comments in the following codes.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Function
 
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
 
source_transform = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 170, 300)),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
target_transform = transforms.Compose([
    # Turn RGB to grayscale.
    transforms.Grayscale(),
    # Resize: size of source data is 32x32, thus we need to 
    #  enlarge the size of target data from 28x28 to 32x32。
    transforms.Resize((32, 32)),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
 
source_dataset = ImageFolder('../input/ml2022-spring-hw11/real_or_drawing/train_data', transform=source_transform)
target_dataset = ImageFolder('../input/ml2022-spring-hw11/real_or_drawing/test_data', transform=target_transform)
 
source_dataloader = DataLoader(source_dataset, batch_size=32, shuffle=True)
target_dataloader = DataLoader(target_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(target_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# # Model
#
# Feature Extractor: Classic VGG-like architecture
#
# Label Predictor / Domain Classifier: Linear models.

# %%
class FeatureExtractor(nn.Module):

    def __init__(self):
        super(FeatureExtractor, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
    def forward(self, x):
        x = self.conv(x).squeeze()
        return x

class LabelPredictor(nn.Module):

    def __init__(self):
        super(LabelPredictor, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 10),
        )

    def forward(self, h):
        c = self.layer(h)
        return c

class DomainClassifier(nn.Module):

    def __init__(self):
        super(DomainClassifier, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 1),
        )

    def forward(self, h):
        y = self.layer(h)
        return y

# %% [markdown]
# # Pre-processing
#
# Here we use Adam as our optimizor.

# %%
feature_extractor = FeatureExtractor().cuda()
label_predictor = LabelPredictor().cuda()
domain_classifier = DomainClassifier().cuda()

class_criterion = nn.CrossEntropyLoss()
domain_criterion = nn.BCEWithLogitsLoss()

optimizer_F = optim.Adam(feature_extractor.parameters())
optimizer_C = optim.Adam(label_predictor.parameters())
optimizer_D = optim.Adam(domain_classifier.parameters())

# %% [markdown]
# # Start Training
#
#
# ## DaNN Implementation
#
# In the original paper, Gradient Reversal Layer is used.
# Feature Extractor, Label Predictor, and Domain Classifier are all trained at the same time. In this code, we train Domain Classifier first, and then train our Feature Extractor (same concept as Generator and Discriminator training process in GAN).
#
# ## Reminder
# * Lambda, which controls the domain adversarial loss, is adaptive in the original paper. You can refer to [the original work](https://arxiv.org/pdf/1505.07818.pdf) . Here lambda is set to 0.1.
# * We do not have the label to target data, you can only evaluate your model by uploading your result to kaggle.:)

# %%
def train_epoch(source_dataloader, target_dataloader, lamb):
    '''
      Args:
        source_dataloader: source data的dataloader
        target_dataloader: target data的dataloader
        lamb: control the balance of domain adaptatoin and classification.
    '''

    # D loss: Domain Classifier的loss
    # F loss: Feature Extrator & Label Predictor的loss
    running_D_loss, running_F_loss = 0.0, 0.0
    total_hit, total_num = 0.0, 0.0

    for i, ((source_data, source_label), (target_data, _)) in enumerate(zip(source_dataloader, target_dataloader)):

        source_data = source_data.cuda()
        source_label = source_label.cuda()
        target_data = target_data.cuda()
        
        # Mixed the source data and target data, or it'll mislead the running params
        #   of batch_norm. (runnning mean/var of soucre and target data are different.)
        mixed_data = torch.cat([source_data, target_data], dim=0)
        domain_label = torch.zeros([source_data.shape[0] + target_data.shape[0], 1]).cuda()
        # set domain label of source data to be 1.
        domain_label[:source_data.shape[0]] = 1

        # Step 1 : train domain classifier
        feature = feature_extractor(mixed_data)
        # We don't need to train feature extractor in step 1.
        # Thus we detach the feature neuron to avoid backpropgation.
        domain_logits = domain_classifier(feature.detach())
        loss = domain_criterion(domain_logits, domain_label)
        running_D_loss+= loss.item()
        loss.backward()
        optimizer_D.step()

        # Step 2 : train feature extractor and label classifier
        class_logits = label_predictor(feature[:source_data.shape[0]])
        domain_logits = domain_classifier(feature)
        # loss = cross entropy of classification - lamb * domain binary cross entropy.
        #  The reason why using subtraction is similar to generator loss in disciminator of GAN
        loss = class_criterion(class_logits, source_label) - lamb * domain_criterion(domain_logits, domain_label)
        running_F_loss+= loss.item()
        loss.backward()
        optimizer_F.step()
        optimizer_C.step()

        optimizer_D.zero_grad()
        optimizer_F.zero_grad()
        optimizer_C.zero_grad()

        total_hit += torch.sum(torch.argmax(class_logits, dim=1) == source_label).item()
        total_num += source_data.shape[0]
        print(i, end='\r')

    return running_D_loss / (i+1), running_F_loss / (i+1), total_hit / total_num

# train 200 epochs
for epoch in range(200):
    train_D_loss, train_F_loss, train_acc = train_epoch(source_dataloader, target_dataloader, lamb=0.1)

    torch.save(feature_extractor.state_dict(), f'extractor_model.bin')
    torch.save(label_predictor.state_dict(), f'predictor_model.bin')

    print('epoch {:>3d}: train D loss: {:6.4f}, train F loss: {:6.4f}, acc {:6.4f}'.format(epoch, train_D_loss, train_F_loss, train_acc))
# Out:
# epoch   0: train D loss: 0.7238, train F loss: 1.8877, acc 0.2812
# epoch   1: train D loss: 0.6127, train F loss: 1.5570, acc 0.4214
# epoch   2: train D loss: 0.5609, train F loss: 1.4346, acc 0.4764
# epoch   3: train D loss: 0.5355, train F loss: 1.3529, acc 0.5068
# epoch   4: train D loss: 0.5322, train F loss: 1.3149, acc 0.5194
# epoch   5: train D loss: 0.5460, train F loss: 1.2445, acc 0.5428
# epoch   6: train D loss: 0.5326, train F loss: 1.2043, acc 0.5682
# epoch   7: train D loss: 0.5285, train F loss: 1.1781, acc 0.5768
# epoch   8: train D loss: 0.5276, train F loss: 1.1413, acc 0.5956
# epoch   9: train D loss: 0.5252, train F loss: 1.0902, acc 0.6042
# epoch  10: train D loss: 0.5344, train F loss: 1.0567, acc 0.6144
# epoch  11: train D loss: 0.5228, train F loss: 1.0277, acc 0.6278
# epoch  12: train D loss: 0.5163, train F loss: 0.9950, acc 0.6358
# epoch  13: train D loss: 0.5175, train F loss: 0.9655, acc 0.6460
# epoch  14: train D loss: 0.5207, train F loss: 0.9234, acc 0.6626
# epoch  15: train D loss: 0.5047, train F loss: 0.9112, acc 0.6642
# epoch  16: train D loss: 0.5177, train F loss: 0.8827, acc 0.6768
# epoch  17: train D loss: 0.5084, train F loss: 0.8457, acc 0.6928
# epoch  18: train D loss: 0.5100, train F loss: 0.7975, acc 0.7082
# epoch  19: train D loss: 0.5120, train F loss: 0.7683, acc 0.7162
# epoch  20: train D loss: 0.4983, train F loss: 0.7572, acc 0.7290
# epoch  21: train D loss: 0.5038, train F loss: 0.6914, acc 0.7466
# epoch  22: train D loss: 0.5086, train F loss: 0.6753, acc 0.7546
# epoch  23: train D loss: 0.4885, train F loss: 0.6333, acc 0.7630
# epoch  24: train D loss: 0.4802, train F loss: 0.6325, acc 0.7694
# epoch  25: train D loss: 0.4763, train F loss: 0.5915, acc 0.7836
# epoch  26: train D loss: 0.4657, train F loss: 0.5480, acc 0.7952
# epoch  27: train D loss: 0.4629, train F loss: 0.5277, acc 0.7988
# epoch  28: train D loss: 0.4702, train F loss: 0.4861, acc 0.8212
# epoch  29: train D loss: 0.4561, train F loss: 0.4688, acc 0.8254
# epoch  30: train D loss: 0.4322, train F loss: 0.4365, acc 0.8338
# epoch  31: train D loss: 0.4472, train F loss: 0.4408, acc 0.8394
# epoch  32: train D loss: 0.4504, train F loss: 0.3974, acc 0.8474
# epoch  33: train D loss: 0.4444, train F loss: 0.3864, acc 0.8590
# epoch  34: train D loss: 0.4351, train F loss: 0.3768, acc 0.8510
# epoch  35: train D loss: 0.4330, train F loss: 0.3719, acc 0.8586
# epoch  36: train D loss: 0.4024, train F loss: 0.3269, acc 0.8720
# epoch  37: train D loss: 0.4346, train F loss: 0.2938, acc 0.8862
# epoch  38: train D loss: 0.4186, train F loss: 0.2828, acc 0.8892
# epoch  39: train D loss: 0.4189, train F loss: 0.2848, acc 0.8920
# epoch  40: train D loss: 0.3950, train F loss: 0.2697, acc 0.8976
# epoch  41: train D loss: 0.4114, train F loss: 0.2406, acc 0.9036
# epoch  42: train D loss: 0.3942, train F loss: 0.2663, acc 0.8972
# epoch  43: train D loss: 0.3935, train F loss: 0.2525, acc 0.9020
# epoch  44: train D loss: 0.3878, train F loss: 0.2170, acc 0.9164
# epoch  45: train D loss: 0.4002, train F loss: 0.2131, acc 0.9152
# epoch  46: train D loss: 0.3848, train F loss: 0.2078, acc 0.9208
# epoch  47: train D loss: 0.3873, train F loss: 0.2044, acc 0.9168
# epoch  48: train D loss: 0.3823, train F loss: 0.1971, acc 0.9258
# epoch  49: train D loss: 0.3931, train F loss: 0.1955, acc 0.9248
# epoch  50: train D loss: 0.3945, train F loss: 0.2071, acc 0.9218
# epoch  51: train D loss: 0.3828, train F loss: 0.1809, acc 0.9268
# epoch  52: train D loss: 0.3776, train F loss: 0.1664, acc 0.9334
# epoch  53: train D loss: 0.3864, train F loss: 0.1402, acc 0.9376
# epoch  54: train D loss: 0.3831, train F loss: 0.1738, acc 0.9322
# epoch  55: train D loss: 0.3930, train F loss: 0.1563, acc 0.9330
# epoch  56: train D loss: 0.3877, train F loss: 0.1575, acc 0.9376
# epoch  57: train D loss: 0.3796, train F loss: 0.1469, acc 0.9410
# epoch  58: train D loss: 0.3820, train F loss: 0.1596, acc 0.9378
# epoch  59: train D loss: 0.3851, train F loss: 0.1408, acc 0.9416
# epoch  60: train D loss: 0.3931, train F loss: 0.1162, acc 0.9500
# epoch  61: train D loss: 0.3769, train F loss: 0.1216, acc 0.9482
# epoch  62: train D loss: 0.4031, train F loss: 0.1125, acc 0.9498
# epoch  63: train D loss: 0.3694, train F loss: 0.1353, acc 0.9430
# epoch  64: train D loss: 0.3679, train F loss: 0.1138, acc 0.9480
# epoch  65: train D loss: 0.3839, train F loss: 0.1333, acc 0.9434
# epoch  66: train D loss: 0.3741, train F loss: 0.1135, acc 0.9490
# epoch  67: train D loss: 0.3868, train F loss: 0.1179, acc 0.9502
# epoch  68: train D loss: 0.3734, train F loss: 0.1056, acc 0.9490
# epoch  69: train D loss: 0.3711, train F loss: 0.1125, acc 0.9540
# epoch  70: train D loss: 0.3646, train F loss: 0.1102, acc 0.9492
# epoch  71: train D loss: 0.3763, train F loss: 0.0836, acc 0.9594
# epoch  72: train D loss: 0.3848, train F loss: 0.0926, acc 0.9582
# epoch  73: train D loss: 0.3802, train F loss: 0.0874, acc 0.9598
# epoch  74: train D loss: 0.3713, train F loss: 0.0986, acc 0.9542
# epoch  75: train D loss: 0.3841, train F loss: 0.0932, acc 0.9556
# epoch  76: train D loss: 0.3714, train F loss: 0.1004, acc 0.9560
# epoch  77: train D loss: 0.3648, train F loss: 0.0859, acc 0.9614
# epoch  78: train D loss: 0.3788, train F loss: 0.0891, acc 0.9550
# epoch  79: train D loss: 0.3833, train F loss: 0.0854, acc 0.9602
# epoch  80: train D loss: 0.3853, train F loss: 0.0882, acc 0.9596
# epoch  81: train D loss: 0.3768, train F loss: 0.0668, acc 0.9656
# epoch  82: train D loss: 0.3659, train F loss: 0.0686, acc 0.9650
# epoch  83: train D loss: 0.3768, train F loss: 0.0878, acc 0.9598
# epoch  84: train D loss: 0.3691, train F loss: 0.0708, acc 0.9650
# epoch  85: train D loss: 0.3671, train F loss: 0.0798, acc 0.9662
# epoch  86: train D loss: 0.3663, train F loss: 0.0912, acc 0.9598
# epoch  87: train D loss: 0.3591, train F loss: 0.0766, acc 0.9658
# epoch  88: train D loss: 0.3780, train F loss: 0.0671, acc 0.9652
# epoch  89: train D loss: 0.3606, train F loss: 0.0732, acc 0.9650
# epoch  90: train D loss: 0.3789, train F loss: 0.0702, acc 0.9658
# epoch  91: train D loss: 0.3630, train F loss: 0.0849, acc 0.9618
# epoch  92: train D loss: 0.3572, train F loss: 0.0823, acc 0.9586
# epoch  93: train D loss: 0.3594, train F loss: 0.0766, acc 0.9620
# epoch  94: train D loss: 0.3713, train F loss: 0.0661, acc 0.9666
# epoch  95: train D loss: 0.3549, train F loss: 0.0664, acc 0.9680
# epoch  96: train D loss: 0.3590, train F loss: 0.0651, acc 0.9660
# epoch  97: train D loss: 0.3666, train F loss: 0.0624, acc 0.9684
# epoch  98: train D loss: 0.3699, train F loss: 0.0679, acc 0.9672
# epoch  99: train D loss: 0.3635, train F loss: 0.0425, acc 0.9738
# epoch 100: train D loss: 0.3694, train F loss: 0.0579, acc 0.9718
# epoch 101: train D loss: 0.3790, train F loss: 0.0584, acc 0.9732
# epoch 102: train D loss: 0.3823, train F loss: 0.0796, acc 0.9630
# epoch 103: train D loss: 0.3676, train F loss: 0.0553, acc 0.9684
# epoch 104: train D loss: 0.3656, train F loss: 0.0572, acc 0.9694
# epoch 105: train D loss: 0.3744, train F loss: 0.0599, acc 0.9690
# epoch 106: train D loss: 0.3701, train F loss: 0.0567, acc 0.9694
# epoch 107: train D loss: 0.3792, train F loss: 0.0560, acc 0.9696
# epoch 108: train D loss: 0.3824, train F loss: 0.0638, acc 0.9666
# epoch 109: train D loss: 0.3743, train F loss: 0.0518, acc 0.9712
# epoch 110: train D loss: 0.3704, train F loss: 0.0515, acc 0.9722
# epoch 111: train D loss: 0.3548, train F loss: 0.0441, acc 0.9748
# epoch 112: train D loss: 0.3634, train F loss: 0.0626, acc 0.9692
# epoch 113: train D loss: 0.3829, train F loss: 0.0654, acc 0.9644
# epoch 114: train D loss: 0.3659, train F loss: 0.0410, acc 0.9750
# epoch 115: train D loss: 0.3740, train F loss: 0.0563, acc 0.9704
# epoch 116: train D loss: 0.3649, train F loss: 0.0582, acc 0.9694
# epoch 117: train D loss: 0.3666, train F loss: 0.0417, acc 0.9768
# epoch 118: train D loss: 0.3612, train F loss: 0.0376, acc 0.9754
# epoch 119: train D loss: 0.3777, train F loss: 0.0520, acc 0.9724
# epoch 120: train D loss: 0.3669, train F loss: 0.0456, acc 0.9746
# epoch 121: train D loss: 0.3674, train F loss: 0.0458, acc 0.9738
# epoch 122: train D loss: 0.3723, train F loss: 0.0418, acc 0.9752
# epoch 123: train D loss: 0.3756, train F loss: 0.0399, acc 0.9770
# epoch 124: train D loss: 0.3692, train F loss: 0.0584, acc 0.9702
# epoch 125: train D loss: 0.3700, train F loss: 0.0513, acc 0.9734
# epoch 126: train D loss: 0.3682, train F loss: 0.0556, acc 0.9706
# epoch 127: train D loss: 0.3755, train F loss: 0.0420, acc 0.9750
# epoch 128: train D loss: 0.3752, train F loss: 0.0443, acc 0.9730
# epoch 129: train D loss: 0.3672, train F loss: 0.0456, acc 0.9740
# epoch 130: train D loss: 0.3681, train F loss: 0.0425, acc 0.9744
# epoch 131: train D loss: 0.3732, train F loss: 0.0477, acc 0.9726
# epoch 132: train D loss: 0.3788, train F loss: 0.0321, acc 0.9766
# epoch 133: train D loss: 0.3748, train F loss: 0.0574, acc 0.9704
# epoch 134: train D loss: 0.3639, train F loss: 0.0296, acc 0.9798
# epoch 135: train D loss: 0.3788, train F loss: 0.0353, acc 0.9776
# epoch 136: train D loss: 0.3672, train F loss: 0.0459, acc 0.9708
# epoch 137: train D loss: 0.3604, train F loss: 0.0363, acc 0.9762
# epoch 138: train D loss: 0.3728, train F loss: 0.0503, acc 0.9734
# epoch 139: train D loss: 0.3701, train F loss: 0.0487, acc 0.9720
# epoch 140: train D loss: 0.3704, train F loss: 0.0389, acc 0.9750
# epoch 141: train D loss: 0.3819, train F loss: 0.0303, acc 0.9780
# epoch 142: train D loss: 0.3602, train F loss: 0.0240, acc 0.9812
# epoch 143: train D loss: 0.3589, train F loss: 0.0381, acc 0.9754
# epoch 144: train D loss: 0.3676, train F loss: 0.0338, acc 0.9780
# epoch 145: train D loss: 0.3691, train F loss: 0.0392, acc 0.9756
# epoch 146: train D loss: 0.3683, train F loss: 0.0388, acc 0.9756
# epoch 147: train D loss: 0.3623, train F loss: 0.0417, acc 0.9772
# epoch 148: train D loss: 0.3601, train F loss: 0.0468, acc 0.9750
# epoch 149: train D loss: 0.3630, train F loss: 0.0337, acc 0.9784
# epoch 150: train D loss: 0.3744, train F loss: 0.0408, acc 0.9758
# epoch 151: train D loss: 0.3683, train F loss: 0.0328, acc 0.9790
# epoch 152: train D loss: 0.3722, train F loss: 0.0316, acc 0.9780
# epoch 153: train D loss: 0.3667, train F loss: 0.0234, acc 0.9798
# epoch 154: train D loss: 0.3723, train F loss: 0.0438, acc 0.9758
# epoch 155: train D loss: 0.3690, train F loss: 0.0326, acc 0.9776
# epoch 156: train D loss: 0.3678, train F loss: 0.0383, acc 0.9758
# epoch 157: train D loss: 0.3709, train F loss: 0.0223, acc 0.9820
# epoch 158: train D loss: 0.3760, train F loss: 0.0325, acc 0.9790
# epoch 159: train D loss: 0.3624, train F loss: 0.0329, acc 0.9786
# epoch 160: train D loss: 0.3639, train F loss: 0.0198, acc 0.9820
# epoch 161: train D loss: 0.3762, train F loss: 0.0259, acc 0.9808
# epoch 162: train D loss: 0.3753, train F loss: 0.0266, acc 0.9814
# epoch 163: train D loss: 0.4002, train F loss: 0.0347, acc 0.9772
# epoch 164: train D loss: 0.3705, train F loss: 0.0184, acc 0.9844
# epoch 165: train D loss: 0.3690, train F loss: 0.0278, acc 0.9804
# epoch 166: train D loss: 0.3898, train F loss: 0.0434, acc 0.9764
# epoch 167: train D loss: 0.3867, train F loss: 0.0334, acc 0.9772
# epoch 168: train D loss: 0.3705, train F loss: 0.0291, acc 0.9784
# epoch 169: train D loss: 0.3673, train F loss: 0.0242, acc 0.9810
# epoch 170: train D loss: 0.3561, train F loss: 0.0292, acc 0.9794
# epoch 171: train D loss: 0.3841, train F loss: 0.0312, acc 0.9778
# epoch 172: train D loss: 0.3763, train F loss: 0.0286, acc 0.9788
# epoch 173: train D loss: 0.3881, train F loss: 0.0279, acc 0.9792
# epoch 174: train D loss: 0.3857, train F loss: 0.0234, acc 0.9782
# epoch 175: train D loss: 0.3691, train F loss: 0.0260, acc 0.9816
# epoch 176: train D loss: 0.3715, train F loss: 0.0166, acc 0.9826
# epoch 177: train D loss: 0.3781, train F loss: 0.0292, acc 0.9770
# epoch 178: train D loss: 0.3772, train F loss: 0.0261, acc 0.9810
# epoch 179: train D loss: 0.3931, train F loss: 0.0192, acc 0.9822
# epoch 180: train D loss: 0.3884, train F loss: 0.0259, acc 0.9780
# epoch 181: train D loss: 0.3830, train F loss: 0.0151, acc 0.9832
# epoch 182: train D loss: 0.3681, train F loss: 0.0287, acc 0.9776
# epoch 183: train D loss: 0.3744, train F loss: 0.0336, acc 0.9778
# epoch 184: train D loss: 0.3773, train F loss: 0.0263, acc 0.9802
# epoch 185: train D loss: 0.3713, train F loss: 0.0226, acc 0.9816
# epoch 186: train D loss: 0.3788, train F loss: 0.0126, acc 0.9830
# epoch 187: train D loss: 0.3807, train F loss: 0.0274, acc 0.9804
# epoch 188: train D loss: 0.3872, train F loss: 0.0141, acc 0.9818
# epoch 189: train D loss: 0.3804, train F loss: 0.0267, acc 0.9812
# epoch 190: train D loss: 0.3861, train F loss: 0.0159, acc 0.9838
# epoch 191: train D loss: 0.3642, train F loss: 0.0296, acc 0.9842
# epoch 192: train D loss: 0.3697, train F loss: 0.0377, acc 0.9746
# epoch 193: train D loss: 0.3787, train F loss: 0.0243, acc 0.9812
# epoch 194: train D loss: 0.3794, train F loss: 0.0263, acc 0.9804
# epoch 195: train D loss: 0.3884, train F loss: 0.0144, acc 0.9824
# epoch 196: train D loss: 0.3727, train F loss: 0.0151, acc 0.9830
# epoch 197: train D loss: 0.3846, train F loss: 0.0158, acc 0.9818
# epoch 198: train D loss: 0.3893, train F loss: 0.0252, acc 0.9814
# epoch 199: train D loss: 0.3821, train F loss: 0.0269, acc 0.9802

# %% [markdown]
# # Inference
#
# We use pandas to generate our csv file.
#
# BTW, the performance of the model trained for 200 epoches might be unstable. You can train for more epoches for a more stable performance.

# %%
result = []
label_predictor.eval()
feature_extractor.eval()
for i, (test_data, _) in enumerate(test_dataloader):
    test_data = test_data.cuda()

    class_logits = label_predictor(feature_extractor(test_data))

    x = torch.argmax(class_logits, dim=1).cpu().detach().numpy()
    result.append(x)

import pandas as pd
result = np.concatenate(result)

# Generate your submission
df = pd.DataFrame({'id': np.arange(0,len(result)), 'label': result})
df.to_csv('DaNN_submission.csv',index=False)

# %% [markdown]
# # Visualization
# We use t-SNE plot to observe the distribution of extracted features.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold

# %% [markdown]
# ## Step1: Load checkpoint and evaluate to get extracted features

# %%
# Hints:
# Set features_extractor to eval mode
# Start evaluation and collect features and labels

# %% [markdown]
# ## Step2: Apply t-SNE and normalize

# %%
# process extracted features with t-SNE
# X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(X)

# Normalization the processed features 
# x_min, x_max = X_tsne.min(0), X_tsne.max(0)
# X_norm = (X_tsne - x_min) / (x_max - x_min)

# %% [markdown]
# ## Step3: Visualization with matplotlib

# %%
# Data Visualization
# Use matplotlib to plot the distribution
# The shape of X_norm is (N,2)

# %% [markdown]
# # Training Statistics
#
# - Number of parameters:
#   - Feature Extractor: 2, 142, 336
#   - Label Predictor: 530, 442
#   - Domain Classifier: 1, 055, 233
#
# - Simple
#  - Training time on colab: ~ 1 hr
# - Medium
#  - Training time on colab: 2 ~ 4 hr
# - Strong
#  - Training time on colab: 5 ~ 6 hrs
# - Boss
#  - **Unmeasurable**

# %% [markdown]
# # Learning Curve (Strong Baseline)
# * This method is slightly different from colab.
#
# ![Loss Curve](https://i.imgur.com/vIujQyo.png)
#
# # Accuracy Curve (Strong Baseline)
# * Note that you cannot access testing accuracy. But this plot tells you that even though the model overfits the training data, the testing accuracy is still improving, and that's why you need to train more epochs.
#
# ![Acc Curve](https://i.imgur.com/4W1otXG.png)

# %% [markdown]
# # Q&A
#
# If there is any problem related to Domain Adaptation, please email to b08901058@ntu.edu.tw / mlta-2022-spring@googlegroups.com。
