# %% [markdown]
# # Homework 11 - Transfer Learning (Domain Adversarial Training)
#
# > Author: Arvin Liu (r09922071@ntu.edu.tw)
#
# If there are any questions, please contact mlta-2022-spring@googlegroups.com

# %% [markdown]
# # Readme
#
# In homework 11, you will need to implement Domain Adversarial Training in Transfer Learning. As shown in the bottom left part of the figure.
#
# <img src="https://i.imgur.com/iMVIxCH.png" width="500px">
#
# >
#
# ## Scenario and Why Domain Adversarial Training
# Now we have labeled source data and unlabeled target data, where source data might be relavent to the target data. We now want to train a model with source data only and test it on target data.
#
# What problem might occur if we do so? After we have learned Anomaly Detection, we now know that if we test the model with an abnormal data that have never appeared in source data, our trained model is likely to result in poor performance since it is not familiar with the abnormal data.
#
# For example, we have a model that contains Feature Extractor and Classifier:
# <img src="https://i.imgur.com/IL0PxCY.png" width="500px">
#
# When the model is trained with source data, the feature extractor
# will extract meaningful features since it is familiar with the distribution of it.It could be seen in the following figure that the blue dots, which is the distribution of source data, has already been clustered into different clusters. Therefore, the Classifier can predict the label based on these clusters.
#
# However, when test on the target data, the Feature Extractor will not be able to extract meaningful features that follow the distribution of the source feature distribution, which result in the classifier learned for the source domain will not be able to apply to the target domain.
#
#
# ## Domain Adversarial Training of Nerural Networks (DaNN)
#
# Based on the above problems, DaNN approaches build mappings between the source (training-time) and the target (test-time) domains, so that the classifier learned for the source domain can also be applied to the target domain, when composed with the learned mapping between domains.
#
# <img src="https://i.imgur.com/vrOE5a6.png" width="500px">
#
# In DaNN, the authors added a Domain Classifier, which is a deep discriminatively-trained classifeir in the training framework to distinguish the data from different domain by the features extracted by the feature extractor. As the training progresses, the approach promotes a domain classifier that discriminates between the source and the target domains and a feature extractor that can extractor features that are discriminative for the main learning task on the source domain and indiscriminate with respect to the shift between the domains.
#
#
# The feature extractor are likely to outperform the domain classifier as its input are generated by the feature extractor and that the task of domain classification and label classification are not conflict.
#
# This method leads to the emergence of features that are domain-invariant and on the same feature distribution.

# %% [markdown]
# # Data Introduce
#
# Our task contains source data: real photos, and target data: hand-drawn graffiti.
#
# We are going to train the model with the photos and the labels, and try to predict what the labels are for hand-drawn graffiti.
#
# The data could be downloaded [here](https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip). The code below is for data downloading and visualization.
#
# Note that: **The source and target data are all balanced data, you can make use of this information.**

# %%
# Download dataset
#!wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip" -O real_or_drawing.zip

# Download from mirrored dataset link
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.1/real_or_drawing.zip" -O real_or_drawing.zip
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.2/real_or_drawing.zip" -O real_or_drawing.zip

# Unzip the files
#!unzip real_or_drawing.zip

# %%
# !nvidia-smi
# Out:
# Thu Jul 21 00:46:21 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.82.01    Driver Version: 470.82.01    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import matplotlib.pyplot as plt

def no_axis_show(img, title='', cmap=None):
  # imshow, and set the interpolation mode to be "nearest"。
  fig = plt.imshow(img, interpolation='nearest', cmap=cmap)
  # do not show the axes in the images.
  fig.axes.get_xaxis().set_visible(False)
  fig.axes.get_yaxis().set_visible(False)
  plt.title(title)

titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/train_data/{i}/{500*i}.bmp'), title=titles[i])

# %%
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/test_data/0/' + str(i).rjust(5, '0') + '.bmp'))

# %% [markdown]
# # Special Domain Knowledge
#
# When we graffiti, we usually draw the outline only, therefore we can perform edge detection processing on the source data to make it more similar to the target data.
#
#
# ## Canny Edge Detection
# The implementation of Canny Edge Detection is as follow.
# The algorithm will not be describe thoroughly here.  If you are interested, please refer to the wiki or [here](https://medium.com/@pomelyu5199/canny-edge-detector-%E5%AF%A6%E4%BD%9C-opencv-f7d1a0a57d19).
#
# We only need two parameters to implement Canny Edge Detection with CV2:  `low_threshold` and `high_threshold`.
#
# ```cv2.Canny(image, low_threshold, high_threshold)```
#
# Simply put, when the edge value exceeds the high_threshold, we determine it as an edge. If the edge value is only above low_threshold, we will then determine whether it is an edge or not.
#
# Let's implement it on the source data.

# %%
import cv2
import matplotlib.pyplot as plt
titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))

original_img = plt.imread(f'../input/ml2022-spring-hw11/real_or_drawing/train_data/0/0.bmp')
plt.subplot(1, 5, 1)
no_axis_show(original_img, title='original')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

canny_50100 = cv2.Canny(gray_img, 50, 100)
plt.subplot(1, 5, 3)
no_axis_show(canny_50100, title='Canny(50, 100)', cmap='gray')

canny_150200 = cv2.Canny(gray_img, 150, 200)
plt.subplot(1, 5, 4)
no_axis_show(canny_150200, title='Canny(150, 200)', cmap='gray')

canny_250300 = cv2.Canny(gray_img, 250, 300)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(250, 300)', cmap='gray')

# %% [markdown]
# # Data Process
#
#
# The data is suitible for `torchvision.ImageFolder`. You can create a dataset with `torchvision.ImageFolder`. Details for image augmentation please refer to the comments in the following codes.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Function
 
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
 
source_transform = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 170, 300)),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
target_transform = transforms.Compose([
    # Turn RGB to grayscale.
    transforms.Grayscale(),
    # Resize: size of source data is 32x32, thus we need to 
    #  enlarge the size of target data from 28x28 to 32x32。
    transforms.Resize((32, 32)),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
 
source_dataset = ImageFolder('../input/ml2022-spring-hw11/real_or_drawing/train_data', transform=source_transform)
target_dataset = ImageFolder('../input/ml2022-spring-hw11/real_or_drawing/test_data', transform=target_transform)
 
source_dataloader = DataLoader(source_dataset, batch_size=32, shuffle=True)
target_dataloader = DataLoader(target_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(target_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# # Model
#
# Feature Extractor: Classic VGG-like architecture
#
# Label Predictor / Domain Classifier: Linear models.

# %%
class FeatureExtractor(nn.Module):

    def __init__(self):
        super(FeatureExtractor, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
    def forward(self, x):
        x = self.conv(x).squeeze()
        return x

class LabelPredictor(nn.Module):

    def __init__(self):
        super(LabelPredictor, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 10),
        )

    def forward(self, h):
        c = self.layer(h)
        return c

class DomainClassifier(nn.Module):

    def __init__(self):
        super(DomainClassifier, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 1),
        )

    def forward(self, h):
        y = self.layer(h)
        return y

# %% [markdown]
# # Pre-processing
#
# Here we use Adam as our optimizor.

# %% [markdown]
# ## Setting network

# %%
feature_extractor = FeatureExtractor().cuda()
label_predictor = LabelPredictor().cuda()

feature_extractor.load_state_dict(torch.load(f'../input/hw11strong/extractor_model.bin'))
label_predictor.load_state_dict(torch.load(f'../input/hw11strong/predictor_model.bin'))

class_criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(list(feature_extractor.parameters()) + list(label_predictor.parameters()), lr=2e-3)

# %% [markdown]
# ## Setting Teacher network

# %%
t_feature_extractor = FeatureExtractor().cuda()
t_label_predictor = LabelPredictor().cuda()

t_feature_extractor.load_state_dict(torch.load(f'../input/hw11strong/extractor_model.bin'))
t_label_predictor.load_state_dict(torch.load(f'../input/hw11strong/predictor_model.bin'))
t_feature_extractor.eval()
t_label_predictor.eval()

def new_state(model1, model2, beta=0.9):
    sd1 = model1.state_dict()
    sd2 = model2.state_dict()
    for key in sd2:
        sd2[key] = sd1[key] * (1 - beta) + sd2[key]*beta
        
    model2.load_state_dict(sd2)
    model2.eval()

# %% [markdown]
# # Start Training
#
#
# ## DaNN Implementation
#
# In the original paper, Gradient Reversal Layer is used.
# Feature Extractor, Label Predictor, and Domain Classifier are all trained at the same time. In this code, we train Domain Classifier first, and then train our Feature Extractor (same concept as Generator and Discriminator training process in GAN).
#
# ## Reminder
# * Lambda, which controls the domain adversarial loss, is adaptive in the original paper. You can refer to [the original work](https://arxiv.org/pdf/1505.07818.pdf) . Here lambda is set to 0.1.
# * We do not have the label to target data, you can only evaluate your model by uploading your result to kaggle.:)

# %%
ce = nn.CrossEntropyLoss(reduction='none')
def c_loss(logits, t_logits):
    prob, pseudo_label = t_logits.softmax(dim=1).max(dim=1)
    flag = prob > 0.95
    return (flag * ce(logits, pseudo_label)).sum() / (flag.sum() + 1e-8), flag.sum()

def train_epoch(source_dataloader, target_dataloader):
    running_loss = 0.0
    total_hit, total_num = 0.0, 0.0
    total_t_used, total_t = 0.0, 0.0

    for i, ((source_data, source_label), (target_data, _)) in enumerate(zip(source_dataloader, target_dataloader)):

        source_data = source_data.cuda()
        source_label = source_label.cuda()
        target_data = target_data.cuda()
        mixed_data = torch.cat([source_data, target_data], dim=0)
        
        class_logits = label_predictor(feature_extractor(mixed_data))
        with torch.no_grad():
            t_class_logits = t_label_predictor(t_feature_extractor(target_data))
        # loss = cross entropy of classification - lamb * domain binary cross entropy.
        #  The reason why using subtraction is similar to generator loss in disciminator of GAN
        loss_s = class_criterion(class_logits[:source_data.shape[0]], source_label)
        loss_t, num = c_loss(class_logits[source_data.shape[0]:], t_class_logits)
        loss = loss_s + loss_t
        running_loss += loss.item()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        
        total_t_used += num
        total_t += target_data.shape[0]
        total_hit += torch.sum(torch.argmax(class_logits[:source_data.shape[0]], dim=1) == source_label).item()
        total_num += source_data.shape[0]
        print(i, end='\r') 
        
    new_state(feature_extractor, t_feature_extractor)
    new_state(label_predictor, t_label_predictor)
        
    return running_loss / (i+1), total_hit / total_num, total_t_used/total_t

# train 200 epochs
print('start training')
epochs = 400
gap = 200
marked_epoch = [0] + [gap*i - 1 for i in range(1, epochs//gap + 1)]
for epoch in range(epochs):
    train_loss, train_acc, used_rate = train_epoch(source_dataloader, target_dataloader)
    
    if epoch in marked_epoch:
        torch.save(feature_extractor.state_dict(), f'extractor_model_{epoch}.bin')
        torch.save(label_predictor.state_dict(), f'predictor_model_{epoch}.bin')

    print('epoch {:>3d}: train loss: {:6.4f}, acc: {:6.4f}, used rate {:6.4f}'.format(epoch, train_loss, train_acc, used_rate))

torch.save(feature_extractor.state_dict(), f'extractor_model.bin')
torch.save(label_predictor.state_dict(), f'predictor_model.bin')
# Out:
# start training
# epoch   0: train loss: 0.1813, acc: 0.9868, used rate 0.9156
# epoch   1: train loss: 0.1826, acc: 0.9856, used rate 0.9158
# epoch   2: train loss: 0.1354, acc: 0.9872, used rate 0.9039
# epoch   3: train loss: 0.1021, acc: 0.9884, used rate 0.8913
# epoch   4: train loss: 0.1556, acc: 0.9860, used rate 0.8879
# epoch   5: train loss: 0.1180, acc: 0.9830, used rate 0.8760
# epoch   6: train loss: 0.1344, acc: 0.9852, used rate 0.8686
# epoch   7: train loss: 0.1135, acc: 0.9880, used rate 0.8722
# epoch   8: train loss: 0.0873, acc: 0.9884, used rate 0.8818
# epoch   9: train loss: 0.1127, acc: 0.9882, used rate 0.8752
# epoch  10: train loss: 0.1099, acc: 0.9882, used rate 0.8746
# epoch  11: train loss: 0.0813, acc: 0.9890, used rate 0.8686
# epoch  12: train loss: 0.0691, acc: 0.9922, used rate 0.8752
# epoch  13: train loss: 0.0823, acc: 0.9902, used rate 0.8772
# epoch  14: train loss: 0.0887, acc: 0.9894, used rate 0.8666
# epoch  15: train loss: 0.0798, acc: 0.9884, used rate 0.8764
# epoch  16: train loss: 0.0850, acc: 0.9888, used rate 0.8748
# epoch  17: train loss: 0.0855, acc: 0.9914, used rate 0.8762
# epoch  18: train loss: 0.0995, acc: 0.9872, used rate 0.8738
# epoch  19: train loss: 0.0774, acc: 0.9884, used rate 0.8704
# epoch  20: train loss: 0.0971, acc: 0.9866, used rate 0.8742
# epoch  21: train loss: 0.0899, acc: 0.9876, used rate 0.8790
# epoch  22: train loss: 0.1022, acc: 0.9848, used rate 0.8806
# epoch  23: train loss: 0.0773, acc: 0.9870, used rate 0.8768
# epoch  24: train loss: 0.0937, acc: 0.9882, used rate 0.8788
# epoch  25: train loss: 0.0811, acc: 0.9872, used rate 0.8704
# epoch  26: train loss: 0.0813, acc: 0.9890, used rate 0.8824
# epoch  27: train loss: 0.0836, acc: 0.9878, used rate 0.8774
# epoch  28: train loss: 0.0958, acc: 0.9860, used rate 0.8842
# epoch  29: train loss: 0.0860, acc: 0.9866, used rate 0.8816
# epoch  30: train loss: 0.1276, acc: 0.9826, used rate 0.8863
# epoch  31: train loss: 0.1211, acc: 0.9840, used rate 0.8788
# epoch  32: train loss: 0.1039, acc: 0.9838, used rate 0.8877
# epoch  33: train loss: 0.0725, acc: 0.9882, used rate 0.8768
# epoch  34: train loss: 0.0655, acc: 0.9896, used rate 0.8877
# epoch  35: train loss: 0.0729, acc: 0.9894, used rate 0.8788
# epoch  36: train loss: 0.0955, acc: 0.9856, used rate 0.8867
# epoch  37: train loss: 0.0963, acc: 0.9820, used rate 0.8905
# epoch  38: train loss: 0.0688, acc: 0.9884, used rate 0.8836
# epoch  39: train loss: 0.0762, acc: 0.9902, used rate 0.8949
# epoch  40: train loss: 0.0794, acc: 0.9862, used rate 0.8854
# epoch  41: train loss: 0.1004, acc: 0.9814, used rate 0.8891
# epoch  42: train loss: 0.0668, acc: 0.9880, used rate 0.8830
# epoch  43: train loss: 0.0716, acc: 0.9868, used rate 0.8967
# epoch  44: train loss: 0.0781, acc: 0.9872, used rate 0.8907
# epoch  45: train loss: 0.0846, acc: 0.9860, used rate 0.8913
# epoch  46: train loss: 0.0736, acc: 0.9870, used rate 0.8969
# epoch  47: train loss: 0.0825, acc: 0.9868, used rate 0.8913
# epoch  48: train loss: 0.1020, acc: 0.9834, used rate 0.8955
# epoch  49: train loss: 0.0691, acc: 0.9912, used rate 0.8895
# epoch  50: train loss: 0.0700, acc: 0.9910, used rate 0.8961
# epoch  51: train loss: 0.0669, acc: 0.9904, used rate 0.8959
# epoch  52: train loss: 0.0889, acc: 0.9882, used rate 0.8969
# epoch  53: train loss: 0.0771, acc: 0.9894, used rate 0.8939
# epoch  54: train loss: 0.0902, acc: 0.9872, used rate 0.8931
# epoch  55: train loss: 0.0752, acc: 0.9874, used rate 0.8931
# epoch  56: train loss: 0.0820, acc: 0.9864, used rate 0.8997
# epoch  57: train loss: 0.0953, acc: 0.9876, used rate 0.8945
# epoch  58: train loss: 0.0538, acc: 0.9876, used rate 0.8997
# epoch  59: train loss: 0.0669, acc: 0.9908, used rate 0.8997
# epoch  60: train loss: 0.0631, acc: 0.9868, used rate 0.8975
# epoch  61: train loss: 0.0849, acc: 0.9868, used rate 0.9025
# epoch  62: train loss: 0.0793, acc: 0.9862, used rate 0.8971
# epoch  63: train loss: 0.0960, acc: 0.9824, used rate 0.8977
# epoch  64: train loss: 0.0833, acc: 0.9864, used rate 0.8977
# epoch  65: train loss: 0.0741, acc: 0.9848, used rate 0.9017
# epoch  66: train loss: 0.0549, acc: 0.9902, used rate 0.8957
# epoch  67: train loss: 0.0865, acc: 0.9874, used rate 0.9066
# epoch  68: train loss: 0.0630, acc: 0.9880, used rate 0.9003
# epoch  69: train loss: 0.0710, acc: 0.9878, used rate 0.9047
# epoch  70: train loss: 0.0690, acc: 0.9894, used rate 0.9051
# epoch  71: train loss: 0.0791, acc: 0.9872, used rate 0.9122
# epoch  72: train loss: 0.0822, acc: 0.9850, used rate 0.9033
# epoch  73: train loss: 0.0725, acc: 0.9872, used rate 0.9001
# epoch  74: train loss: 0.0675, acc: 0.9866, used rate 0.9051
# epoch  75: train loss: 0.0772, acc: 0.9866, used rate 0.9098
# epoch  76: train loss: 0.0732, acc: 0.9880, used rate 0.9009
# epoch  77: train loss: 0.0677, acc: 0.9882, used rate 0.9023
# epoch  78: train loss: 0.0760, acc: 0.9872, used rate 0.9118
# epoch  79: train loss: 0.0601, acc: 0.9880, used rate 0.8993
# epoch  80: train loss: 0.1115, acc: 0.9832, used rate 0.9051
# epoch  81: train loss: 0.0945, acc: 0.9832, used rate 0.9064
# epoch  82: train loss: 0.0765, acc: 0.9884, used rate 0.9031
# epoch  83: train loss: 0.0714, acc: 0.9898, used rate 0.9080
# epoch  84: train loss: 0.0672, acc: 0.9872, used rate 0.9114
# epoch  85: train loss: 0.0571, acc: 0.9902, used rate 0.9070
# epoch  86: train loss: 0.0581, acc: 0.9898, used rate 0.9102
# epoch  87: train loss: 0.0813, acc: 0.9868, used rate 0.9090
# epoch  88: train loss: 0.0651, acc: 0.9914, used rate 0.9017
# epoch  89: train loss: 0.0903, acc: 0.9834, used rate 0.9088
# epoch  90: train loss: 0.0553, acc: 0.9904, used rate 0.9084
# epoch  91: train loss: 0.0702, acc: 0.9904, used rate 0.9092
# epoch  92: train loss: 0.1456, acc: 0.9744, used rate 0.9102
# epoch  93: train loss: 0.1004, acc: 0.9794, used rate 0.9015
# epoch  94: train loss: 0.0916, acc: 0.9848, used rate 0.9094
# epoch  95: train loss: 0.1134, acc: 0.9784, used rate 0.9033
# epoch  96: train loss: 0.0691, acc: 0.9866, used rate 0.8997
# epoch  97: train loss: 0.0526, acc: 0.9910, used rate 0.9035
# epoch  98: train loss: 0.0495, acc: 0.9902, used rate 0.9059
# epoch  99: train loss: 0.0486, acc: 0.9918, used rate 0.9084
# epoch 100: train loss: 0.0629, acc: 0.9902, used rate 0.9088
# epoch 101: train loss: 0.0638, acc: 0.9900, used rate 0.9094
# epoch 102: train loss: 0.0536, acc: 0.9898, used rate 0.9172
# epoch 103: train loss: 0.0547, acc: 0.9914, used rate 0.9148
# epoch 104: train loss: 0.0642, acc: 0.9886, used rate 0.9172
# epoch 105: train loss: 0.0769, acc: 0.9840, used rate 0.9160
# epoch 106: train loss: 0.0657, acc: 0.9862, used rate 0.9138
# epoch 107: train loss: 0.0715, acc: 0.9876, used rate 0.9108
# epoch 108: train loss: 0.0783, acc: 0.9872, used rate 0.9190
# epoch 109: train loss: 0.0836, acc: 0.9862, used rate 0.9184
# epoch 110: train loss: 0.0723, acc: 0.9888, used rate 0.9144
# epoch 111: train loss: 0.0624, acc: 0.9886, used rate 0.9180
# epoch 112: train loss: 0.0537, acc: 0.9906, used rate 0.9140
# epoch 113: train loss: 0.0645, acc: 0.9904, used rate 0.9184
# epoch 114: train loss: 0.0630, acc: 0.9878, used rate 0.9112
# epoch 115: train loss: 0.0583, acc: 0.9892, used rate 0.9126
# epoch 116: train loss: 0.0417, acc: 0.9888, used rate 0.9110
# epoch 117: train loss: 0.0754, acc: 0.9878, used rate 0.9118
# epoch 118: train loss: 0.0521, acc: 0.9904, used rate 0.9148
# epoch 119: train loss: 0.0776, acc: 0.9864, used rate 0.9142
# epoch 120: train loss: 0.0699, acc: 0.9854, used rate 0.9238
# epoch 121: train loss: 0.0694, acc: 0.9892, used rate 0.9182
# epoch 122: train loss: 0.0635, acc: 0.9902, used rate 0.9158
# epoch 123: train loss: 0.0668, acc: 0.9880, used rate 0.9152
# epoch 124: train loss: 0.0799, acc: 0.9854, used rate 0.9220
# epoch 125: train loss: 0.0558, acc: 0.9900, used rate 0.9252
# epoch 126: train loss: 0.0625, acc: 0.9882, used rate 0.9192
# epoch 127: train loss: 0.0659, acc: 0.9904, used rate 0.9170
# epoch 128: train loss: 0.0793, acc: 0.9846, used rate 0.9108
# epoch 129: train loss: 0.0509, acc: 0.9912, used rate 0.9098
# epoch 130: train loss: 0.0618, acc: 0.9888, used rate 0.9236
# epoch 131: train loss: 0.0739, acc: 0.9872, used rate 0.9194
# epoch 132: train loss: 0.0760, acc: 0.9884, used rate 0.9182
# epoch 133: train loss: 0.0753, acc: 0.9880, used rate 0.9162
# epoch 134: train loss: 0.0558, acc: 0.9902, used rate 0.9164
# epoch 135: train loss: 0.0667, acc: 0.9878, used rate 0.9126
# epoch 136: train loss: 0.0606, acc: 0.9902, used rate 0.9066
# epoch 137: train loss: 0.0421, acc: 0.9904, used rate 0.9200
# epoch 138: train loss: 0.0656, acc: 0.9890, used rate 0.9238
# epoch 139: train loss: 0.0515, acc: 0.9886, used rate 0.9134
# epoch 140: train loss: 0.0604, acc: 0.9874, used rate 0.9208
# epoch 141: train loss: 0.0886, acc: 0.9874, used rate 0.9188
# epoch 142: train loss: 0.0492, acc: 0.9898, used rate 0.9140
# epoch 143: train loss: 0.0546, acc: 0.9900, used rate 0.9150
# epoch 144: train loss: 0.0795, acc: 0.9850, used rate 0.9252
# epoch 145: train loss: 0.0582, acc: 0.9864, used rate 0.9234
# epoch 146: train loss: 0.0575, acc: 0.9878, used rate 0.9168
# epoch 147: train loss: 0.0558, acc: 0.9892, used rate 0.9234
# epoch 148: train loss: 0.0546, acc: 0.9920, used rate 0.9198
# epoch 149: train loss: 0.0592, acc: 0.9898, used rate 0.9234
# epoch 150: train loss: 0.0677, acc: 0.9882, used rate 0.9238
# epoch 151: train loss: 0.0599, acc: 0.9894, used rate 0.9258
# epoch 152: train loss: 0.0547, acc: 0.9910, used rate 0.9329
# epoch 153: train loss: 0.0509, acc: 0.9920, used rate 0.9285
# epoch 154: train loss: 0.0587, acc: 0.9900, used rate 0.9208
# epoch 155: train loss: 0.0661, acc: 0.9874, used rate 0.9277
# epoch 156: train loss: 0.0568, acc: 0.9876, used rate 0.9202
# epoch 157: train loss: 0.0613, acc: 0.9904, used rate 0.9214
# epoch 158: train loss: 0.0811, acc: 0.9894, used rate 0.9283
# epoch 159: train loss: 0.0801, acc: 0.9844, used rate 0.9240
# epoch 160: train loss: 0.0530, acc: 0.9898, used rate 0.9258
# epoch 161: train loss: 0.0737, acc: 0.9878, used rate 0.9268
# epoch 162: train loss: 0.0708, acc: 0.9854, used rate 0.9275
# epoch 163: train loss: 0.0866, acc: 0.9840, used rate 0.9309
# epoch 164: train loss: 0.1070, acc: 0.9864, used rate 0.9234
# epoch 165: train loss: 0.0531, acc: 0.9906, used rate 0.9283
# epoch 166: train loss: 0.0572, acc: 0.9876, used rate 0.9216
# epoch 167: train loss: 0.0436, acc: 0.9914, used rate 0.9331
# epoch 168: train loss: 0.0435, acc: 0.9920, used rate 0.9293
# epoch 169: train loss: 0.0603, acc: 0.9872, used rate 0.9266
# epoch 170: train loss: 0.0608, acc: 0.9912, used rate 0.9271
# epoch 171: train loss: 0.0723, acc: 0.9866, used rate 0.9258
# epoch 172: train loss: 0.0605, acc: 0.9894, used rate 0.9230
# epoch 173: train loss: 0.0558, acc: 0.9918, used rate 0.9250
# epoch 174: train loss: 0.0418, acc: 0.9916, used rate 0.9355
# epoch 175: train loss: 0.0575, acc: 0.9902, used rate 0.9363
# epoch 176: train loss: 0.0530, acc: 0.9898, used rate 0.9256
# epoch 177: train loss: 0.0538, acc: 0.9900, used rate 0.9355
# epoch 178: train loss: 0.0534, acc: 0.9940, used rate 0.9281
# epoch 179: train loss: 0.0568, acc: 0.9928, used rate 0.9281
# epoch 180: train loss: 0.0479, acc: 0.9922, used rate 0.9252
# epoch 181: train loss: 0.0943, acc: 0.9846, used rate 0.9357
# epoch 182: train loss: 0.0510, acc: 0.9886, used rate 0.9228
# epoch 183: train loss: 0.0563, acc: 0.9908, used rate 0.9285
# epoch 184: train loss: 0.0491, acc: 0.9922, used rate 0.9275
# epoch 185: train loss: 0.0649, acc: 0.9878, used rate 0.9244
# epoch 186: train loss: 0.0623, acc: 0.9886, used rate 0.9204
# epoch 187: train loss: 0.0718, acc: 0.9880, used rate 0.9236
# epoch 188: train loss: 0.0501, acc: 0.9922, used rate 0.9271
# epoch 189: train loss: 0.0585, acc: 0.9896, used rate 0.9279
# epoch 190: train loss: 0.0481, acc: 0.9928, used rate 0.9283
# epoch 191: train loss: 0.0367, acc: 0.9924, used rate 0.9260
# epoch 192: train loss: 0.0633, acc: 0.9912, used rate 0.9281
# epoch 193: train loss: 0.0522, acc: 0.9904, used rate 0.9248
# epoch 194: train loss: 0.0570, acc: 0.9924, used rate 0.9266
# epoch 195: train loss: 0.0379, acc: 0.9922, used rate 0.9323
# epoch 196: train loss: 0.0582, acc: 0.9896, used rate 0.9285
# epoch 197: train loss: 0.0532, acc: 0.9892, used rate 0.9315
# epoch 198: train loss: 0.0617, acc: 0.9908, used rate 0.9291
# epoch 199: train loss: 0.0527, acc: 0.9902, used rate 0.9337
# epoch 200: train loss: 0.0761, acc: 0.9874, used rate 0.9327
# epoch 201: train loss: 0.0666, acc: 0.9908, used rate 0.9309
# epoch 202: train loss: 0.0483, acc: 0.9892, used rate 0.9289
# epoch 203: train loss: 0.0479, acc: 0.9898, used rate 0.9242
# epoch 204: train loss: 0.0539, acc: 0.9914, used rate 0.9313
# epoch 205: train loss: 0.1192, acc: 0.9864, used rate 0.9343
# epoch 206: train loss: 0.1002, acc: 0.9846, used rate 0.9268
# epoch 207: train loss: 0.0771, acc: 0.9848, used rate 0.9283
# epoch 208: train loss: 0.0593, acc: 0.9882, used rate 0.9222
# epoch 209: train loss: 0.0759, acc: 0.9854, used rate 0.9309
# epoch 210: train loss: 0.0504, acc: 0.9870, used rate 0.9285
# epoch 211: train loss: 0.0477, acc: 0.9890, used rate 0.9323
# epoch 212: train loss: 0.0311, acc: 0.9940, used rate 0.9242
# epoch 213: train loss: 0.0620, acc: 0.9898, used rate 0.9307
# epoch 214: train loss: 0.0494, acc: 0.9914, used rate 0.9367
# epoch 215: train loss: 0.0406, acc: 0.9924, used rate 0.9373
# epoch 216: train loss: 0.0442, acc: 0.9938, used rate 0.9377
# epoch 217: train loss: 0.0419, acc: 0.9922, used rate 0.9333
# epoch 218: train loss: 0.0532, acc: 0.9902, used rate 0.9355
# epoch 219: train loss: 0.0577, acc: 0.9894, used rate 0.9349
# epoch 220: train loss: 0.0505, acc: 0.9900, used rate 0.9329
# epoch 221: train loss: 0.0444, acc: 0.9920, used rate 0.9377
# epoch 222: train loss: 0.0547, acc: 0.9896, used rate 0.9279
# epoch 223: train loss: 0.0613, acc: 0.9902, used rate 0.9345
# epoch 224: train loss: 0.0628, acc: 0.9878, used rate 0.9333
# epoch 225: train loss: 0.0527, acc: 0.9906, used rate 0.9319
# epoch 226: train loss: 0.0609, acc: 0.9894, used rate 0.9329
# epoch 227: train loss: 0.0525, acc: 0.9916, used rate 0.9331
# epoch 228: train loss: 0.0522, acc: 0.9904, used rate 0.9311
# epoch 229: train loss: 0.0599, acc: 0.9922, used rate 0.9319
# epoch 230: train loss: 0.0411, acc: 0.9924, used rate 0.9335
# epoch 231: train loss: 0.0494, acc: 0.9906, used rate 0.9333
# epoch 232: train loss: 0.0512, acc: 0.9902, used rate 0.9289
# epoch 233: train loss: 0.0428, acc: 0.9930, used rate 0.9311
# epoch 234: train loss: 0.0300, acc: 0.9958, used rate 0.9329
# epoch 235: train loss: 0.0370, acc: 0.9936, used rate 0.9339
# epoch 236: train loss: 0.0684, acc: 0.9874, used rate 0.9375
# epoch 237: train loss: 0.0548, acc: 0.9884, used rate 0.9357
# epoch 238: train loss: 0.0618, acc: 0.9894, used rate 0.9345
# epoch 239: train loss: 0.0361, acc: 0.9932, used rate 0.9319
# epoch 240: train loss: 0.0491, acc: 0.9916, used rate 0.9333
# epoch 241: train loss: 0.0583, acc: 0.9872, used rate 0.9309
# epoch 242: train loss: 0.0704, acc: 0.9864, used rate 0.9355
# epoch 243: train loss: 0.0552, acc: 0.9902, used rate 0.9347
# epoch 244: train loss: 0.0519, acc: 0.9914, used rate 0.9369
# epoch 245: train loss: 0.0574, acc: 0.9904, used rate 0.9301
# epoch 246: train loss: 0.0463, acc: 0.9912, used rate 0.9341
# epoch 247: train loss: 0.0672, acc: 0.9884, used rate 0.9405
# epoch 248: train loss: 0.0797, acc: 0.9862, used rate 0.9345
# epoch 249: train loss: 0.0613, acc: 0.9890, used rate 0.9317
# epoch 250: train loss: 0.0468, acc: 0.9914, used rate 0.9337
# epoch 251: train loss: 0.0449, acc: 0.9916, used rate 0.9355
# epoch 252: train loss: 0.0492, acc: 0.9918, used rate 0.9359
# epoch 253: train loss: 0.0435, acc: 0.9898, used rate 0.9301
# epoch 254: train loss: 0.0438, acc: 0.9894, used rate 0.9357
# epoch 255: train loss: 0.0279, acc: 0.9934, used rate 0.9339
# epoch 256: train loss: 0.0637, acc: 0.9892, used rate 0.9383
# epoch 257: train loss: 0.0649, acc: 0.9882, used rate 0.9329
# epoch 258: train loss: 0.0642, acc: 0.9904, used rate 0.9429
# epoch 259: train loss: 0.0395, acc: 0.9930, used rate 0.9427
# epoch 260: train loss: 0.0664, acc: 0.9866, used rate 0.9295
# epoch 261: train loss: 0.0413, acc: 0.9918, used rate 0.9413
# epoch 262: train loss: 0.0567, acc: 0.9904, used rate 0.9397
# epoch 263: train loss: 0.0657, acc: 0.9882, used rate 0.9359
# epoch 264: train loss: 0.0504, acc: 0.9904, used rate 0.9397
# epoch 265: train loss: 0.0349, acc: 0.9930, used rate 0.9391
# epoch 266: train loss: 0.0534, acc: 0.9910, used rate 0.9357
# epoch 267: train loss: 0.0512, acc: 0.9920, used rate 0.9361
# epoch 268: train loss: 0.0598, acc: 0.9910, used rate 0.9375
# epoch 269: train loss: 0.0456, acc: 0.9900, used rate 0.9395
# epoch 270: train loss: 0.0386, acc: 0.9922, used rate 0.9357
# epoch 271: train loss: 0.0389, acc: 0.9920, used rate 0.9341
# epoch 272: train loss: 0.0589, acc: 0.9888, used rate 0.9401
# epoch 273: train loss: 0.0488, acc: 0.9910, used rate 0.9333
# epoch 274: train loss: 0.0530, acc: 0.9874, used rate 0.9413
# epoch 275: train loss: 0.0455, acc: 0.9926, used rate 0.9345
# epoch 276: train loss: 0.0395, acc: 0.9920, used rate 0.9381
# epoch 277: train loss: 0.0347, acc: 0.9938, used rate 0.9377
# epoch 278: train loss: 0.0578, acc: 0.9918, used rate 0.9411
# epoch 279: train loss: 0.0492, acc: 0.9916, used rate 0.9423
# epoch 280: train loss: 0.0469, acc: 0.9902, used rate 0.9339
# epoch 281: train loss: 0.0518, acc: 0.9912, used rate 0.9403
# epoch 282: train loss: 0.0382, acc: 0.9924, used rate 0.9397
# epoch 283: train loss: 0.0423, acc: 0.9948, used rate 0.9367
# epoch 284: train loss: 0.0472, acc: 0.9914, used rate 0.9385
# epoch 285: train loss: 0.0458, acc: 0.9912, used rate 0.9399
# epoch 286: train loss: 0.0433, acc: 0.9926, used rate 0.9381
# epoch 287: train loss: 0.0404, acc: 0.9942, used rate 0.9445
# epoch 288: train loss: 0.0531, acc: 0.9936, used rate 0.9429
# epoch 289: train loss: 0.0635, acc: 0.9874, used rate 0.9435
# epoch 290: train loss: 0.0448, acc: 0.9906, used rate 0.9409
# epoch 291: train loss: 0.0517, acc: 0.9888, used rate 0.9367
# epoch 292: train loss: 0.0487, acc: 0.9906, used rate 0.9347
# epoch 293: train loss: 0.0568, acc: 0.9890, used rate 0.9319
# epoch 294: train loss: 0.0512, acc: 0.9914, used rate 0.9347
# epoch 295: train loss: 0.0449, acc: 0.9904, used rate 0.9321
# epoch 296: train loss: 0.0651, acc: 0.9910, used rate 0.9379
# epoch 297: train loss: 0.1126, acc: 0.9822, used rate 0.9377
# epoch 298: train loss: 0.0477, acc: 0.9890, used rate 0.9415
# epoch 299: train loss: 0.0450, acc: 0.9922, used rate 0.9341
# epoch 300: train loss: 0.0454, acc: 0.9934, used rate 0.9411
# epoch 301: train loss: 0.0510, acc: 0.9910, used rate 0.9441
# epoch 302: train loss: 0.0415, acc: 0.9926, used rate 0.9323
# epoch 303: train loss: 0.0526, acc: 0.9922, used rate 0.9379
# epoch 304: train loss: 0.0511, acc: 0.9920, used rate 0.9353
# epoch 305: train loss: 0.0468, acc: 0.9938, used rate 0.9415
# epoch 306: train loss: 0.0391, acc: 0.9924, used rate 0.9373
# epoch 307: train loss: 0.0382, acc: 0.9902, used rate 0.9383
# epoch 308: train loss: 0.0490, acc: 0.9906, used rate 0.9427
# epoch 309: train loss: 0.0372, acc: 0.9926, used rate 0.9403
# epoch 310: train loss: 0.0616, acc: 0.9906, used rate 0.9439
# epoch 311: train loss: 0.0515, acc: 0.9904, used rate 0.9433
# epoch 312: train loss: 0.0502, acc: 0.9916, used rate 0.9469
# epoch 313: train loss: 0.0354, acc: 0.9934, used rate 0.9395
# epoch 314: train loss: 0.0361, acc: 0.9918, used rate 0.9359
# epoch 315: train loss: 0.0432, acc: 0.9916, used rate 0.9383
# epoch 316: train loss: 0.0582, acc: 0.9884, used rate 0.9453
# epoch 317: train loss: 0.0457, acc: 0.9916, used rate 0.9377
# epoch 318: train loss: 0.0493, acc: 0.9920, used rate 0.9359
# epoch 319: train loss: 0.0493, acc: 0.9922, used rate 0.9413
# epoch 320: train loss: 0.0481, acc: 0.9914, used rate 0.9391
# epoch 321: train loss: 0.0401, acc: 0.9920, used rate 0.9407
# epoch 322: train loss: 0.0574, acc: 0.9910, used rate 0.9403
# epoch 323: train loss: 0.0472, acc: 0.9916, used rate 0.9433
# epoch 324: train loss: 0.0432, acc: 0.9942, used rate 0.9369
# epoch 325: train loss: 0.0513, acc: 0.9910, used rate 0.9381
# epoch 326: train loss: 0.0454, acc: 0.9902, used rate 0.9385
# epoch 327: train loss: 0.0436, acc: 0.9910, used rate 0.9393
# epoch 328: train loss: 0.0364, acc: 0.9932, used rate 0.9387
# epoch 329: train loss: 0.0466, acc: 0.9912, used rate 0.9455
# epoch 330: train loss: 0.0370, acc: 0.9930, used rate 0.9383
# epoch 331: train loss: 0.0414, acc: 0.9920, used rate 0.9389
# epoch 332: train loss: 0.0556, acc: 0.9900, used rate 0.9427
# epoch 333: train loss: 0.0391, acc: 0.9948, used rate 0.9467
# epoch 334: train loss: 0.0458, acc: 0.9926, used rate 0.9411
# epoch 335: train loss: 0.0420, acc: 0.9932, used rate 0.9415
# epoch 336: train loss: 0.0386, acc: 0.9938, used rate 0.9451
# epoch 337: train loss: 0.0444, acc: 0.9914, used rate 0.9383
# epoch 338: train loss: 0.0562, acc: 0.9906, used rate 0.9451
# epoch 339: train loss: 0.0339, acc: 0.9928, used rate 0.9427
# epoch 340: train loss: 0.0686, acc: 0.9878, used rate 0.9459
# epoch 341: train loss: 0.0485, acc: 0.9910, used rate 0.9435
# epoch 342: train loss: 0.0457, acc: 0.9918, used rate 0.9443
# epoch 343: train loss: 0.0595, acc: 0.9932, used rate 0.9459
# epoch 344: train loss: 0.0673, acc: 0.9864, used rate 0.9437
# epoch 345: train loss: 0.0465, acc: 0.9912, used rate 0.9411
# epoch 346: train loss: 0.0488, acc: 0.9900, used rate 0.9421
# epoch 347: train loss: 0.0503, acc: 0.9914, used rate 0.9391
# epoch 348: train loss: 0.0386, acc: 0.9932, used rate 0.9401
# epoch 349: train loss: 0.0365, acc: 0.9926, used rate 0.9431
# epoch 350: train loss: 0.0316, acc: 0.9950, used rate 0.9469
# epoch 351: train loss: 0.0408, acc: 0.9924, used rate 0.9451
# epoch 352: train loss: 0.0345, acc: 0.9936, used rate 0.9463
# epoch 353: train loss: 0.0351, acc: 0.9930, used rate 0.9455
# epoch 354: train loss: 0.0427, acc: 0.9912, used rate 0.9502
# epoch 355: train loss: 0.0468, acc: 0.9948, used rate 0.9479
# epoch 356: train loss: 0.0499, acc: 0.9914, used rate 0.9409
# epoch 357: train loss: 0.1730, acc: 0.9714, used rate 0.9389
# epoch 358: train loss: 0.0624, acc: 0.9878, used rate 0.9480
# epoch 359: train loss: 0.0452, acc: 0.9900, used rate 0.9508
# epoch 360: train loss: 0.0509, acc: 0.9902, used rate 0.9494
# epoch 361: train loss: 0.0403, acc: 0.9924, used rate 0.9488
# epoch 362: train loss: 0.0353, acc: 0.9950, used rate 0.9411
# epoch 363: train loss: 0.0406, acc: 0.9928, used rate 0.9377
# epoch 364: train loss: 0.0425, acc: 0.9930, used rate 0.9451
# epoch 365: train loss: 0.0374, acc: 0.9930, used rate 0.9459
# epoch 366: train loss: 0.0481, acc: 0.9932, used rate 0.9482
# epoch 367: train loss: 0.0343, acc: 0.9934, used rate 0.9441
# epoch 368: train loss: 0.0316, acc: 0.9954, used rate 0.9482
# epoch 369: train loss: 0.0432, acc: 0.9918, used rate 0.9524
# epoch 370: train loss: 0.1003, acc: 0.9828, used rate 0.9427
# epoch 371: train loss: 0.0699, acc: 0.9878, used rate 0.9457
# epoch 372: train loss: 0.0625, acc: 0.9896, used rate 0.9427
# epoch 373: train loss: 0.0400, acc: 0.9916, used rate 0.9405
# epoch 374: train loss: 0.0468, acc: 0.9918, used rate 0.9425
# epoch 375: train loss: 0.0421, acc: 0.9922, used rate 0.9413
# epoch 376: train loss: 0.0383, acc: 0.9920, used rate 0.9415
# epoch 377: train loss: 0.0302, acc: 0.9928, used rate 0.9415
# epoch 378: train loss: 0.0363, acc: 0.9932, used rate 0.9403
# epoch 379: train loss: 0.0316, acc: 0.9930, used rate 0.9375
# epoch 380: train loss: 0.0321, acc: 0.9946, used rate 0.9413
# epoch 381: train loss: 0.0387, acc: 0.9922, used rate 0.9429
# epoch 382: train loss: 0.0327, acc: 0.9924, used rate 0.9397
# epoch 383: train loss: 0.0377, acc: 0.9942, used rate 0.9449
# epoch 384: train loss: 0.0381, acc: 0.9948, used rate 0.9443
# epoch 385: train loss: 0.0346, acc: 0.9946, used rate 0.9441
# epoch 386: train loss: 0.0391, acc: 0.9918, used rate 0.9477
# epoch 387: train loss: 0.0363, acc: 0.9922, used rate 0.9465
# epoch 388: train loss: 0.0324, acc: 0.9930, used rate 0.9455
# epoch 389: train loss: 0.0356, acc: 0.9932, used rate 0.9482
# epoch 390: train loss: 0.0428, acc: 0.9902, used rate 0.9469
# epoch 391: train loss: 0.0513, acc: 0.9916, used rate 0.9467
# epoch 392: train loss: 0.0412, acc: 0.9926, used rate 0.9473
# epoch 393: train loss: 0.0361, acc: 0.9936, used rate 0.9447
# epoch 394: train loss: 0.0874, acc: 0.9840, used rate 0.9496
# epoch 395: train loss: 0.0488, acc: 0.9888, used rate 0.9443
# epoch 396: train loss: 0.0535, acc: 0.9880, used rate 0.9437
# epoch 397: train loss: 0.0470, acc: 0.9910, used rate 0.9391
# epoch 398: train loss: 0.0428, acc: 0.9922, used rate 0.9409
# epoch 399: train loss: 0.0564, acc: 0.9920, used rate 0.9486

# %% [markdown]
# # Inference
#
# We use pandas to generate our csv file.
#
# BTW, the performance of the model trained for 200 epoches might be unstable. You can train for more epoches for a more stable performance.

# %%
result = []
label_predictor.eval()
feature_extractor.eval()
for i, (test_data, _) in enumerate(test_dataloader):
    test_data = test_data.cuda()

    class_logits = label_predictor(feature_extractor(test_data))

    x = torch.argmax(class_logits, dim=1).cpu().detach().numpy()
    result.append(x)

import pandas as pd
result = np.concatenate(result)

# Generate your submission
df = pd.DataFrame({'id': np.arange(0,len(result)), 'label': result})
df.to_csv('DaNN_submission.csv',index=False)

# %% [markdown]
# # Visualization
# We use t-SNE plot to observe the distribution of extracted features.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold

# %%
class Feature():
    def __init__(self):
        self.X = []
        self.TX = []
        self.labels = []

def get_features(model_list):
    features = []
    for model in model_list:
        model.cuda()
        model.eval()
        features.append(Feature())
    for (x, y), (tx, _) in zip(source_dataloader, target_dataloader):
        x , tx= x.cuda(), tx.cuda()
        for i, model in enumerate(model_list):
            features[i].X.append(model(x).detach().cpu())
            features[i].TX.append(model(tx).detach().cpu())
            features[i].labels.append(y)
    
    for feature in features:
        feature.X = torch.cat(feature.X).numpy()
        feature.TX = torch.cat(feature.TX).numpy()
        feature.labels = torch.cat(feature.labels).numpy()
        
    return features

def visualization(features):
    for i, feature in enumerate(features):
        data = np.concatenate([feature.X, feature.TX])
        num_source = len(feature.labels)
        X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(data)
        # Normalization the processed features 
        x_min, x_max = X_tsne.min(0), X_tsne.max(0)
        X_norm = (X_tsne - x_min) / (x_max - x_min)
    
        plt.figure(figsize=(16, 8))
        plt.subplot(121)
        plt.title(f'epoch {marked_epoch[i]}:distribution of features accross different class')
        plt.scatter(X_norm[:num_source, 0], X_norm[:num_source, 1], c=feature.labels, label='source domain')
        plt.subplot(122)
        plt.title(f'epoch {marked_epoch[i]}:distribution of features accross different domain')
        plt.scatter(X_norm[:num_source, 0], X_norm[:num_source, 1], c='b', label='source domain')
        plt.scatter(X_norm[num_source:, 0], X_norm[num_source:, 1], c='r', label='target domain', alpha=0.5)
        plt.legend()
    plt.show()

# %%
model_list = []
for epoch in marked_epoch:
    model = FeatureExtractor()
    model.load_state_dict(torch.load(f'extractor_model_{epoch}.bin'))
    model_list.append(model)
    
visualization(get_features(model_list))
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10024 samples in 0.005s...
# [t-SNE] Computed neighbors for 10024 samples in 3.389s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10024
# [t-SNE] Computed conditional probabilities for sample 2000 / 10024
# [t-SNE] Computed conditional probabilities for sample 3000 / 10024
# [t-SNE] Computed conditional probabilities for sample 4000 / 10024
# [t-SNE] Computed conditional probabilities for sample 5000 / 10024
# [t-SNE] Computed conditional probabilities for sample 6000 / 10024
# [t-SNE] Computed conditional probabilities for sample 7000 / 10024
# [t-SNE] Computed conditional probabilities for sample 8000 / 10024
# [t-SNE] Computed conditional probabilities for sample 9000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10024 / 10024
# [t-SNE] Mean sigma: 1.144668
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.036415
# [t-SNE] KL divergence after 1000 iterations: 1.985181
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10024 samples in 0.004s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 10024 samples in 4.263s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10024
# [t-SNE] Computed conditional probabilities for sample 2000 / 10024
# [t-SNE] Computed conditional probabilities for sample 3000 / 10024
# [t-SNE] Computed conditional probabilities for sample 4000 / 10024
# [t-SNE] Computed conditional probabilities for sample 5000 / 10024
# [t-SNE] Computed conditional probabilities for sample 6000 / 10024
# [t-SNE] Computed conditional probabilities for sample 7000 / 10024
# [t-SNE] Computed conditional probabilities for sample 8000 / 10024
# [t-SNE] Computed conditional probabilities for sample 9000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10024 / 10024
# [t-SNE] Mean sigma: 1.283252
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.740044
# [t-SNE] KL divergence after 1000 iterations: 1.763971
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10024 samples in 0.004s...
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 10024 samples in 4.515s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10024
# [t-SNE] Computed conditional probabilities for sample 2000 / 10024
# [t-SNE] Computed conditional probabilities for sample 3000 / 10024
# [t-SNE] Computed conditional probabilities for sample 4000 / 10024
# [t-SNE] Computed conditional probabilities for sample 5000 / 10024
# [t-SNE] Computed conditional probabilities for sample 6000 / 10024
# [t-SNE] Computed conditional probabilities for sample 7000 / 10024
# [t-SNE] Computed conditional probabilities for sample 8000 / 10024
# [t-SNE] Computed conditional probabilities for sample 9000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10000 / 10024
# [t-SNE] Computed conditional probabilities for sample 10024 / 10024
# [t-SNE] Mean sigma: 1.312352
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.897934
# [t-SNE] KL divergence after 1000 iterations: 1.723547

# %% [markdown]
# ## Step1: Load checkpoint and evaluate to get extracted features

# %%
# Hints:
# Set features_extractor to eval mode
# Start evaluation and collect features and labels

# %% [markdown]
# ## Step2: Apply t-SNE and normalize

# %%
# process extracted features with t-SNE
# X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(X)

# Normalization the processed features 
# x_min, x_max = X_tsne.min(0), X_tsne.max(0)
# X_norm = (X_tsne - x_min) / (x_max - x_min)

# %% [markdown]
# ## Step3: Visualization with matplotlib

# %%
# Data Visualization
# Use matplotlib to plot the distribution
# The shape of X_norm is (N,2)

# %% [markdown]
# # Training Statistics
#
# - Number of parameters:
#   - Feature Extractor: 2, 142, 336
#   - Label Predictor: 530, 442
#   - Domain Classifier: 1, 055, 233
#
# - Simple
#  - Training time on colab: ~ 1 hr
# - Medium
#  - Training time on colab: 2 ~ 4 hr
# - Strong
#  - Training time on colab: 5 ~ 6 hrs
# - Boss
#  - **Unmeasurable**

# %% [markdown]
# # Learning Curve (Strong Baseline)
# * This method is slightly different from colab.
#
# ![Loss Curve](https://i.imgur.com/vIujQyo.png)
#
# # Accuracy Curve (Strong Baseline)
# * Note that you cannot access testing accuracy. But this plot tells you that even though the model overfits the training data, the testing accuracy is still improving, and that's why you need to train more epochs.
#
# ![Acc Curve](https://i.imgur.com/4W1otXG.png)

# %% [markdown]
# # Q&A
#
# If there is any problem related to Domain Adaptation, please email to b08901058@ntu.edu.tw / mlta-2022-spring@googlegroups.com。
